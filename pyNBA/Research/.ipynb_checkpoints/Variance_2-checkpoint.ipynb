# %%
import pandas as pd
import numpy as np
from pyNBA.Data.data import QueryData
from pyNBA.Models.helpers import CleanData
from pyNBA.DFS.rules import FPCalculator
from pyNBA.DFS.constants import Site
from pyNBA.Data.constants import (ROTOWIRE_NAME_TO_NBA_NAME, LINESTARAPP_TEAM_TO_NBA_TEAM,
                                  LINESTARAPP_NAME_TO_NBA_NAME, OWNERSHIP_NAME_TO_NBA_NAME,
                                  BAD_CONTEST_SUBSTRINGS)

import warnings
warnings.filterwarnings('ignore')
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
query_data = QueryData(update=False)
clean_data = CleanData()

linestarapp_data = query_data.query_linestarapp_data()
linestarapp_data = linestarapp_data.loc[linestarapp_data['SITE'] == 'DRAFTKINGS']
linestarapp_data['PLAYER_NAME'] = linestarapp_data['PLAYER_NAME'].apply(
    lambda x: x if x not in LINESTARAPP_NAME_TO_NBA_NAME else LINESTARAPP_NAME_TO_NBA_NAME[x]
)
linestarapp_data['TEAM'] = linestarapp_data['TEAM'].apply(
    lambda x: x if x not in LINESTARAPP_TEAM_TO_NBA_TEAM else LINESTARAPP_TEAM_TO_NBA_TEAM[x]
)

rotowire_data = query_data.query_rotowire_data()
rotowire_data = rotowire_data.drop(columns=['TEAM', 'POS', 'G'])
rotowire_data['PLAYER_NAME'] = rotowire_data['PLAYER_NAME'].apply(
    lambda x: x if x not in ROTOWIRE_NAME_TO_NBA_NAME else ROTOWIRE_NAME_TO_NBA_NAME[x]
)

salary_data = query_data.query_salary_data()
salary_data = salary_data.loc[salary_data['SITE'] == 'DRAFTKINGS']
salary_data['POSITION'] = salary_data['POSITION'].apply(lambda x: x.replace('_', '/'))
salary_data['NAME'] = salary_data['PLAYER'].apply(clean_data.convert_rotoguru_name_to_nba_name)

boxscore_data = query_data.query_boxscore_data()
# Out:
# /Users/brandonshimiaie/Projects/pyNBA/sqlite/db/nba.db
# 2.6.0

# %%
def _get_projection(roto_projection, linestar_projection):
    if np.isnan(roto_projection) and np.isnan(linestar_projection):
        return 0
    elif np.isnan(roto_projection):
        return linestar_projection
    elif np.isnan(linestar_projection):
        return roto_projection
    elif roto_projection == 0 and linestar_projection != 0:
        return linestar_projection
    elif roto_projection != 0 and linestar_projection == 0:
        return 0
    else:
        return roto_projection

linestarapp_data = linestarapp_data.loc[linestarapp_data['SITE'] == 'DRAFTKINGS']
linestarapp_data = linestarapp_data.rename(columns={'PROJECTION': 'LINESTARAPP_PROJECTION'})

rotowire_data['ROTOWIRE_PROJECTION'] = rotowire_data.apply(
    lambda row: FPCalculator.calculate_draftkings_fp(
        row['PTS'], row['REB'], row['AST'], row['TOV'], row['BLK'], row['STL'], row['THREEPM'], (row['DBLDBL'], row['TRPDBL'])
    ),
    axis=1
)
projections = linestarapp_data.merge(rotowire_data, on=['DATE', 'PLAYER_NAME'], how='left')
projections['PROJECTION'] = projections.apply(
    lambda row: _get_projection(row['ROTOWIRE_PROJECTION'], row['LINESTARAPP_PROJECTION']),
    axis=1
)

player_comments = boxscore_data[['DATE', 'NAME', 'COMMENT']]
player_comments = player_comments.rename(columns={'NAME': 'PLAYER_NAME'})
projections = projections.merge(player_comments, on=['DATE', 'PLAYER_NAME'], how='left')

projections = projections.loc[projections['DATE'].isin(set(boxscore_data['DATE'].unique()))]
projections = projections[[
    'DATE', 'SITE', 'PLAYER_ID', 'PLAYER_NAME', 'POS', 'TEAM', 'START', 'SPREAD', 'TOTAL',
    'OPPRANK_DvP_L20', 'OPPRANK_D_L20', 'PROJECTION', 'FINAL', 'COMMENT', 'LINESTARAPP_PROJECTION', 'ROTOWIRE_PROJECTION'
]]

projections
# Out:
#               DATE        SITE  PLAYER_ID       PLAYER_NAME POS TEAM  START  \
# 0       2015-10-27  DRAFTKINGS        138  Anderson Varejao   C  CLE    NaN
# 1       2015-10-27  DRAFTKINGS        196       Earl Barron   C  ATL    NaN
# 2       2015-10-27  DRAFTKINGS        396  Kendrick Perkins   C  NOP    NaN
# 3       2015-10-27  DRAFTKINGS        381     Alexis Ajinca   C  NOP    NaN
# 4       2015-10-27  DRAFTKINGS        211    Tiago Splitter   C  ATL    NaN
# ...            ...         ...        ...               ...  ..  ...    ...
# 238868  2021-05-16  DRAFTKINGS        889    Justin Jackson  PF  MIL    0.0
# 238869  2021-05-16  DRAFTKINGS       1299      Jordan Nwora  PF  MIL    0.0
# 238870  2021-05-16  DRAFTKINGS       1377         Josh Hall  PF  OKC    1.0
# 238871  2021-05-16  DRAFTKINGS       1207      Nicolo Melli  PF  DAL    0.0
# 238872  2021-05-16  DRAFTKINGS        168      Solomon Hill  PF  ATL    1.0
#
#         SPREAD  TOTAL  OPPRANK_DvP_L20  OPPRANK_D_L20  PROJECTION  FINAL  \
# 0          NaN    NaN              NaN            NaN   13.291550   6.50
# 1          NaN    NaN              NaN            NaN    6.640000   0.00
# 2          NaN    NaN              NaN            NaN   18.150000  16.50
# 3          NaN    NaN              NaN            NaN   15.190000  10.50
# 4          NaN    NaN              NaN            NaN   19.260000  11.00
# ...        ...    ...              ...            ...         ...    ...
# 238868    -7.5  224.5              8.0           12.0    0.000000  18.50
# 238869    -7.5  224.5              8.0           12.0    0.000000  59.50
# 238870     8.0  220.5             19.0            4.0   10.515493  41.00
# 238871    -7.5  230.0             25.0           25.0    8.550000  22.25
# 238872    -7.5  232.0             28.0           29.0   21.667275  22.75
#
#        COMMENT  LINESTARAPP_PROJECTION  ROTOWIRE_PROJECTION
# 0                                21.01            13.291550
# 1          NaN                    6.64                  NaN
# 2                                18.15                  NaN
# 3                                15.19                  NaN
# 4                                19.26                  NaN
# ...        ...                     ...                  ...
# 238868                            0.00                  NaN
# 238869                            0.00             0.000000
# 238870                            7.53            10.515493
# 238871                            8.55                  NaN
# 238872                           14.17            21.667275
#
# [225899 rows x 16 columns]

# %%
salaries = linestarapp_data.merge(
    salary_data,
    left_on=['SITE', 'DATE', 'PLAYER_NAME', 'POS'],
    right_on=['SITE', 'DATE', 'NAME', 'POSITION'],
    how='left',
    suffixes = ('_linestarrapp', '_rotoguru')
)

salaries = salaries.loc[salaries['DATE'].isin(set(boxscore_data['DATE'].unique()))]

salaries['SALARY'] = salaries[['SALARY_linestarrapp', 'SALARY_rotoguru']].min(axis=1)
salaries.loc[salaries['SALARY'] < 3000, 'SALARY'] = 3000
salaries = salaries[['DATE', 'SITE', 'PLAYER_ID', 'PLAYER_NAME', 'POS', 'TEAM', 'SALARY']]

salaries
# Out:
#               DATE        SITE  PLAYER_ID       PLAYER_NAME POS TEAM  SALARY
# 0       2015-10-27  DRAFTKINGS        138  Anderson Varejao   C  CLE  3400.0
# 1       2015-10-27  DRAFTKINGS        196       Earl Barron   C  ATL  3000.0
# 2       2015-10-27  DRAFTKINGS        396  Kendrick Perkins   C  NOP  3000.0
# 3       2015-10-27  DRAFTKINGS        381     Alexis Ajinca   C  NOP  3500.0
# 4       2015-10-27  DRAFTKINGS        211    Tiago Splitter   C  ATL  4500.0
# ...            ...         ...        ...               ...  ..  ...     ...
# 238868  2021-05-16  DRAFTKINGS        889    Justin Jackson  PF  MIL  3000.0
# 238869  2021-05-16  DRAFTKINGS       1299      Jordan Nwora  PF  MIL  3000.0
# 238870  2021-05-16  DRAFTKINGS       1377         Josh Hall  PF  OKC  3000.0
# 238871  2021-05-16  DRAFTKINGS       1207      Nicolo Melli  PF  DAL  3000.0
# 238872  2021-05-16  DRAFTKINGS        168      Solomon Hill  PF  ATL  3000.0
#
# [225899 rows x 7 columns]

# %%
df = projections.merge(
    salaries,
    on=['DATE', 'SITE', 'PLAYER_ID', 'PLAYER_NAME', 'POS', 'TEAM'],
    how='left'
)

season_dates = boxscore_data[['SEASON', 'DATE']].drop_duplicates()
df = df.merge(
    season_dates,
    on=['DATE'],
    how='left'
)
df = df.dropna(subset=['START'])

df = df.dropna(subset=['SALARY'])
df = df.loc[
    (df['PROJECTION'] != 0) |
    (df['COMMENT'] == '') |
    (df['COMMENT'].str.contains('coach', case=False))
]

pd.set_option('display.max_columns', None)
df[[
    'SEASON', 'DATE', 'PLAYER_ID', 'PLAYER_NAME', 'TEAM', 'POS', 'SALARY', 'START',
    'SPREAD', 'TOTAL', 'OPPRANK_DvP_L20', 'OPPRANK_D_L20', 'PROJECTION', 'FINAL', 'COMMENT'
]].sort_values(by=['DATE', 'SALARY'], ascending=[True, False])
# Out:
#          SEASON        DATE  PLAYER_ID     PLAYER_NAME TEAM    POS   SALARY  \
# 73139   2017-18  2017-10-17        126    LeBron James  CLE  SF/PF  10200.0
# 73152   2017-18  2017-10-17        425    James Harden  HOU     SG  10000.0
# 73140   2017-18  2017-10-17        535    Kevin Durant  GSW  SF/PF   9600.0
# 73161   2017-18  2017-10-17        296   Stephen Curry  GSW     PG   8800.0
# 73162   2017-18  2017-10-17        125    Kyrie Irving  BOS     PG   8300.0
# ...         ...         ...        ...             ...  ...    ...      ...
# 225894  2020-21  2021-05-16        889  Justin Jackson  MIL     PF   3000.0
# 225895  2020-21  2021-05-16       1299    Jordan Nwora  MIL     PF   3000.0
# 225896  2020-21  2021-05-16       1377       Josh Hall  OKC     PF   3000.0
# 225897  2020-21  2021-05-16       1207    Nicolo Melli  DAL     PF   3000.0
# 225898  2020-21  2021-05-16        168    Solomon Hill  ATL     PF   3000.0
#
#         START  SPREAD  TOTAL  OPPRANK_DvP_L20  OPPRANK_D_L20  PROJECTION  \
# 73139     1.0    -4.5  216.0             30.0           19.0   50.203012
# 73152     1.0     9.5  230.5             22.0            9.0   50.292245
# 73140     1.0    -9.5  230.5             27.0           29.0   53.035150
# 73161     1.0    -9.5  230.5             29.0           29.0   49.960242
# 73162     1.0     4.5  216.0             13.0           14.0   42.549822
# ...       ...     ...    ...              ...            ...         ...
# 225894    0.0    -7.5  224.5              8.0           12.0    0.000000
# 225895    0.0    -7.5  224.5              8.0           12.0    0.000000
# 225896    1.0     8.0  220.5             19.0            4.0   10.515493
# 225897    0.0    -7.5  230.0             25.0           25.0    8.550000
# 225898    1.0    -7.5  232.0             28.0           29.0   21.667275
#
#         FINAL COMMENT
# 73139   66.50
# 73152   55.00
# 73140   41.75
# 73161   36.75
# 73162   50.50
# ...       ...     ...
# 225894  18.50
# 225895  59.50
# 225896  41.00
# 225897  22.25
# 225898  22.75
#
# [114484 rows x 15 columns]

# %%
from pyNBA.Models.features import FeatureCreation

feature_creation = FeatureCreation()

df['PROJECTION_DIFF'] = (df['ROTOWIRE_PROJECTION'] - df['LINESTARAPP_PROJECTION']).abs()
df.loc[
    (df['ROTOWIRE_PROJECTION'] == 0) |
    (df['LINESTARAPP_PROJECTION'] == 0),
    'PROJECTION_DIFF'
] = np.nan

df = feature_creation.expanding_mean(
    df=df, group_col_names=['SEASON', 'PLAYER_ID', 'TEAM', 'START'], col_name='SALARY', new_col_name='AVG_SALARY'
)
df = feature_creation.lag(
    df=df, group_col_names=['SEASON', 'PLAYER_ID', 'TEAM', 'START'], col_name='SALARY', new_col_name='L1_SALARY', n_shift=1
)
df['SALARY_CHANGE'] = df['SALARY'] - df['L1_SALARY']

df = feature_creation.expanding_mean(
    df=df, group_col_names=['SEASON', 'PLAYER_ID', 'TEAM', 'START'], col_name='PROJECTION', new_col_name='AVG_PROJECTION'
)
df = feature_creation.lag(
    df=df, group_col_names=['SEASON', 'PLAYER_ID', 'TEAM', 'START'], col_name='PROJECTION', new_col_name='L1_PROJECTION', n_shift=1
)
df['PROJECTION_CHANGE'] = df['PROJECTION'] - df['L1_PROJECTION']

df = feature_creation.expanding_standard_deviation(
    df=df, group_col_names=['SEASON', 'PLAYER_ID', 'TEAM', 'START'], col_name='FINAL', new_col_name='STD_FP', min_periods=5
)

df = feature_creation.expanding_min(
    df=df, group_col_names=['SEASON', 'PLAYER_ID', 'TEAM', 'START'], col_name='FINAL', new_col_name='MIN_FP'
)
df = feature_creation.expanding_max(
    df=df, group_col_names=['SEASON', 'PLAYER_ID', 'TEAM', 'START'], col_name='FINAL', new_col_name='MAX_FP'
)

df['ABS_RES'] = (df['PROJECTION'] - df['FINAL']).abs()
df = feature_creation.expanding_mean(
    df=df, group_col_names=['SEASON', 'PLAYER_ID', 'TEAM', 'START'], col_name='ABS_RES', new_col_name='AVG_ABS_RES'
)
df = feature_creation.lag(
    df=df, group_col_names=['SEASON', 'PLAYER_ID', 'TEAM', 'START'], col_name='ABS_RES', new_col_name='L1_ABS_RES', n_shift=1
)

df['GP'] = 1
df = feature_creation.expanding_sum(
    df=df, group_col_names=['SEASON', 'PLAYER_ID', 'TEAM'], col_name='GP', new_col_name='COUNT_GP'
)
df = feature_creation.expanding_sum(
    df=df, group_col_names=['SEASON', 'PLAYER_ID', 'TEAM'], col_name='START', new_col_name='COUNT_START'
)
df['PCT_IN_ROLE'] = np.nan
df.loc[df['START'] == 1, 'PCT_IN_ROLE'] = df['COUNT_START']/df['COUNT_GP']
df.loc[df['START'] == 0, 'PCT_IN_ROLE'] = 1 - (df['COUNT_START']/df['COUNT_GP'])

# %%
regressors = [
    'PROJECTION_DIFF', 'SALARY', 'AVG_SALARY', 'SALARY_CHANGE', 'PROJECTION', 'AVG_PROJECTION', 'PROJECTION_CHANGE',
    'STD_FP', 'MIN_FP', 'MAX_FP', 'AVG_ABS_RES', 'L1_ABS_RES', 'START', 'COUNT_GP', 'PCT_IN_ROLE'
]
y = 'ABS_RES'

# %%
import xgboost as xgb
from catboost import CatBoostRegressor, Pool
from sklearn.model_selection import GridSearchCV, train_test_split, KFold
from sklearn.feature_selection import SelectFromModel, RFE
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

models = [
    xgb.XGBRegressor(objective='reg:squarederror', eval_metric='mae', learning_rate=0.1, n_estimators=500, tree_method='hist'),
    CatBoostRegressor(eval_metric='MAE', learning_rate=0.1, n_estimators=500, silent=True)
    
]

min_score = float('inf')
best_model = None
for model in models:
      
    # feature selection
    X = df[regressors]
    Y = df[y]

    model.fit(X, Y)

    # importance
    importance_selector = SelectFromModel(model, threshold='0.75*median')
    importance_selector = importance_selector.fit(X, Y)
    importance_support = importance_selector.get_support()

    # rank
    rank_selector = RFE(model)
    rank_selector = rank_selector.fit(X, Y)
    rank_support = rank_selector.ranking_
    median_rank = np.median(rank_support)

    selected_features = []
    for feature, importance_flag, rank in zip(list(X.columns), importance_support, rank_support):
        # select the feature if it's important, or has a low rank
        if importance_flag or (rank <= median_rank):
            selected_features.append(feature)

    X = df[selected_features].values
    Y = df[y].values

    # cross validation
    scores = []
    cv = KFold(n_splits=5, shuffle=True)
    for train, test in cv.split(X, Y):
        prediction = model.fit(X[train], Y[train]).predict(X[test])
        true = Y[test]

        scores.append(mean_absolute_error(prediction, true))

    mean_score = np.mean(scores)
    print('\nModel:', model)
    print('Selected Features:', selected_features)
    print('Mean MAE:', mean_score)
    if mean_score < min_score:
        min_score = mean_score
        best_model = (model, selected_features)

print()
print(best_model, min_score)
# Out:
# Model: XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, eval_metric='mae', gamma=0,
#              gpu_id=-1, importance_type='gain', interaction_constraints='',
#              learning_rate=0.1, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=500, n_jobs=1, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='hist', validate_parameters=1, verbosity=None)
# Selected Features: ['PROJECTION_DIFF', 'SALARY', 'AVG_SALARY', 'SALARY_CHANGE', 'PROJECTION', 'AVG_PROJECTION', 'PROJECTION_CHANGE', 'STD_FP', 'MIN_FP', 'MAX_FP', 'AVG_ABS_RES', 'L1_ABS_RES', 'START', 'COUNT_GP', 'PCT_IN_ROLE']
# Mean MAE: 4.322750794253225
#
# Model: <catboost.core.CatBoostRegressor object at 0x7f9d887d28e0>
# Selected Features: ['PROJECTION_DIFF', 'SALARY', 'AVG_SALARY', 'SALARY_CHANGE', 'PROJECTION', 'AVG_PROJECTION', 'PROJECTION_CHANGE', 'STD_FP', 'MIN_FP', 'MAX_FP', 'AVG_ABS_RES', 'L1_ABS_RES', 'COUNT_GP']
# Mean MAE: 4.289105311127981
#
# (<catboost.core.CatBoostRegressor object at 0x7f9d887d28e0>, ['PROJECTION_DIFF', 'SALARY', 'AVG_SALARY', 'SALARY_CHANGE', 'PROJECTION', 'AVG_PROJECTION', 'PROJECTION_CHANGE', 'STD_FP', 'MIN_FP', 'MAX_FP', 'AVG_ABS_RES', 'L1_ABS_RES', 'COUNT_GP']) 4.289105311127981

# %%
selected_features = [
    'PROJECTION_DIFF', 'SALARY', 'AVG_SALARY', 'PROJECTION', 'AVG_PROJECTION', 'PROJECTION_CHANGE',
    'STD_FP', 'MIN_FP', 'MAX_FP', 'AVG_ABS_RES', 'L1_ABS_RES', 'START', 'COUNT_GP', 'PCT_IN_ROLE'
]
X = df[selected_features]
Y = df[y]
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.25, random_state=1)

# %%
model = xgb.XGBRegressor()

model_params = {
    'max_depth': [6, 8, 10],
    'eta' : [0.01, 0.02, 0.05],
    'subsample': [0.8, 0.9, 1],
    'colsample_bytree': [0.8, 0.9, 1],
    'n_estimators': [2000],
    'eval_metric': ['mae'],
    'tree_method': ['hist']
}

grid = GridSearchCV(estimator=model, param_grid=model_params, scoring='neg_mean_absolute_error', cv=2, n_jobs=-1)

fit_params = {
    "early_stopping_rounds": 25,
    "eval_set": [(X_test, y_test)]
}

grid.fit(X_train, y_train, **fit_params)    

print("\n========================================================")
print(" Results from Grid Search " )
print("========================================================")    

print("\n The best estimator across ALL searched params:\n", grid.best_estimator_)

print("\n The best score across ALL searched params:\n", grid.best_score_)

print("\n The best parameters across ALL searched params:\n", grid.best_params_)

print("\n ========================================================")
# Out:
# [0]	validation_0-mae:6.31583
# [1]	validation_0-mae:6.26342
# [2]	validation_0-mae:6.21211
# [3]	validation_0-mae:6.16197
# [4]	validation_0-mae:6.11266
# [5]	validation_0-mae:6.06471
# [6]	validation_0-mae:6.01778
# [7]	validation_0-mae:5.97185
# [8]	validation_0-mae:5.92712
# [9]	validation_0-mae:5.88340
# [10]	validation_0-mae:5.84056
# [11]	validation_0-mae:5.79882
# [12]	validation_0-mae:5.75816
# [13]	validation_0-mae:5.71835
# [14]	validation_0-mae:5.67946
# [15]	validation_0-mae:5.64130
# [16]	validation_0-mae:5.60406
# [17]	validation_0-mae:5.56764
# [18]	validation_0-mae:5.53223
# [19]	validation_0-mae:5.49748
# [20]	validation_0-mae:5.46347
# [21]	validation_0-mae:5.43039
# [22]	validation_0-mae:5.39787
# [23]	validation_0-mae:5.36624
# [24]	validation_0-mae:5.33536
# [25]	validation_0-mae:5.30517
# [26]	validation_0-mae:5.27559
# [27]	validation_0-mae:5.24684
# [28]	validation_0-mae:5.21870
# [29]	validation_0-mae:5.19132
# [30]	validation_0-mae:5.16463
# [31]	validation_0-mae:5.13849
# [32]	validation_0-mae:5.11289
# [33]	validation_0-mae:5.08791
# [34]	validation_0-mae:5.06352
# [35]	validation_0-mae:5.03967
# [36]	validation_0-mae:5.01636
# [37]	validation_0-mae:4.99379
# [38]	validation_0-mae:4.97161
# [39]	validation_0-mae:4.95003
# [40]	validation_0-mae:4.92901
# [41]	validation_0-mae:4.90834
# [42]	validation_0-mae:4.88830
# [43]	validation_0-mae:4.86861
# [44]	validation_0-mae:4.84934
# [45]	validation_0-mae:4.83066
# [46]	validation_0-mae:4.81244
# [47]	validation_0-mae:4.79459
# [48]	validation_0-mae:4.77736
# [49]	validation_0-mae:4.76035
# [50]	validation_0-mae:4.74369
# [51]	validation_0-mae:4.72752
# [52]	validation_0-mae:4.71177
# [53]	validation_0-mae:4.69641
# [54]	validation_0-mae:4.68134
# [55]	validation_0-mae:4.66672
# [56]	validation_0-mae:4.65252
# [57]	validation_0-mae:4.63863
# [58]	validation_0-mae:4.62504
# [59]	validation_0-mae:4.61182
# [60]	validation_0-mae:4.59888
# [61]	validation_0-mae:4.58627
# [62]	validation_0-mae:4.57404
# [63]	validation_0-mae:4.56219
# [64]	validation_0-mae:4.55056
# [65]	validation_0-mae:4.53926
# [66]	validation_0-mae:4.52820
# [67]	validation_0-mae:4.51745
# [68]	validation_0-mae:4.50689
# [69]	validation_0-mae:4.49666
# [70]	validation_0-mae:4.48663
# [71]	validation_0-mae:4.47689
# [72]	validation_0-mae:4.46741
# [73]	validation_0-mae:4.45826
# [74]	validation_0-mae:4.44923
# [75]	validation_0-mae:4.44055
# [76]	validation_0-mae:4.43199
# [77]	validation_0-mae:4.42373
# [78]	validation_0-mae:4.41574
# [79]	validation_0-mae:4.40787
# [80]	validation_0-mae:4.40023
# [81]	validation_0-mae:4.39277
# [82]	validation_0-mae:4.38551
# [83]	validation_0-mae:4.37850
# [84]	validation_0-mae:4.37180
# [85]	validation_0-mae:4.36511
# [86]	validation_0-mae:4.35874
# [87]	validation_0-mae:4.35243
# [88]	validation_0-mae:4.34637
# [89]	validation_0-mae:4.34043
# [90]	validation_0-mae:4.33476
# [91]	validation_0-mae:4.32918
# [92]	validation_0-mae:4.32372
# [93]	validation_0-mae:4.31840
# [94]	validation_0-mae:4.31331
# [95]	validation_0-mae:4.30819
# [96]	validation_0-mae:4.30323
# [97]	validation_0-mae:4.29858
# [98]	validation_0-mae:4.29392
# [99]	validation_0-mae:4.28939
# [100]	validation_0-mae:4.28511
# [101]	validation_0-mae:4.28091
# [102]	validation_0-mae:4.27682
# [103]	validation_0-mae:4.27281
# [104]	validation_0-mae:4.26914
# [105]	validation_0-mae:4.26539
# [106]	validation_0-mae:4.26177
# [107]	validation_0-mae:4.25823
# [108]	validation_0-mae:4.25483
# [109]	validation_0-mae:4.25154
# [110]	validation_0-mae:4.24822
# [111]	validation_0-mae:4.24506
# [112]	validation_0-mae:4.24213
# [113]	validation_0-mae:4.23920
# [114]	validation_0-mae:4.23641
# [115]	validation_0-mae:4.23368
# [116]	validation_0-mae:4.23100
# [117]	validation_0-mae:4.22844
# [118]	validation_0-mae:4.22604
# [119]	validation_0-mae:4.22370
# [120]	validation_0-mae:4.22138
# [121]	validation_0-mae:4.21910
# [122]	validation_0-mae:4.21693
# [123]	validation_0-mae:4.21482
# [124]	validation_0-mae:4.21285
# [125]	validation_0-mae:4.21092
# [126]	validation_0-mae:4.20914
# [127]	validation_0-mae:4.20735
# [128]	validation_0-mae:4.20565
# [129]	validation_0-mae:4.20397
# [130]	validation_0-mae:4.20233
# [131]	validation_0-mae:4.20072
# [132]	validation_0-mae:4.19926
# [133]	validation_0-mae:4.19785
# [134]	validation_0-mae:4.19647
# [135]	validation_0-mae:4.19521
# [136]	validation_0-mae:4.19393
# [137]	validation_0-mae:4.19273
# [138]	validation_0-mae:4.19162
# [139]	validation_0-mae:4.19054
# [140]	validation_0-mae:4.18945
# [141]	validation_0-mae:4.18850
# [142]	validation_0-mae:4.18761
# [143]	validation_0-mae:4.18665
# [144]	validation_0-mae:4.18580
# [145]	validation_0-mae:4.18494
# [146]	validation_0-mae:4.18421
# [147]	validation_0-mae:4.18349
# [148]	validation_0-mae:4.18285
# [149]	validation_0-mae:4.18219
# [150]	validation_0-mae:4.18159
# [151]	validation_0-mae:4.18105
# [152]	validation_0-mae:4.18050
# [153]	validation_0-mae:4.18002
# [154]	validation_0-mae:4.17961
# [155]	validation_0-mae:4.17923
# [156]	validation_0-mae:4.17886
# [157]	validation_0-mae:4.17852
# [158]	validation_0-mae:4.17827
# [159]	validation_0-mae:4.17790
# [160]	validation_0-mae:4.17765
# [161]	validation_0-mae:4.17736
# [162]	validation_0-mae:4.17716
# [163]	validation_0-mae:4.17702
# [164]	validation_0-mae:4.17683
# [165]	validation_0-mae:4.17662
# [166]	validation_0-mae:4.17659
# [167]	validation_0-mae:4.17654
# [168]	validation_0-mae:4.17643
# [169]	validation_0-mae:4.17635
# [170]	validation_0-mae:4.17624
# [171]	validation_0-mae:4.17621
# [172]	validation_0-mae:4.17619
# [173]	validation_0-mae:4.17619
# [174]	validation_0-mae:4.17622
# [175]	validation_0-mae:4.17626
# [176]	validation_0-mae:4.17630
# [177]	validation_0-mae:4.17637
# [178]	validation_0-mae:4.17645
# [179]	validation_0-mae:4.17656
# [180]	validation_0-mae:4.17671
# [181]	validation_0-mae:4.17687
# [182]	validation_0-mae:4.17708
# [183]	validation_0-mae:4.17734
# [184]	validation_0-mae:4.17752
# [185]	validation_0-mae:4.17769
# [186]	validation_0-mae:4.17791
# [187]	validation_0-mae:4.17810
# [188]	validation_0-mae:4.17835
# [189]	validation_0-mae:4.17867
# [190]	validation_0-mae:4.17899
# [191]	validation_0-mae:4.17932
# [192]	validation_0-mae:4.17958
# [193]	validation_0-mae:4.17984
# [194]	validation_0-mae:4.18013
# [195]	validation_0-mae:4.18046
# [196]	validation_0-mae:4.18078
#
# ========================================================
#  Results from Grid Search
# ========================================================
#
#  The best estimator across ALL searched params:
#  XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, eta=0.01,
#              eval_metric='mae', gamma=0, gpu_id=-1, importance_type='gain',
#              interaction_constraints='', learning_rate=0.00999999978,
#              max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=2000, n_jobs=1,
#              num_parallel_tree=1, random_state=0, reg_alpha=0, reg_lambda=1,
#              scale_pos_weight=1, subsample=0.8, tree_method='hist',
#              validate_parameters=1, verbosity=None)
#
#  The best score across ALL searched params:
#  -4.19777550311665
#
#  The best parameters across ALL searched params:
#  {'colsample_bytree': 1, 'eta': 0.01, 'eval_metric': 'mae', 'max_depth': 6, 'n_estimators': 2000, 'subsample': 0.8, 'tree_method': 'hist'}
#
#  ========================================================

# %%
best_params = grid.best_params_
model = xgb.XGBRegressor(**best_params)

model.fit(X_train, y_train, **fit_params)

y_hat = model.predict(X_test)
# Out:
# [0]	validation_0-mae:6.31583
# [1]	validation_0-mae:6.26342
# [2]	validation_0-mae:6.21211
# [3]	validation_0-mae:6.16197
# [4]	validation_0-mae:6.11266
# [5]	validation_0-mae:6.06471
# [6]	validation_0-mae:6.01778
# [7]	validation_0-mae:5.97185
# [8]	validation_0-mae:5.92712
# [9]	validation_0-mae:5.88340
# [10]	validation_0-mae:5.84056
# [11]	validation_0-mae:5.79882
# [12]	validation_0-mae:5.75816
# [13]	validation_0-mae:5.71835
# [14]	validation_0-mae:5.67946
# [15]	validation_0-mae:5.64130
# [16]	validation_0-mae:5.60406
# [17]	validation_0-mae:5.56764
# [18]	validation_0-mae:5.53223
# [19]	validation_0-mae:5.49748
# [20]	validation_0-mae:5.46347
# [21]	validation_0-mae:5.43039
# [22]	validation_0-mae:5.39787
# [23]	validation_0-mae:5.36624
# [24]	validation_0-mae:5.33536
# [25]	validation_0-mae:5.30517
# [26]	validation_0-mae:5.27559
# [27]	validation_0-mae:5.24684
# [28]	validation_0-mae:5.21870
# [29]	validation_0-mae:5.19132
# [30]	validation_0-mae:5.16463
# [31]	validation_0-mae:5.13849
# [32]	validation_0-mae:5.11289
# [33]	validation_0-mae:5.08791
# [34]	validation_0-mae:5.06352
# [35]	validation_0-mae:5.03967
# [36]	validation_0-mae:5.01636
# [37]	validation_0-mae:4.99379
# [38]	validation_0-mae:4.97161
# [39]	validation_0-mae:4.95003
# [40]	validation_0-mae:4.92901
# [41]	validation_0-mae:4.90834
# [42]	validation_0-mae:4.88830
# [43]	validation_0-mae:4.86861
# [44]	validation_0-mae:4.84934
# [45]	validation_0-mae:4.83066
# [46]	validation_0-mae:4.81244
# [47]	validation_0-mae:4.79459
# [48]	validation_0-mae:4.77736
# [49]	validation_0-mae:4.76035
# [50]	validation_0-mae:4.74369
# [51]	validation_0-mae:4.72752
# [52]	validation_0-mae:4.71177
# [53]	validation_0-mae:4.69641
# [54]	validation_0-mae:4.68134
# [55]	validation_0-mae:4.66672
# [56]	validation_0-mae:4.65252
# [57]	validation_0-mae:4.63863
# [58]	validation_0-mae:4.62504
# [59]	validation_0-mae:4.61182
# [60]	validation_0-mae:4.59888
# [61]	validation_0-mae:4.58627
# [62]	validation_0-mae:4.57404
# [63]	validation_0-mae:4.56219
# [64]	validation_0-mae:4.55056
# [65]	validation_0-mae:4.53926
# [66]	validation_0-mae:4.52820
# [67]	validation_0-mae:4.51745
# [68]	validation_0-mae:4.50689
# [69]	validation_0-mae:4.49666
# [70]	validation_0-mae:4.48663
# [71]	validation_0-mae:4.47689
# [72]	validation_0-mae:4.46741
# [73]	validation_0-mae:4.45826
# [74]	validation_0-mae:4.44923
# [75]	validation_0-mae:4.44055
# [76]	validation_0-mae:4.43199
# [77]	validation_0-mae:4.42373
# [78]	validation_0-mae:4.41574
# [79]	validation_0-mae:4.40787
# [80]	validation_0-mae:4.40023
# [81]	validation_0-mae:4.39277
# [82]	validation_0-mae:4.38551
# [83]	validation_0-mae:4.37850
# [84]	validation_0-mae:4.37180
# [85]	validation_0-mae:4.36511
# [86]	validation_0-mae:4.35874
# [87]	validation_0-mae:4.35243
# [88]	validation_0-mae:4.34637
# [89]	validation_0-mae:4.34043
# [90]	validation_0-mae:4.33476
# [91]	validation_0-mae:4.32918
# [92]	validation_0-mae:4.32372
# [93]	validation_0-mae:4.31840
# [94]	validation_0-mae:4.31331
# [95]	validation_0-mae:4.30819
# [96]	validation_0-mae:4.30323
# [97]	validation_0-mae:4.29858
# [98]	validation_0-mae:4.29392
# [99]	validation_0-mae:4.28939
# [100]	validation_0-mae:4.28511
# [101]	validation_0-mae:4.28091
# [102]	validation_0-mae:4.27682
# [103]	validation_0-mae:4.27281
# [104]	validation_0-mae:4.26914
# [105]	validation_0-mae:4.26539
# [106]	validation_0-mae:4.26177
# [107]	validation_0-mae:4.25823
# [108]	validation_0-mae:4.25483
# [109]	validation_0-mae:4.25154
# [110]	validation_0-mae:4.24822
# [111]	validation_0-mae:4.24506
# [112]	validation_0-mae:4.24213
# [113]	validation_0-mae:4.23920
# [114]	validation_0-mae:4.23641
# [115]	validation_0-mae:4.23368
# [116]	validation_0-mae:4.23100
# [117]	validation_0-mae:4.22844
# [118]	validation_0-mae:4.22604
# [119]	validation_0-mae:4.22370
# [120]	validation_0-mae:4.22138
# [121]	validation_0-mae:4.21910
# [122]	validation_0-mae:4.21693
# [123]	validation_0-mae:4.21482
# [124]	validation_0-mae:4.21285
# [125]	validation_0-mae:4.21092
# [126]	validation_0-mae:4.20914
# [127]	validation_0-mae:4.20735
# [128]	validation_0-mae:4.20565
# [129]	validation_0-mae:4.20397
# [130]	validation_0-mae:4.20233
# [131]	validation_0-mae:4.20072
# [132]	validation_0-mae:4.19926
# [133]	validation_0-mae:4.19785
# [134]	validation_0-mae:4.19647
# [135]	validation_0-mae:4.19521
# [136]	validation_0-mae:4.19393
# [137]	validation_0-mae:4.19273
# [138]	validation_0-mae:4.19162
# [139]	validation_0-mae:4.19054
# [140]	validation_0-mae:4.18945
# [141]	validation_0-mae:4.18850
# [142]	validation_0-mae:4.18761
# [143]	validation_0-mae:4.18665
# [144]	validation_0-mae:4.18580
# [145]	validation_0-mae:4.18494
# [146]	validation_0-mae:4.18421
# [147]	validation_0-mae:4.18349
# [148]	validation_0-mae:4.18285
# [149]	validation_0-mae:4.18219
# [150]	validation_0-mae:4.18159
# [151]	validation_0-mae:4.18105
# [152]	validation_0-mae:4.18050
# [153]	validation_0-mae:4.18002
# [154]	validation_0-mae:4.17961
# [155]	validation_0-mae:4.17923
# [156]	validation_0-mae:4.17886
# [157]	validation_0-mae:4.17852
# [158]	validation_0-mae:4.17827
# [159]	validation_0-mae:4.17790
# [160]	validation_0-mae:4.17765
# [161]	validation_0-mae:4.17736
# [162]	validation_0-mae:4.17716
# [163]	validation_0-mae:4.17702
# [164]	validation_0-mae:4.17683
# [165]	validation_0-mae:4.17662
# [166]	validation_0-mae:4.17659
# [167]	validation_0-mae:4.17654
# [168]	validation_0-mae:4.17643
# [169]	validation_0-mae:4.17635
# [170]	validation_0-mae:4.17624
# [171]	validation_0-mae:4.17621
# [172]	validation_0-mae:4.17619
# [173]	validation_0-mae:4.17619
# [174]	validation_0-mae:4.17622
# [175]	validation_0-mae:4.17626
# [176]	validation_0-mae:4.17630
# [177]	validation_0-mae:4.17637
# [178]	validation_0-mae:4.17645
# [179]	validation_0-mae:4.17656
# [180]	validation_0-mae:4.17671
# [181]	validation_0-mae:4.17687
# [182]	validation_0-mae:4.17708
# [183]	validation_0-mae:4.17734
# [184]	validation_0-mae:4.17752
# [185]	validation_0-mae:4.17769
# [186]	validation_0-mae:4.17791
# [187]	validation_0-mae:4.17810
# [188]	validation_0-mae:4.17835
# [189]	validation_0-mae:4.17867
# [190]	validation_0-mae:4.17899
# [191]	validation_0-mae:4.17932
# [192]	validation_0-mae:4.17958
# [193]	validation_0-mae:4.17984
# [194]	validation_0-mae:4.18013
# [195]	validation_0-mae:4.18046
# [196]	validation_0-mae:4.18078
# [197]	validation_0-mae:4.18110

# %%
feature_importances = model.feature_importances_
feature_importance_df = pd.DataFrame({'Importance': feature_importances, 'Feature': selected_features})
feature_importance_df = feature_importance_df.sort_values(by='Importance')
feature_importance_df.plot.bar(x='Feature', y='Importance', figsize=(12, 8))
# Out:
# <AxesSubplot:xlabel='Feature'>

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

y_avg = df.loc[X_test.index, 'AVG_ABS_RES'].fillna(df['ABS_RES'])

# Kpi
print("R2 (explained variance):")
print("Model:", round(r2_score(y_test, y_hat), 3))
print("Baseline:", round(r2_score(y_test, y_avg), 3))

print("\nMean Absolute Error (Σ|y-pred|/n):")
print("Model:", round(mean_absolute_error(y_test, y_hat), 6))
print("Baseline:", round(mean_absolute_error(y_test, y_avg), 6))

print("\nRoot Mean Squared Error (sqrt(Σ(y-pred)^2/n)):")
print("Model:", round(np.sqrt(mean_squared_error(y_test, y_hat)), 6))
print("Baseline:", round(np.sqrt(mean_squared_error(y_test, y_avg)), 6))
# Out:
# R2 (explained variance):
# Model: 0.113
# Baseline: 0.067
#
# Mean Absolute Error (Σ|y-pred|/n):
# Model: 4.176183
# Baseline: 4.37939
#
# Root Mean Squared Error (sqrt(Σ(y-pred)^2/n)):
# Model: 5.828942
# Baseline: 5.977438

# %%
import matplotlib.pyplot as plt

residuals = y_test - y_hat

# plot predicted vs true
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(18, 10))
ax[0].scatter(y_hat, y_test)
ax[0].grid(True)
ax[0].set(xlabel="Predicted", ylabel="True", title="Predicted vs True")
ax[0].legend()
    
# plot predicted vs residuals
ax[1].scatter(y_hat, residuals)
ax[1].grid(True)
ax[1].set(xlabel="Predicted", ylabel="Residuals", title="Predicted vs Residuals")
ax[1].hlines(y=0, xmin=np.min(y_hat), xmax=np.max(y_hat))
ax[1].legend()
plt.show()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
temp = df.copy()
temp.loc[X_test.index, 'ABS_RES_HAT'] = y_hat
temp.sort_values(by='ABS_RES_HAT', ascending=False)
# Out:
#               SITE  PLAYER_ID             PLAYER_NAME        DATE    POS TEAM  \
# 19190   DRAFTKINGS        178   Giannis Antetokounmpo  2018-02-04  SF/PF  MIL
# 33639   DRAFTKINGS        549       Russell Westbrook  2018-11-05     PG  OKC
# 62001   DRAFTKINGS        512      Karl-Anthony Towns  2019-10-30      C  MIN
# 31403   DRAFTKINGS        425            James Harden  2018-10-24  PG/SG  HOU
# 25000   DRAFTKINGS        175            Myles Turner  2018-03-15      C  IND
# ...            ...        ...                     ...         ...    ...  ...
# 114478  DRAFTKINGS         43  Thanasis Antetokounmpo  2021-05-16     PF  MIL
# 114479  DRAFTKINGS        889          Justin Jackson  2021-05-16     PF  MIL
# 114481  DRAFTKINGS       1377               Josh Hall  2021-05-16     PF  OKC
# 114482  DRAFTKINGS       1207            Nicolo Melli  2021-05-16     PF  DAL
# 114483  DRAFTKINGS        168            Solomon Hill  2021-05-16     PF  ATL
#
#         START  SPREAD  TOTAL  OPPRANK_DvP_L20  OPPRANK_D_L20  PROJECTION  \
# 19190     1.0    -4.5  207.0             30.0           18.0   54.980000
# 33639     1.0    -3.5  235.5             27.0           27.0   58.800000
# 62001     1.0     7.0  222.5              1.0            2.0   54.360000
# 31403     1.0    -1.0  217.0             30.0            3.0   61.250000
# 25000     1.0     4.0  212.5             16.0            4.0   33.880000
# ...       ...     ...    ...              ...            ...         ...
# 114478    0.0    -7.5  224.5              8.0           12.0    1.709422
# 114479    0.0    -7.5  224.5              8.0           12.0    0.000000
# 114481    1.0     8.0  220.5             19.0            4.0   10.515493
# 114482    0.0    -7.5  230.0             25.0           25.0    8.550000
# 114483    1.0    -7.5  232.0             28.0           29.0   21.667275
#
#         FINAL COMMENT  LINESTARAPP_PROJECTION  ROTOWIRE_PROJECTION   SALARY  \
# 19190   33.50                           54.98             0.000000  11300.0
# 33639   38.25                           58.80             0.000000  11100.0
# 62001   28.00                           54.36             0.000000   9900.0
# 31403   45.75                           61.25             0.000000  11400.0
# 25000    5.50                           33.88             0.000000   6500.0
# ...       ...     ...                     ...                  ...      ...
# 114478   4.25                            3.28             1.709422   3000.0
# 114479  18.50                            0.00                  NaN   3000.0
# 114481  41.00                            7.53            10.515493   3000.0
# 114482  22.25                            8.55                  NaN   3000.0
# 114483  22.75                           14.17            21.667275   3000.0
#
#          SEASON  PROJECTION_DIFF    AVG_SALARY  L1_SALARY  SALARY_CHANGE  \
# 19190   2017-18        54.980000  11000.000000    10800.0          500.0
# 33639   2018-19        58.800000  10633.333333    10900.0          200.0
# 62001   2019-20        54.360000  10333.333333    10100.0         -200.0
# 31403   2018-19        61.250000  11333.333333    11200.0          200.0
# 25000   2017-18        33.880000   6522.000000     6200.0          300.0
# ...         ...              ...           ...        ...            ...
# 114478  2020-21         1.570577   3086.956522     3000.0            0.0
# 114479  2020-21              NaN   3000.000000     3000.0            0.0
# 114481  2020-21         2.985493           NaN        NaN            NaN
# 114482  2020-21              NaN   3083.333333     3000.0            0.0
# 114483  2020-21         7.497275   3620.000000     3000.0            0.0
#
#         AVG_PROJECTION  L1_PROJECTION  PROJECTION_CHANGE     STD_FP  MIN_FP  \
# 19190     5.028189e+01      51.500970           3.479030  10.057518   32.00
# 33639     5.605192e+01      55.093262           3.706738   6.374591   42.75
# 62001     5.438157e+01      52.151855           2.208145        NaN   51.25
# 31403     5.985693e+01      62.349815          -1.099815        NaN   53.25
# 25000     3.452742e+01      36.286322          -2.406322  11.864563    0.00
# ...                ...            ...                ...        ...     ...
# 114478    5.219907e+00       0.000000           1.709422   6.152905   -0.50
# 114479    1.065814e-14       0.000000           0.000000   0.000000    0.00
# 114481             NaN            NaN                NaN        NaN     NaN
# 114482    5.800833e+00       5.380000           3.170000   6.365162    0.00
# 114483    1.793077e+01       9.000190          12.667085   7.100344    7.25
#
#         MAX_FP    ABS_RES   AVG_ABS_RES  L1_ABS_RES  GP  COUNT_GP  \
# 19190    78.25  21.480000  8.786563e+00    5.249030   1      47.0
# 33639    60.00  20.550000  6.267849e+00    1.343262   1       6.0
# 62001    82.25  26.360000  1.521967e+01    0.901855   1       3.0
# 31403    63.00  15.500000  2.290382e+00    0.650185   1       3.0
# 25000    51.00  28.380000  1.043659e+01    1.786322   1      53.0
# ...        ...        ...           ...         ...  ..       ...
# 114478   23.75   2.540578  4.301205e+00    1.500000   1      71.0
# 114479    0.00  18.500000  3.552714e-15    0.000000   1       8.0
# 114481     NaN  30.484507           NaN         NaN   1      30.0
# 114482   19.00  13.700000  5.788750e+00    7.620000   1      28.0
# 114483   30.75   1.082725  4.751685e+00    1.500190   1      71.0
#
#         COUNT_START  PCT_IN_ROLE  ABS_RES_HAT
# 19190          47.0     1.000000    18.821081
# 33639           6.0     1.000000    18.240183
# 62001           3.0     1.000000    18.043552
# 31403           3.0     1.000000    17.732241
# 25000          50.0     0.943396    17.588261
# ...             ...          ...          ...
# 114478          2.0     0.971831          NaN
# 114479          0.0     1.000000          NaN
# 114481          0.0     0.000000          NaN
# 114482          4.0     0.857143          NaN
# 114483         15.0     0.211268          NaN
#
# [114484 rows x 36 columns]

# %%
temp = df.copy()
temp = temp.loc[
    ((temp['LINESTARAPP_PROJECTION'] == 0) | (temp['ROTOWIRE_PROJECTION'] == 0)) &
    (temp['FINAL'] != 0)
]
temp[['DATE', 'PLAYER_NAME', 'LINESTARAPP_PROJECTION', 'ROTOWIRE_PROJECTION', 'FINAL']]

# %%
temp = df.copy()
temp2 = temp.loc[
    (temp['LINESTARAPP_PROJECTION'] == 0) &
    (temp['ROTOWIRE_PROJECTION'] != 0)
]
print(len(temp2.loc[temp2['FINAL'] != 0]), len(temp2.loc[temp2['FINAL'] == 0]))

# %%
temp = df.copy()
temp2 = temp.loc[
    (temp['LINESTARAPP_PROJECTION'] != 0) &
    (temp['ROTOWIRE_PROJECTION'] == 0)
]
print(len(temp2.loc[temp2['FINAL'] != 0]), len(temp2.loc[temp2['FINAL'] == 0]))
