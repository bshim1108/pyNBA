# %%
import numba
from numba.typed import List

@numba.vectorize(nopython=True)
def double_every_value_withnumba(x):  # noqa E501
    return x

# %%
import pandas as pd
import numpy as np

a = pd.DataFrame({'a': 1}, index = [i for i in range(100)])
a['a'] = [List()] * len(a)
a['a'] = double_every_value_withnumba(a['a'].to_numpy())
# Out:
# ---------------------------------------------------------------------------
# TypingError                               Traceback (most recent call last)
# <ipython-input-22-48594ec10f16> in <module>
#       4 a = pd.DataFrame({'a': 1}, index = [i for i in range(100)])
#       5 a['a'] = [[]] * len(a)
# ----> 6 a['a'] = double_every_value_withnumba(a['a'].to_numpy())
#
# ~/Projects/pyNBA/venv/lib/python3.7/site-packages/numba/np/ufunc/dufunc.py in _compile_for_args(self, *args, **kws)
#     191                 argty = numpy_support.map_arrayscalar_type(arg)
#     192             argtys.append(argty)
# --> 193         return self._compile_for_argtys(tuple(argtys))
#     194
#     195     def _compile_for_argtys(self, argtys, return_type=None):
#
# ~/Projects/pyNBA/venv/lib/python3.7/site-packages/numba/np/ufunc/dufunc.py in _compile_for_argtys(self, argtys, return_type)
#     209             sig = return_type(*argtys)
# ...
