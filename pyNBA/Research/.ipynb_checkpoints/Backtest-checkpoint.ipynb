# %% [markdown]
# # Backtest
# In this section, I will backtest an investment strategy that enters Draftkings DFS contests based on my player statistic projections. I *temporarily* limit the backtest to Draftkings contests due to the current lack of data on the historical results of DFS contests on other sites. The methods that determine which contests I will enter and the lineups that enter each contest will be explored in this notebook.

# %% [markdown]
# ## Setup
#
# Import the necessary libraries.

# %%
# for data
from pyNBA.Data.constants import ROTO_NAME_TO_NBA_NAME, DB_TEAM_TO_NBA_TEAM, BAD_CONTEST_SUBSTRINGS, OWNERSHIP_NAME_TO_NBA_NAME
from pyNBA.Data.data import QueryData
from pyNBA.Models.helpers import CleanData
import pandas as pd
import numpy as np
from numpy.random import normal

# for models
from pyNBA.DFS.rules import FPCalculator
from pyNBA.DFS.constants import Site
from pyNBA.Models.fantasy_points import FPModel
from pyNBA.Models.variance import VarianceModel
from pyNBA.Models.ownership import OwnershipModel
from pyNBA.Models.top_score import TopScoreModel
import pulp
from pydfs_lineup_optimizer.solvers.pulp_solver import PuLPSolver

# for backtesting
from pyNBA.Models.features import FeatureCreation
import time
from pydfs_lineup_optimizer import get_optimizer, Sport
from pydfs_lineup_optimizer import Player
from numpy.random import normal
from numpy.random import choice
import scipy.stats as st

# for plotting
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
# %matplotlib inline
from datetime import datetime
import seaborn as sns; sns.set()

# misc
import warnings
warnings.filterwarnings('ignore')
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %% [markdown]
# ## Data
# Collect all data necessary to perform the backtest.

# %%
query_data = QueryData()
clean_data = CleanData()

# pull boxscore data
boxscores = query_data.query_boxscore_data()

# we are only interested in the boxscores of healthy and non-resting players
boxscores = clean_data.drop_rows_player_injured(boxscores)
boxscores = clean_data.drop_rows_player_rest(boxscores)

# historical DFS salary data
salary_data = query_data.query_salary_data()
salary_data = salary_data.rename(columns={'POSITION': 'DFS_POSITION'})
salary_data['NAME'] = salary_data['PLAYER'].apply(clean_data.roto_name_to_nba_name)

# historical DFS contest data. I am only interested in predicting ownership in Classic GPP compeititions.
contest_data = query_data.query_contest_data()
contest_data['MAXROI'] = contest_data['TOPPRIZE']/contest_data['ENTRYFEE']
contest_data = contest_data.loc[
    (contest_data['SLATETYPE'] == 'Classic') & (contest_data['CASHLINE'] > 200) & (contest_data['MAXROI'] > 2) &
    (~contest_data['CONTESTNAME'].str.lower().str.contains('|'.join(BAD_CONTEST_SUBSTRINGS)))
].dropna(subset=['CASHLINE'])

# contest payout structure
contest_info = query_data.query_contest_info_data()

# historical player ownership
ownership_data = query_data.query_ownership_data()
ownership_data['NAME'] = ownership_data['PLAYERNAME'].apply(
    lambda x: x if x not in OWNERSHIP_NAME_TO_NBA_NAME else OWNERSHIP_NAME_TO_NBA_NAME[x]
    )

# historical vegas odds data
odds_data = query_data.query_odds_data()

# historical quarterly boxscore data
quarterly_boxscore_data = query_data.query_quarterly_boxscore_data()
# Out:
# /Users/brandonshimiaie/Projects/pyNBA/sqlite/db/nba.db
# 2.6.0

# %% [markdown]
# ## Strategy
# Determine viable contests and how to enter each contest.

# %% [markdown]
# Initilize data.

# %%
season_list = list(boxscores['SEASON'].unique())

# to calculate fantasy points
DKFPCalculator = FPCalculator(Site.DRAFTKINGS)

# isolate Draftkings salaries
boxscores['REB'] = boxscores['DREB'] + boxscores['OREB']
    
# optimize Draftkings NBA lineups
class CustomPuLPSolver(PuLPSolver):
    LP_SOLVER = pulp.GLPK_CMD(msg=0)
optimizer = get_optimizer(Site.DRAFTKINGS, Sport.BASKETBALL, solver=CustomPuLPSolver)

# %% [markdown]
# Helper Functions.

# %%
def calc_p(mu_1, var_1, mu_2, var_2):
    z = (mu_2 - mu_1)/np.sqrt(var_1 + var_2)
    return 1 - st.norm.cdf(z)

def get_contest_prize(contest_info, score):
    prize = contest_info.loc[contest_info['MINPOINTS'] <= score, 'PRIZE'].max()
    return prize

# %% [markdown]
# Enter contests.

# %%
print(time.ctime())

max_entry_fee_per_contest = 1000
pnl = 0

results = pd.DataFrame(columns = [
    'DATE', 'GAME_COUNT', 'CONTEST_TYPE', 'MAX_ENTRIES', 'TOTAL_ENTRIES', 'ENTRY_FEE', 'CASHLINE', 'PRED_SCORE', 'EV', 'SCORE', 'PRIZE', 'TOP_PRIZE'
])

for i in range(1, len(season_list)):
    print(season_list[i])
    fp_train_data = boxscores.loc[boxscores['SEASON'].isin(season_list[0:i])]
    ownership_train_data = boxscores.loc[~(boxscores['SEASON'] == season_list[i])]
    test_data = boxscores.loc[boxscores['SEASON'] == season_list[i]]

    # projected contest top scores
    contest_test_data = contest_data.loc[
        (contest_data['DATE'] >= test_data['DATE'].min()) & (contest_data['DATE'] <= test_data['DATE'].max())
    ]
    contest_train_data = contest_data.loc[
        ~((contest_data['DATE'] >= test_data['DATE'].min()) & (contest_data['DATE'] <= test_data['DATE'].max()))
    ]
    if contest_test_data.empty:
        continue

    topscore_model = TopScoreModel(contest_train_data, contest_test_data)
    topscore_model.create_features(odds_data)
    topscore_model.train_model()
    topscore_predictions, topscore_hat_column = topscore_model.predict()
    contest_test_data = contest_test_data.merge(topscore_predictions, on=['DATE', 'CONTESTID'], how='left')

    # projected fantasy points
    fp_model = FPModel(fp_train_data, test_data, Site.DRAFTKINGS)
    fp_model.train_model(quarterly_boxscore_data, odds_data)
    predictions, fp_hat_column = fp_model.predict()
    predictions = predictions.dropna(subset=[fp_hat_column])

    # actual fantasy points
    predictions['DKFP'] = predictions.apply(
        lambda x: DKFPCalculator.calculate_fantasy_points(
            x['SEASON'], x['PTS'], x['REB'], x['AST'], x['TOV'], x['BLK'], x['STL'], x['FG3M']
        ), 
        axis=1
    )

    # fantasy point variance
    variance_model = VarianceModel(predictions)
    predictions, variance_column = variance_model.predict('DKFP', fp_hat_column)
    pct_variance_column = 'RESIDUAL_PCT'
    predictions[pct_variance_column] = predictions[variance_column]/predictions[fp_hat_column]
    predictions[pct_variance_column] = predictions[pct_variance_column].replace([np.inf, -np.inf], np.nan)
    predictions[pct_variance_column] = predictions[pct_variance_column].fillna(0.25)
    predictions[pct_variance_column] = predictions[pct_variance_column].clip(lower=0.05)

    # projected ownership
    ownership_model = OwnershipModel(ownership_train_data, test_data, Site.DRAFTKINGS)
    ownership_model.create_features(salary_data, contest_data, ownership_data, odds_data)
    ownership_model.train_model()
    ownership_predictions, ownership_column = ownership_model.predict()

    # merge projections to data
    dk_salary_data = salary_data.loc[salary_data['SITE'] == Site.DRAFTKINGS]
    predictions = predictions.merge(dk_salary_data, on=['DATE', 'NAME'], how='left')
    predictions = predictions.dropna(subset=['SALARY', 'DFS_POSITION'])

    ownership_predictions = ownership_predictions.merge(
        predictions[['DATE', 'NAME', fp_hat_column, pct_variance_column, 'SALARY']],
        on=['DATE', 'NAME'], how='left'
    )

    print(time.ctime())

    # iterate through each slate in the season
    for (date, _), slate_contest_data in contest_test_data.groupby(['DATE', 'SLATEID']):
        print(date)

        # get players in slate
        slate_teams = slate_contest_data.iloc[0]['TEAMS'].split('_')
        slate_teams = [i if i not in DB_TEAM_TO_NBA_TEAM else DB_TEAM_TO_NBA_TEAM[i] for i in slate_teams]
        board = predictions.loc[
            (predictions['DATE'] == date) &
            (predictions['TEAM'].isin(slate_teams))
        ]

        board_teams = list(board['TEAM'].unique())
        game_count = slate_contest_data.iloc[0]['GAMECOUNT']
        sym_dif = (set(board_teams).symmetric_difference(set(slate_teams)))
        if bool(sym_dif) or len(slate_teams) != game_count*2:
            print('ERROR')
            continue

        # iterate through each contest in the slate
        slate_contest_data = slate_contest_data.loc[slate_contest_data['ENTRYFEE'] <= 250]
        for _, contest in slate_contest_data.iterrows():
            contest_id = contest['CONTESTID']
            contest_total_entries = contest['TOTALENTRIES']
            contest_max_entries = contest['MAXENTRIES']
            contest_entry_fee = contest['ENTRYFEE']
            
            result = {} 
            result['DATE'] = date
            result['GAME_COUNT'] = game_count
            result['MAX_ENTRIES'] = contest_max_entries
            result['TOTAL_ENTRIES'] = contest_total_entries
            result['ENTRY_FEE'] = contest_entry_fee
            result['CASHLINE'] = contest['CASHLINE']
            result['TOP_PRIZE'] = contest['TOPPRIZE']

            contest_ownership_predictions = ownership_predictions.loc[
                ownership_predictions['CONTESTID'] == contest_id
            ]
            contest_board = board.merge(
                contest_ownership_predictions, on=['NAME']
            )

            # generate distribution of possible max scores of contest
            contest_topscore_mean = contest[topscore_hat_column]
            contest_topscore_variance = 150 #TODO

            # generate lineups for contest
            contest_board = contest_ownership_predictions[['DATE', 'NAME', ownership_column]].merge(board, on=['DATE', 'NAME'], how='left')
            contest_board = contest_board.dropna(subset=['SALARY', 'DFS_POSITION', fp_hat_column, pct_variance_column, ownership_column])

            players = []
            for _, player in contest_board.iterrows():
                player_id = player['PLAYERID']

                name = player['NAME'].split()
                first_name = name[0]
                last_name = name[1] if len(name) > 1 else ''

                positions = player['DFS_POSITION'].split('_')

                team = player['TEAM']

                mu = player[fp_hat_column]
                salary =  player['SALARY']

                player = Player(player_id, first_name, last_name, positions, team, salary, mu, standard_deviation=0.10)
                players.append(player)

            optimizer.load_players(players)
            optimizer.set_max_deviation(3)
            optimizer.set_min_salary_cap(49200)

            n = max(int(1.5*contest_max_entries), 20)
            lineups = optimizer.optimize(n=n, randomness=True)

            try:
                lineup_df = pd.DataFrame()
                contest_board = contest_ownership_predictions[['DATE', 'NAME', ownership_column]].merge(board, on=['DATE', 'NAME'], how='left')
                for lineup in lineups:
                    player_ids = [i.id for i in lineup.lineup]

                    lineup_players = contest_board.loc[contest_board['PLAYERID'].isin(player_ids)]

                    lineup_mean_fp = lineup_players[fp_hat_column].sum()

                    lineup_players['VARIANCE'] = (lineup_players[pct_variance_column]*lineup_players[fp_hat_column]).apply(lambda x: x**2)
                    lineup_players['PARTIALVARIANCE'] = lineup_players[ownership_column].apply(lambda x: 1-x) * lineup_players['VARIANCE']
                    lineup_variance = lineup_players['PARTIALVARIANCE'].sum()

                    real_score = lineup_players['DKFP'].sum()

                    lineup_df = lineup_df.append(
                        pd.DataFrame({'PLAYERIDS': [player_ids], 'MEAN_FP': [lineup_mean_fp], 'VARIANCE': [lineup_variance], 'REALSCORE': [real_score]})
                    )
            except:
                print('COULD NOT GENERATE LINEUPS')
                continue

            # isolate +ev lineups
            lineup_df['PVALUE'] = lineup_df.apply(lambda x: calc_p(x['MEAN_FP'], x['VARIANCE'], contest_topscore_mean, contest_topscore_variance), axis=1)

            value = float(1/contest_total_entries)
            contest_entries = min(contest_max_entries, int(max_entry_fee_per_contest/contest_entry_fee)) if contest_entry_fee > 0 else contest_max_entries
            plus_ev_lineups = lineup_df.sort_values(by='PVALUE', ascending=False).head(int(contest_entries))
            plus_ev_lineups['EV'] = plus_ev_lineups['PVALUE']/value

            # get lineup results
            entered_contest_info = contest_info.loc[contest_info['CONTESTID'] == contest_id]
            entered_contest_info['MINPOINTS'] = entered_contest_info['MINPOINTS'].fillna(0)

            plus_ev_lineups['v'] = plus_ev_lineups['PVALUE']/value
            for _, lineup in plus_ev_lineups.iterrows():
                score = lineup['REALSCORE']
                prize = get_contest_prize(entered_contest_info, score)
                
                
                result['PRED_SCORE'] = lineup['MEAN_FP']
                result['EV'] = lineup['EV']
                result['SCORE'] = score
                result['PRIZE'] = prize
                results = results.append(result, ignore_index=True)
                
                contest_pnl = prize - contest_entry_fee
                if not np.isnan(contest_pnl):
                    pnl += (prize - contest_entry_fee)
            print(round(pnl, 2))
# Out:
# Sun Jul  5 17:11:11 2020
# 2015-16
# 2016-17
# 2017-18
# Sun Jul  5 17:49:50 2020
# 2017-10-18
# ERROR
# 2017-10-18
# ERROR
# 2017-10-18
# ERROR
# 2017-10-19
# ERROR
# 2017-10-19
# ERROR
# 2017-10-20
# -150.0
# 3115.0
# 3175.31
# 2017-10-20
# 2725.31
# 2575.31
# 2515.31
# 2513.31
# 2413.31
# 2409.31
# 2349.31
# 2337.31
# 2310.31
# 1325.31
# 1316.31
# 1296.31
# 1269.31
# 1229.31
# 1053.31
# 753.31
# 2017-10-20
# 591.31
# 579.31
# 2017-10-20
# 581.31
# 2017-10-21
# 554.31
# 454.31
# 455.81
# 419.81
# 410.81
# 210.81
# 180.81
# 120.81
# 111.81
# 99.81
# -284.53
# -286.53
# -1034.53
# -1134.53
# -1462.53
# -1468.03
# -1480.03
# -1500.03
# -1050.03
# -1387.03
# 2017-10-21
# -1537.03
# -1552.03
# -1578.03
# 2017-10-22
# -1740.03
# -1806.03
# -1886.03
# -1966.03
# 2017-10-22
# -2915.03
# -3065.03
# -3241.03
# -3258.03
# -3332.03
# -3350.03
# -3414.03
# 2017-10-23
# -3864.03
# -4014.03
# -4074.03
# -3974.03
# -3975.28
# -4013.28
# -4022.28
# -4034.28
# -4036.28
# -4046.28
# -4058.28
# -4629.37
# -4779.37
# -4879.37
# -4891.37
# -5191.37
# -5203.37
# 2017-10-23
# -5353.37
# -5351.87
# -5358.87
# 2017-10-23
# -5380.87
# -5502.87
# 2017-10-24
# -5485.87
# -5437.87
# -4687.87
# -4684.1
# -4627.1
# -4639.1
# -4599.6
# -3026.85
# -3028.85
# -2968.85
# -2892.85
# -2888.85
# -2900.85
# -3350.85
# -2425.85
# -2465.85
# -1265.85
# -1261.85
# -880.85
# -862.85
# -689.85
# -601.85
# 2017-10-24
# -597.35
# -271.01
# -36.01
# -22.51
# 214.49
# 486.89
# 623.89
# 2017-10-24
# 1986.89
# 2017-10-25
# 1959.89
# 1809.89
# 1709.89
# 1706.14
# 1658.14
# 1631.14
# 1620.14
# 1615.14
# 1606.14
# 1546.14
# 1544.14
# 1532.14
# 1082.14
# 1042.14
# 122.14
# 102.14
# -47.86
# -62.36
# -162.36
# -505.36
# -555.36
# -575.36
# -615.36
# -1295.36
# -1835.03
# -1848.53
# -2148.53
# -2160.53
# -2770.53
# -3201.53
# -3366.53
# -3509.53
# 2017-10-25
# -3516.03
# -3488.03
# -3638.03
# -3388.03
# 2017-10-25
# -3538.03
# -3539.32
# -3441.94
# -3009.94
# -2734.44
# -2635.11
# -2599.11
# -2582.58
# -2510.58
# -2218.58
# -2161.58
# -1846.25
# 2017-10-26
# -1446.25
# -1452.75
# -1560.75
# -1761.74
# -1738.05
# -1730.55
# 2017-10-26
# -1757.55
# -1832.55
# -1932.55
# -1930.55
# -1898.55
# -1925.55
# -1936.55
# -1945.55
# -1965.55
# -2495.88
# -2535.88
# -2547.88
# -2997.88
# -2999.88
# -2324.88
# -2341.38
# -2401.38
# -2528.38
# -2814.71
# -2826.71
# -2834.71
# 2017-10-27
# -2984.71
# -2994.21
# -3017.44
# -2940.44
# -3382.44
# -3284.44
# 2017-10-27
# -3296.44
# -4030.44
# 2017-10-27
# -4057.44
# -4232.44
# -4230.44
# -4231.44
# -4286.44
# -4386.44
# -4398.44
# -4412.44
# -4862.44
# -4922.44
# -4931.44
# -4933.44
# -4945.44
# -5853.44
# -5833.44
# 2017-10-28
# -5845.44
# -5995.44
# -5991.94
# -6021.94
# -5971.94
# -5952.94
# -5979.94
# -5984.94
# -6184.94
# -5699.94
# -5729.94
# -5728.94
# -5740.94
# -5922.94
# -5920.94
# -5964.7
# -5931.7
# -5932.7
# -5944.7
# -5994.7
# 2017-10-28
# -6007.7
# -6241.7
# -6303.7
# -7061.7
# -7125.7
# 2017-10-28
# -7188.32
# -7170.65
# 2017-10-29
# -7182.65
# -7181.4
# -7081.4
# -7096.07
# -7108.07
# -7388.07
# -7395.07
# -7596.76
# -7594.56
# -7744.56
# -7684.56
# -7784.2
# -7824.2
# -7792.2
# 2017-10-29
# -7491.2
# -7763.34
# -7836.34
# 2017-10-29
# -7131.17
# 2017-10-30
# -7581.17
# -7621.17
# -7630.17
# -7642.17
# -8583.17
# -8733.17
# -8833.17
# -8837.17
# -8853.67
# -8880.67
# -8907.67
# -8909.67
# -9059.67
# -9114.67
# -9154.67
# -9604.67
# -9644.67
# -10634.67
# -10654.67
# -10666.67
# -11324.67
# -11574.67
# -12220.41
# 2017-10-30
# -12234.41
# -13076.41
# 2017-10-30
# -13083.91
# -13213.91
# -13374.15
# -13392.15
# 2017-10-31
# -13192.15
# -13170.15
# -13197.15
# -13201.15
# -13204.15
# -13203.15
# -12864.15
# -12830.15
# -12825.15
# -9675.15
# -9630.48
# -9530.48
# -9510.48
# -9509.48
# -7840.62
# -7843.12
# -7870.12
# -7850.12
# -8000.12
# -7321.45
# -7333.45
# -7159.45
# -7057.45
# 2017-10-31
# -7150.45
# -7284.58
# -7050.25
# 2017-11-01
# -7017.25
# -7192.25
# -7195.25
# -7189.25
# -7185.25
# -7285.25
# -7294.25
# -7321.25
# -7236.67
# -7238.67
# -7235.67
# -7247.67
# -7070.67
# -7110.67
# -7140.67
# -6740.67
# -6739.67
# -6751.67
# -6701.67
# -5934.67
# -5900.76
# -5940.76
# -5952.76
# -3739.09
# -3370.09
# -3331.09
# 2017-11-01
# -3313.09
# -3239.59
# 2017-11-01
# -3241.59
# -3511.59
# -3661.59
# -4228.92
# 2017-11-02
# -4328.92
# -4190.92
# -4184.2
# -3584.2
# -3573.99
# -3575.99
# -3325.99
# -3319.99
# -2066.24
# -2106.24
# -2093.57
# -2078.57
# -2043.78
# -2012.78
# -2024.78
# -1952.95
# -148.61
# 359.39
# 2017-11-03
# 332.39
# 182.39
# 155.39
# 150.39
# 100.39
# 0.39
# -15.61
# -20.61
# -80.61
# -89.61
# -91.61
# -103.61
# -553.61
# -593.61
# -593.61
# -612.11
# -692.11
# -1142.11
# -1685.11
# -2402.11
# -2470.11
# -2635.11
# -2811.11
# 2017-11-03
# -2814.77
# -2964.77
# -3409.77
# -3457.77
# -4005.38
# -4011.88
# -4055.88
# -4097.88
# 2017-11-03
# -4262.88
# -4886.88
# 2017-11-04
# -4986.88
# -5013.88
# -5016.38
# -5060.38
# -5074.38
# -5079.38
# -5074.38
# -5099.78
# -5249.78
# -5309.78
# -6117.78
# -6129.78
# -6990.78
# -7002.78
# -7022.78
# -7322.78
# -8027.78
# -8092.78
# 2017-11-04
# -8104.28
# -8136.28
# -8351.28
# -9019.28
# 2017-11-05
# -9176.28
# 2017-11-05
# -9189.28
# -9387.28
# -9425.28
# -10206.28
# -10370.28
# 2017-11-05
# -10370.28
# -10820.28
# -10832.28
# -11772.28
# -11815.28
# -11830.28
# -11842.28
# -12636.28
# -12654.78
# -12804.78
# -12969.78
# -13007.78
# -13548.78
# 2017-11-05
# -13544.75
# -13709.75
# -14056.01
# -14234.28
# 2017-11-06
# -7934.28
# -7926.28
# -7866.28
# -7766.28
# -7360.03
# -7344.03
# -7346.03
# -7373.03
# -7359.03
# -7399.03
# -7243.03
# -3643.03
# -3420.03
# -3345.53
# -2885.53
# 4091.47
# 4109.47
# 4127.97
# 4227.97
# 4319.47
# 5660.89
# 2017-11-06
# 5652.39
# 5642.39
# 5771.21
# 5741.21
# 2017-11-07
# 5732.21
# 5582.21
# 5482.21
# 5479.71
# 5452.21
# 5450.21
# 5423.21
# 5412.21
# 5407.21
# 5395.21
# 5355.21
# 5255.21
# 5180.21
# 5180.21
# 5230.21
# 5230.21
# 5203.21
# 5003.21
# 4990.71
# 4465.71
# 4432.71
# 3924.71
# 3832.71
# 3779.71
# 3581.71
# 2017-11-07
# 3561.71
# 2849.28
# 2017-11-07
# 2830.78
# 2335.78
# 2255.78
# 1294.78
# 1274.78
# 1194.78
# 1018.78
# 2017-11-08
# 868.78
# 768.78
# 768.28
# 775.28
# 764.28
# 762.28
# 735.28
# 762.28
# 802.28
# 790.28
# 778.28
# 763.28
# 743.28
# 938.28
# 488.28
# 477.28
# -53.72
# -95.58
# -103.08
# -253.08
# -771.08
# -910.08
# -929.08
# -1047.08
# -1095.08
# 2017-11-08
# -1097.08
# -1251.08
# -1308.58
# -1862.58
# -2077.98
# 2017-11-09
# -2065.48
# -2296.73
# 2017-11-09
# -946.73
# -945.23
# -894.69
# -171.02
# 279.47
# 349.85
# 2017-11-09
# 322.85
# 295.85
# 195.85
# 195.63
# 190.63
# 188.63
# 148.63
# 135.63
# 139.63
# 64.63
# 52.63
# 105.63
# 78.63
# 77.13
# 2017-11-10
# -122.87
# -149.87
# -249.87
# -253.37
# -258.37
# -313.37
# -315.37
# -342.37
# -359.37
# -399.37
# -330.62
# -342.62
# -354.62
# -654.62
# -667.12
# -1365.12
# -1412.12
# -1424.12
# -1442.12
# 2017-11-10
# -1450.12
# -1600.12
# -1924.12
# -1978.12
# -2712.12
# 2017-11-10
# -2878.12
# 2017-11-11
# -2882.12
# -3012.12
# -3747.12
# -4247.12
# -4412.12
# -4517.12
# -4821.37
# -5051.37
# -5670.37
# -5950.37
# -6485.87
# -6183.87
# 2017-11-11
# -6174.37
# -6026.37
# 2017-11-12
# -6018.06
# -5768.06
# -5745.06
# -4833.95
# -4368.24
# -198.93
# -190.93
# -172.43
# 2017-11-12
# 2013.68
# 3010.48
# 2017-11-13
# 2983.48
# 3133.48
# 3093.48
# 3090.48
# 3078.48
# 3071.98
# 3066.98
# 2966.98
# 2968.98
# 2946.98
# 2934.98
# 2894.98
# 2867.98
# 2767.98
# 2753.48
# 2703.48
# 2230.48
# 2210.48
# 2204.18
# 2263.18
# 2046.18
# 1815.18
# 2017-11-13
# 1815.68
# 2090.85
# 2017-11-13
# 2081.85
# 2077.85
# 1892.85
# 1640.95
# 2017-11-13
# 1642.12
# 4038.09
# 2017-11-14
# 4011.09
# 3911.09
# 3909.34
# 3904.34
# 3854.34
# 3852.34
# 3402.34
# 3387.34
# 3347.34
# 3335.34
# 3260.34
# 3248.34
# 3250.34
# 3100.34
# 2579.34
# 2571.34
# 2541.34
# 2245.34
# 2069.34
# 2017-11-14
# 1955.34
# 1262.64
# 2017-11-15
# 1235.64
# 1135.64
# 1131.64
# 1129.64
# 1124.64
# 1112.64
# 912.64
# 932.64
# 918.64
# 883.64
# 871.64
# 844.64
# -70.36
# -520.36
# -528.36
# -572.36
# -912.36
# -1357.36
# -1361.36
# -1535.34
# -1571.34
# -1526.34
# 2017-11-15
# -1541.34
# -1800.17
# -1856.17
# -2571.17
# -2484.67
# -2624.67
# 2017-11-16
# -2724.67
# -2729.67
# -2734.67
# -3184.67
# -3224.67
# -3236.67
# -3252.67
# -3264.67
# -3339.67
# -3374.67
# -3391.17
# -3431.17
# 2017-11-17
# -3458.17
# -3458.17
# -3461.17
# -3561.17
# -3563.17
# -3568.17
# -3570.17
# -3537.17
# -3581.17
# -3431.17
# -3471.17
# -3482.84
# -3494.84
# -3505.84
# -3517.84
# -3517.84
# -3717.84
# -4427.84
# -4467.84
# -3917.84
# -3929.84
# -4350.17
# -4366.67
# -4451.67
# -4494.67
# -4946.67
# 2017-11-17
# -4947.92
# -4964.92
# -4949.92
# -5005.92
# -5434.92
# -5452.42
# -5524.42
# -5675.82
# 2017-11-17
# -4666.68
# 2017-11-17
# -4862.89
# 2017-11-18
# -4889.89
# -4989.89
# -4990.64
# -4985.64
# -4990.64
# -5440.64
# -5445.64
# -5457.64
# -6138.64
# -6150.64
# -6166.64
# -7014.64
# -7089.64
# -7114.64
# -7141.64
# -7341.64
# -7353.64
# -7356.82
# -7806.82
# -8526.82
# -9059.82
# -9225.82
# 2017-11-18
# -9241.82
# -9465.82
# -9530.82
# -10156.82
# -10380.82
# 2017-11-19
# -10389.94
# -10366.94
# -10747.27
# 2017-11-19
# -10703.27
# -10218.27
# -8649.79
# -8581.79
# 2017-11-19
# -9031.79
# -9010.79
# -9022.79
# -9023.79
# -9658.79
# -9689.79
# 2017-11-20
# -9839.79
# -9839.29
# -9844.29
# -9776.29
# -9816.29
# -9769.79
# -9771.79
# -9771.79
# -9798.79
# -9810.79
# -9710.79
# -9770.79
# -9970.79
# -9940.79
# -9927.79
# -10027.79
# 2017-11-20
# -10032.79
# -10104.79
# -10769.83
# 2017-11-20
# -11161.01
# 2017-11-22
# -11188.01
# -11288.01
# -11438.01
# -11441.51
# -11453.51
# -11463.01
# -11468.01
# -11508.01
# -11520.01
# -11595.01
# -11638.01
# -11678.01
# -11728.01
# -11787.01
# -11800.51
# -12357.65
# -12402.65
# -12389.65
# -12401.65
# -13034.65
# -13077.65
# -13381.65
# 2017-11-22
# -13398.15
# -13668.15
# -13748.15
# -14625.15
# -14641.15
# 2017-11-22
# -14609.89
# 2017-11-24
# -14636.89
# -14711.89
# -14661.89
# -14663.64
# -14641.97
# -14640.97
# -14580.97
# -14557.97
# -14592.97
# -14598.97
# -14497.97
# -14452.97
# -9712.97
# -9512.97
# -9524.97
# -8964.97
# -8948.97
# -7666.97
# 2017-11-24
# -7530.97
# -6308.97
# -5841.97
# 26527.3
# 2017-11-24
# 26129.3
# 25759.3
# 25590.3
# 2017-11-25
# 25563.3
# 25463.3
# 25460.05
# 25458.05
# 25453.05
# 25410.55
# 25401.55
# 24951.55
# 24939.55
# 24941.55
# 24093.55
# 24018.55
# 23168.55
# 23120.55
# 23108.55
# 23048.55
# 23050.05
# 22193.05
# 21743.05
# 21703.55
# 21258.55
# 21108.55
# 20932.55
# 2017-11-25
# 20915.55
# 20635.55
# 19978.63
# 2017-11-25
# 19964.13
# 19637.63
# 2017-11-25
# 19681.13
# 19785.21
# 2017-11-26
# 19485.21
# 19473.21
# 19459.21
# 19455.71
# 19412.71
# 18672.71
# 18008.17
# 17997.67
# 2017-11-27
# 17983.67
# 17783.67
# 16980.38
# 16922.38
# 16874.38
# 2017-11-27
# 16724.38
# 16730.63
# 16711.63
# 16724.63
# 16740.56
# 16780.56
# 16804.06
# 16979.06
# 16879.06
# 16902.06
# 16897.06
# 16747.06
# 16765.06
# 16725.06
# 16713.06
# 17229.74
# 18601.74
# 18801.74
# 18944.74
# 18962.74
# 2017-11-27
# 19510.17
# 2017-11-28
# 19483.17
# 19443.17
# 19446.17
# 19406.17
# 19456.17
# 19381.17
# 19369.17
# 19363.17
# 19349.17
# 19347.42
# 19357.42
# 19352.42
# 19325.42
# 19231.09
# 19081.09
# 2017-11-28
# 19078.09
# 19084.09
# 19038.09
# 18496.18
# 18486.68
# 18432.68
# 18390.68
# 2017-11-29
# 18413.68
# 18513.68
# 18511.93
# 19911.93
# 19936.93
# 19924.93
# 19849.93
# 19837.93
# 19829.93
# 19796.93
# 19827.1
# 19800.1
# 19473.1
# 19468.1
# 19459.1
# 19526.1
# 19376.1
# 19765.1
# 2017-11-29
# 19753.6
# 19489.6
# 18855.6
# 2017-11-29
# 18871.1
# 19940.1
# 2017-11-30
# 19913.1
# 19763.1
# 19765.1
# 19761.1
# 19711.1
# 19611.1
# 19612.1
# 19607.1
# 19595.1
# 19583.1
# 19543.1
# 19468.1
# 19457.1
# 19438.6
# 19426.6
# 18666.6
# 18626.6
# 18326.6
# 18111.6
# 18066.6
# 2017-11-30
# 18052.1
# 17728.1
# 17654.1
# 17055.1
# 17038.1
# 16876.1
# 16820.1
# 2017-12-01
# 16793.1
# 16718.1
# 16715.1
# 16615.1
# 16620.85
# 16615.85
# 16584.85
# 16582.85
# 16590.85
# 16550.85
# 16548.35
# 16613.35
# 16601.35
# 16603.35
# 16623.35
# 2017-12-01
# 16622.28
# 16500.28
# 16436.28
# 2017-12-02
# 16484.28
# 16384.28
# 16387.28
# 16392.28
# 16401.99
# 16406.99
# 16407.99
# 16395.99
# 16314.69
# 16274.69
# 16574.69
# 16539.69
# 16547.69
# 16540.48
# 16408.48
# 16401.48
# 16406.48
# 16395.48
# 16245.48
# 2017-12-02
# 16237.48
# 16239.04
# 16227.04
# 15942.04
# 15766.54
# 15778.54
# 15774.04
# 15678.33
# 16989.33
# 16956.33
# 16841.33
# 2017-12-02
# 16833.83
# 16653.83
# 16216.76
# 16109.76
# 2017-12-03
# 16109.76
# 16149.76
# 16157.76
# 16160.26
# 15855.06
# 15435.06
# 14985.06
# 15021.06
# 14981.28
# 15110.28
# 15088.28
# 2017-12-03
# ERROR
# 2017-12-04
# 15061.28
# 15056.28
# 14956.28
# 14962.28
# 14922.28
# 14997.28
# 14998.78
# 14992.78
# 14970.78
# 14943.78
# 14843.78
# 14123.78
# 14119.28
# 13969.28
# 13957.28
# 13917.28
# 13517.28
# 13521.28
# 13607.28
# 13581.78
# 2017-12-04
# 13561.78
# 13297.78
# 12372.78
# 2017-12-05
# 12367.78
# 12355.78
# 12328.78
# 12316.78
# 12216.78
# 12141.78
# COULD NOT GENERATE LINEUPS
# COULD NOT GENERATE LINEUPS
# COULD NOT GENERATE LINEUPS
# COULD NOT GENERATE LINEUPS
# COULD NOT GENERATE LINEUPS
# COULD NOT GENERATE LINEUPS
# COULD NOT GENERATE LINEUPS
# COULD NOT GENERATE LINEUPS
# COULD NOT GENERATE LINEUPS
# COULD NOT GENERATE LINEUPS
# 2017-12-05
# 12132.78
# 12135.45
# 11694.45
# 2017-12-06
# 11694.45
# 11494.45
# 11467.45
# 11464.45
# 11460.2
# 11360.2
# 11358.2
# 11353.2
# 11341.2
# 11291.2
# 11279.2
# 11267.2
# 11227.2
# 11152.2
# 11147.2
# 11120.2
# 10383.2
# 10343.2
# 10328.7
# 10287.7
# 10269.7
# 10257.7
# 9957.7
# 9367.7
# 9312.7
# 8542.7
# 2017-12-06
# 8525.7
# 8195.7
# 7528.7
# 7514.2
# 6978.2
# 2017-12-06
# 7006.7
# 2017-12-07
# 6979.7
# 6879.7
# 6875.95
# 6825.95
# 6820.95
# 6806.95
# 6766.95
# 6754.95
# 6742.95
# 6667.95
# 6640.95
# 6622.45
# 6610.45
# 6570.45
# 5813.95
# 5513.95
# 5118.95
# 5103.6
# 5071.6
# 4817.6
# 2017-12-07
# 4797.6
# 4473.6
# 4405.6
# 3549.6
# 2017-12-08
# 3522.6
# 3447.6
# 3547.6
# 3554.6
# 3548.6
# 3509.6
# 3470.6
# 3483.6
# 3481.14
# 3441.14
# 3437.64
# 3255.64
# 3228.64
# 3230.64
# 3047.14
# 3007.14
# 3020.14
# 4370.14
# 4231.14
# 4206.14
# 2017-12-08
# 4230.64
# 4711.64
# 4259.55
# 4215.55
# 2017-12-09
# 4238.55
# 4138.55
# 4138.8
# 4147.8
# 4150.8
# 4144.8
# 4148.8
# 4166.66
# 4668.66
# 4656.66
# 4623.66
# 7423.66
# 7448.66
# 7465.66
# 7736.33
# 7738.33
# 7744.83
# 7744.83
# 8144.83
# 2017-12-09
# 8132.83
# 7489.83
# 7473.33
# 7024.26
# 6976.26
# 6963.26
# 6380.46
# 6337.46
# 6073.46
# 2017-12-09
# 6153.65
# 7836.23
# 8322.23
# 2017-12-10
# 8327.73
# 8277.73
# 8295.73
# 8345.73
# 8354.23
# 9113.23
# 9823.23
# 9873.23
# 10034.23
# 2017-12-10
# 10479.23
# 10553.23
# 10899.23
# 2017-12-11
# 11028.23
# 11030.92
# 10883.92
# 10748.92
# 2017-12-11
# 10648.92
# 10646.42
# 10634.42
# 10607.42
# 10602.42
# 10573.42
# 10561.42
# 10560.42
# 10520.42
# 10445.42
# 10256.42
# 9806.42
# 9706.42
# 9679.42
# 9674.42
# 9241.42
# 9229.42
# 9217.42
# 9177.42
# 8931.42
# 8892.42
# 2017-12-12
# 8865.42
# 9315.42
# 9215.42
# 9217.5
# 9205.5
# 9200.5
# 9120.5
# 9081.5
# 9069.5
# 9063.5
# 9114.5
# 9134.5
# 9107.5
# 8537.5
# 8532.5
# 8530.65
# 2017-12-12
# 8588.29
# 8613.0
# 8728.0
# 9107.64
# 9307.64
# 2017-12-12
# 9596.31
# 2017-12-13
# 9569.31
# 9469.31
# 9466.56
# 9416.56
# 9411.56
# 9399.56
# 8949.56
# 8937.56
# 8897.56
# 8885.56
# 8810.56
# 8760.56
# 7860.56
# 7365.56
# 7347.06
# 7335.06
# 7074.06
# 7024.06
# 2017-12-13
# 6982.06
# 6962.06
# 6882.06
# 6324.06
# 6242.06
# 2017-12-13
# 6209.06
# 2017-12-14
# 6182.06
# 6032.06
# 5932.06
# 5928.81
# 5868.81
# 5863.81
# 5867.81
# 5768.81
# 5756.81
# 5716.81
# 5688.81
# 5668.81
# 5628.81
# 5602.81
# 2017-12-14
# 5592.31
# 5342.31
# 5119.19
# 2017-12-15
# 5092.19
# 4942.19
# 5242.19
# 5237.94
# 5192.94
# 5187.94
# 5182.94
# 5083.94
# 5089.94
# 5077.94
# 5037.94
# 4217.94
# 3972.94
# 3822.94
# 3789.94
# 3690.94
# 3686.94
# 2017-12-15
# 3622.94
# 2017-12-15
# 3660.19
# 3654.69
# 3758.36
# 3778.36
# 3551.47
# 3759.47
# 2017-12-16
# 3659.47
# 3622.47
# 3610.47
# 3611.22
# 3561.22
# 3569.22
# 3559.22
# 3109.22
# 2409.22
# 2369.22
# 1429.22
# 1424.22
# 1412.22
# 1400.22
# 2017-12-16
# 1411.22
# 1677.22
# 21910.96
# 2017-12-17
# 21895.96
# 21733.96
# 20974.29
# 20834.29
# 2017-12-17
# 20830.04
# 20780.04
# 20187.04
# 20175.04
# 20156.54
# 20096.54
# 19195.54
# 19135.54
# 2017-12-18
# 19185.54
# 19181.79
# 19142.79
# 19130.79
# 19118.79
# 19078.79
# 19066.79
# 18967.79
# 18940.79
# 18935.79
# 18933.79
# 18633.79
# 18188.79
# 18168.79
# 18186.79
# 17739.79
# 17539.79
# 17494.79
# 2017-12-18
# 17476.29
# 17146.29
# 16166.29
# 2017-12-19
# 16066.29
# 16063.79
# 16057.79
# 16017.79
# 16023.79
# 15984.79
# 15534.79
# 15527.79
# 15487.79
# 15493.79
# 15483.79
# 15498.79
# 15398.79
# 15266.79
# 2017-12-20
# 15166.79
# 15164.29
# 15152.29
# 15150.29
# 15156.29
# 15171.29
# 15181.29
# 15169.29
# 15160.79
# 14960.79
# 14475.79
# 14463.79
# 14423.79
# 14385.79
# 2017-12-20
# 14814.79
# 14855.79
# 14882.79
# 15089.8
# 15667.93
# 2017-12-20
# 15478.93
# 2017-12-20
# 15402.13
# 2017-12-21
# 15375.13
# 15275.13
# 15277.73
# 15282.73
# 15292.73
# 15298.73
# 15312.73
# 15613.73
# 15736.73
# 2017-12-21
# 15798.78
# 15814.28
# 16755.7
# 17040.28
# 2017-12-22
# 17013.28
# 16913.28
# 16910.03
# 16895.03
# 16890.03
# 16878.03
# 16779.03
# 16752.03
# 16743.03
# 16293.03
# 16281.03
# 15567.94
# 15527.94
# 15473.94
# 15293.94
# 14993.94
# 14719.94
# 14747.94
# 14719.94
# 14582.94
# 2017-12-22
# 14540.94
# 14528.94
# 14663.94
# 14297.3
# 14283.8
# 14117.91
# 14081.91
# 2017-12-22
# 13972.91
# 2017-12-23
# 13981.66
# 13857.66
# 16855.62
# 16973.62
# 2017-12-23
# 16946.62
# 16846.62
# 16860.62
# 16870.62
# 16870.62
# 16876.12
# 17676.12
# 17636.12
# 17804.46
# 17994.46
# 17982.46
# 17971.46
# 18422.46
# 18264.46
# 18224.46
# 18218.46
# 18768.46
# 20131.46
# 20136.46
# 2017-12-23
# 20132.46
# 2017-12-25
# 20132.46
# 20132.96
# 20127.96
# 20028.96
# 20016.96
# 19976.96
# 19971.96
# 19944.96
# 19941.96
# 19841.96
# 19839.96
# 19812.96
# 19800.96
# 19850.96
# 19856.96
# 19789.96
# 2017-12-25
# 19790.46
# 19513.15
# 2017-12-25
# 19138.15
# 19127.65
# 19081.65
# 18559.25
# 18228.5
# 2017-12-25
# 18230.8
# 17866.73
# 17741.73
# 2017-12-26
# 17641.73
# 17602.73
# 17590.73
# 17700.73
# 17700.73
# 17673.73
# 17674.48
# 17664.48
# 17667.48
# 17642.48
# 17632.98
# 17620.98
# 16840.98
# 16540.98
# 16495.98
# 2017-12-26
# 16490.98
# 17389.98
# 17380.57
# 17036.91
# 17107.91
# 2017-12-26
# 16799.91
# 2017-12-27
# 16772.91
# 16801.3
# 16826.3
# 16833.3
# 16842.8
# 16743.8
# 16866.8
# 16897.3
# 16447.3
# 16505.3
# 16525.3
# 16593.5
# 16601.5
# 16556.5
# 16566.5
# 2017-12-27
# 16265.5
# 2017-12-27
# 16375.0
# 16512.0
# 17281.0
# 18231.33
# 18287.33
# 18439.33
# 2017-12-28
# 18339.33
# 18312.33
# 18318.08
# 18314.08
# 18309.08
# 18305.08
# 18293.08
# 18194.08
# 18154.08
# 18127.08
# 18122.08
# 18110.08
# 18112.83
# 18096.83
# 18056.83
# 17756.83
# 17451.83
# 17132.83
# 17108.83
# 2017-12-28
# 17114.33
# 17126.83
# 16759.83
# 16612.83
# 2017-12-29
# 16635.83
# 17135.83
# 17161.83
# 17175.83
# 17185.83
# 17196.83
# 17216.83
# 17239.83
# 18949.33
# 19006.83
# 25478.09
# 25466.09
# 25543.09
# 2017-12-29
# 25531.09
# 25528.41
# 25510.41
# 25345.41
# 28053.99
# 2017-12-29
# 28276.99
# 35354.66
# 2017-12-30
# 35354.56
# 35423.56
# 35172.56
# 35167.06
# 35177.06
# 35245.06
# 2017-12-30
# 35645.06
# 35768.06
# 35901.06
# 35911.06
# 35909.06
# 35922.81
# 37910.81
# 37960.81
# 37980.81
# 39352.81
# 42916.94
# 42986.67
# 43047.67
# 43286.71
# 48718.21
# 49888.21
# 49876.21
# 50576.21
# 51387.88
# 2017-12-31
# 51781.38
# 52243.18
# 56093.18
# 57212.8
# 57260.8
# 71210.8
# 78920.68
# 79180.12
# 80156.12
# 81566.12
# 93235.12
# 96279.12
# 2017-12-31
# 96274.12
# 96085.12
# 95416.12
# 95385.62
# 2018-01-01
# 95389.62
# 95452.29
# 95912.79
# 97126.21
# 2018-01-01
# 97026.21
# 97030.21
# 97040.21
# 97061.21
# 97084.21
# 97079.21
# 97129.21
# 97137.21
# 97038.21
# 96998.21
# 97040.21
# 96695.21
# 96880.74
# 96885.74
# 96908.74
# 97521.16
# 97511.16
# 97499.16
# 97699.16
# 97659.16
# 99576.16
# 99597.66
# 99638.66
# 100108.66
# 100122.66
# 100258.16
# 100289.16
# 2018-01-02
# 100310.66
# 100339.22
# 100585.72
# 100703.29
# 2018-01-02
# 100703.29
# 100183.29
# 100084.29
# 100044.29
# 100087.29
# 100075.29
# 100060.46
# 99610.46
# 99510.46
# 99507.46
# 99507.46
# 99480.46
# 99475.46
# 99488.46
# 99483.46
# 2018-01-02
# 99473.96
# 99543.96
# 2018-01-03
# 99536.94
# 99855.94
# 99398.31
# 99217.88
# 99139.55
# 99000.55
# 2018-01-03
# 102000.55
# 101973.55
# 101975.55
# 102075.55
# 102078.05
# 102081.05
# 102079.05
# 102079.05
# 101629.05
# 102041.92
# 102029.92
# 102049.92
# 102099.42
# 102318.42
# 102219.42
# 101594.42
# 101394.42
# 101344.42
# 101317.42
# 103167.42
# 103567.42
# 103580.42
# 103585.42
# 103648.42
# 103608.42
# 103636.42
# 105723.42
# 105727.06
# 2018-01-04
# 105627.06
# 105626.31
# 104866.31
# 104844.16
# 104832.16
# 104783.16
# 104783.4
# 104771.4
# 104731.4
# 104090.56
# 103940.56
# 103900.56
# 103913.56
# 103813.56
# 103782.03
# 103632.03
# 103620.03
# 103451.26
# 103411.26
# 103378.26
# 2018-01-05
# 103377.26
# 103321.26
# 103106.26
# 102917.26
# 102905.26
# 102911.26
# 2018-01-05
# 102811.26
# 102784.26
# 102781.01
# 102776.01
# 102759.01
# 102747.01
# 102687.01
# 101789.16
# 101690.16
# 101650.16
# 101638.16
# 101188.16
# 101138.16
# 100305.16
# 99417.16
# 2018-01-06
# 99405.16
# 99402.22
# 99372.22
# 99042.22
# 98186.22
# 2018-01-06
# 98189.22
# 98174.22
# 97901.63
# 97911.63
# 2018-01-06
# 97811.63
# 97784.63
# 97786.63
# 97781.63
# 97788.38
# 97786.38
# 97776.38
# 99576.38
# 99516.38
# 99504.38
# 99500.38
# 99378.52
# 99338.52
# 98713.52
# 2018-01-07
# 98745.52
# 98776.02
# 99838.02
# 99929.02
# 100244.52
# 2018-01-07
# 99794.52
# 99782.52
# 100507.07
# 100520.07
# 100240.07
# 100246.72
# 100284.22
# 100522.22
# 100222.22
# 100254.22
# 100782.97
# 100522.97
# 100791.97
# 101271.97
# 2018-01-07
# 101266.97
# 101265.47
# 101250.47
# 101053.24
# 101027.67
# 100893.3
# 2018-01-08
# 100901.3
# 100921.3
# 100721.3
# 100686.3
# 100578.3
# 100578.64
# 100590.64
# 100568.14
# 100468.14
# 100473.47
# 100485.07
# 100494.32
# 100517.32
# 100520.32
# 100493.32
# 100494.82
# 100529.82
# 101049.82
# 101079.82
# 101117.82
# 101090.32
# 101140.32
# 101307.32
# 101506.32
# 101494.32
# 101502.32
# 101302.32
# 2018-01-08
# 101296.07
# 2018-01-08
# 101349.07
# 101319.07
# 101320.07
# 101174.07
# 100700.07
# 100941.07
# 100938.07
# 100773.07
# 100715.07
# 2018-01-09
# 100615.07
# 100588.07
# 100576.07
# 100571.07
# 100566.57
# 99850.57
# 99856.57
# 99816.57
# 99810.07
# 98820.07
# 98777.07
# 98702.07
# 98252.07
# 98210.07
# 98205.07
# 98178.07
# 98164.07
# 97471.07
# 97477.07
# 97437.07
# 96565.32
# 96715.32
# 96682.32
# 2018-01-09
# 96522.32
# 96499.32
# 96494.82
# 96021.77
# 96046.52
# 2018-01-10
# 97513.02
# 98526.85
# 98548.52
# 99394.86
# 99420.36
# 100459.7
# 101621.7
# 2018-01-10
# 101747.2
# 2018-01-10
# 101720.2
# 101620.2
# 101617.2
# 101625.7
# 101620.7
# 101618.7
# 101612.7
# 101698.7
# 101248.7
# 101851.7
# 101852.7
# 101812.7
# 100932.7
# 100955.7
# 100981.7
# 100481.7
# 100406.7
# 100419.7
# 100414.7
# 100419.2
# 100117.87
# 100077.87
# 2018-01-11
# 99977.87
# 99992.87
# 99992.87
# 99997.62
# 100062.62
# 100089.05
# 101139.05
# 101150.05
# 101158.05
# 102258.05
# 102513.05
# 102623.05
# 102688.05
# 102683.05
# 102707.05
# 103157.05
# 103166.38
# 103126.38
# 103134.38
# 103756.38
# 2018-01-11
# 103848.14
# 103879.64
# 105108.97
# 105848.64
# 2018-01-11
# 105842.14
# 105680.14
# 105230.14
# 104979.28
# 2018-01-12
# 105177.11
# 105576.11
# 105654.0
# 106474.33
# 107268.78
# 107308.61
# 107789.61
# 2018-01-12
# 107792.02
# 107753.02
# 2018-01-12
# 107653.02
# 107676.02
# 107681.02
# 107692.02
# 107729.52
# 107731.02
# 107581.02
# 107569.02
# 107609.02
# 107627.02
# 107552.02
# 109804.02
# 110174.4
# 109613.4
# 109658.4
# 109660.92
# 109918.07
# 109968.07
# 109983.07
# 109996.07
# 110252.07
# 110403.74
# 110515.74
# 2018-01-13
# 110578.74
# 110584.74
# 111284.74
# 111292.74
# 116294.74
# 116385.24
# 2018-01-13
# 116285.24
# 116283.99
# 116279.99
# 116270.49
# 116247.49
# 116297.49
# 116256.49
# 116196.49
# 116156.49
# 115666.91
# 115286.91
# 115274.91
# 2018-01-13
# 115124.91
# 115124.91
# 114820.91
# 2018-01-14
# 114870.91
# 114687.73
# 114681.61
# 114682.86
# 114677.86
# 114497.36
# 114513.29
# 114516.79
# 114392.84
# 114390.84
# 114367.84
# 114256.84
# 2018-01-14
# 114091.84
# 114096.34
# 114079.34
# 128742.34
# 128742.34
# 128778.34
# 2018-01-15
# 128678.34
# 128676.34
# 128649.34
# 128644.34
# 128629.34
# 128179.34
# 128167.34
# 128107.34
# 128092.34
# 127298.34
# 127258.34
# 126583.34
# 126528.34
# 126228.34
# 125591.34
# 125577.99
# 125565.99
# 125595.99
# 125295.99
# 125253.99
# 124685.99
# 124324.49
# 124312.49
# 124262.49
# 124227.49
# 123975.49
# 2018-01-15
# 123970.38
# 124028.38
# 2018-01-15
# 124016.38
# 123812.38
# 123793.88
# 122912.88
# 122307.88
# 122123.88
# 122015.38
# 2018-01-15
# 122015.38
# 122016.81
# 122216.81
# 122176.81
# 122191.81
# 121882.81
# 121870.81
# 121250.81
# 121450.81
# 121410.81
# 121406.31
# 121394.31
# 121278.17
# 121320.77
# 121280.77
# 2018-01-16
# 121305.77
# 121434.77
# 121442.77
# 121472.27
# 121931.05
# 122132.48
# 2018-01-16
# 122332.48
# 122305.48
# 122300.48
# 122296.48
# 122299.73
# 122263.73
# 122303.73
# 122302.73
# 122320.73
# 122120.73
# 122795.73
# 122787.73
# 122658.73
# 122733.73
# 122728.73
# 122628.73
# 122671.73
# 122677.73
# 122637.73
# 122645.73
# 122970.73
# 122990.73
# 122992.73
# 122844.73
# 2018-01-17
# 122744.73
# 122717.73
# 122722.73
# 122727.98
# 122723.98
# 123013.38
# 123026.38
# 123041.58
# 123061.58
# 123561.58
# 123528.58
# 123575.58
# 123576.58
# 123527.58
# 123427.58
# 123432.58
# 123456.4
# 123444.4
# 123554.4
# 123633.4
# 124427.4
# 2018-01-17
# 124451.92
# 124449.43
# 124417.87
# 124127.75
# 124126.25
# 124148.91
# 2018-01-17
# 124301.91
# 124311.91
# 125170.29
# 2018-01-18
# 125070.29
# 125043.29
# 125038.29
# 125035.79
# 124987.79
# 124960.54
# 124243.54
# 124231.54
# 124216.54
# 124016.54
# 123976.54
# 123216.54
# 123141.54
# 123114.54
# 123100.01
# 123095.01
# 122645.01
# 122605.01
# 122611.01
# 122589.01
# 122150.01
# 2018-01-18
# 122070.01
# 121674.01
# 121662.01
# 120662.01
# 120643.51
# 120115.51
# 119899.51
# 2018-01-19
# 120199.51
# 120372.51
# 120373.51
# 120376.51
# 120391.51
# 120403.51
# 120444.84
# 120994.84
# 121012.84
# 120972.84
# 120757.84
# 121007.3
# 121060.78
# 121135.78
# 121437.78
# 122487.78
# 123489.78
# 123497.78
# 123511.28
# 124012.28
# 124030.78
# 2018-01-19
# 123992.78
# 124000.78
# 124000.39
# 123814.39
# 123663.46
# 2018-01-19
# 123647.96
# 123437.96
# 2018-01-20
# 123337.96
# 123385.96
# 123386.19
# 123394.19
# 123389.19
# 123384.19
# 123930.19
# 123730.19
# 123744.19
# 123732.19
# 123792.19
# 123863.51
# 123325.51
# 123369.84
# 123232.84
# 123278.84
# 2018-01-20
# 123311.55
# 123547.43
# 123604.72
# 123971.72
# 124002.05
# 124331.05
# 125619.05
# 126368.72
# 2018-01-20
# 126376.72
# 126379.72
# 126886.12
# 127220.12
# 127235.12
# 127233.62
# 127334.62
# 127347.62
# 127643.29
# 127784.29
# 2018-01-21
# 128165.62
# 128429.51
# 128468.51
# 128889.09
# 128911.09
# 2018-01-21
# 128851.09
# 128888.09
# 128889.82
# 128877.82
# 128865.82
# 128825.82
# 130560.9
# 130760.9
# 130240.9
# 130241.9
# 2018-01-22
# 130456.9
# 130662.42
# 130762.42
# 130750.42
# 130759.75
# 130768.75
# 2018-01-22
# 130606.75
# 130591.25
# 130099.25
# 2018-01-22
# 129999.25
# 129337.25
# 129338.75
# 129298.75
# 129290.25
# 128840.25
# 128828.25
# 128789.25
# 128750.25
# 127862.25
# 127814.25
# 127805.25
# 127778.25
# 127780.25
# 127778.25
# 127773.25
# 127768.25
# 127741.25
# 127734.75
# 127284.75
# 127242.08
# 127230.08
# 2018-01-23
# 127580.08
# 127576.08
# 127584.93
# 127596.13
# 127556.13
# 128209.07
# 143661.07
# 143682.57
# 143691.57
# 143662.57
# 144827.82
# 144900.82
# 144913.82
# 144908.82
# 144904.82
# 144804.82
# 144851.32
# 144842.32
# 145071.32
# 2018-01-23
# 145005.32
# 144993.32
# 144981.32
# 144756.32
# 143915.32
# 143907.32
# 2018-01-23
# 144211.67
# 144662.33
# 2018-01-24
# 144562.33
# 144535.33
# 144536.08
# 144539.08
# 144537.08
# 144533.08
# 144521.08
# 144481.08
# 144481.9
# 144031.9
# 143932.9
# 143580.9
# 143522.9
# 143352.9
# 143453.9
# 143426.9
# 143681.9
# 143676.9
# 143684.9
# 143625.9
# 143667.9
# 143753.9
# 2018-01-24
# 143841.9
# 143835.4
# 144205.4
# 2018-01-24
# 144292.4
# 144300.4
# 144321.51
# 144325.51
# 144820.34
# 2018-01-25
# 144979.34
# 145179.34
# 145174.34
# 145039.44
# 146018.69
# 2018-01-25
# 146318.69
# 146704.19
# 146727.19
# 146734.69
# 146737.69
# 146966.19
# 147216.19
# 147222.19
# 147243.19
# 147403.19
# 148437.04
# 148588.04
# 148884.04
# 149400.87
# 149457.37
# 149730.37
# 151032.7
# 151120.7
# 2018-01-26
# 151020.7
# 150993.7
# 150993.7
# 150988.7
# 150955.7
# 150953.7
# 150941.7
# 150930.1
# 150480.1
# 150590.1
# 149966.1
# 151367.1
# 150727.1
# 150679.1
# 150263.1
# 150251.6
# 150259.6
# 150384.6
# 150352.6
# 150192.6
# 2018-01-26
# 149920.1
# 149912.6
# 149345.6
# 150185.6
# 2018-01-26
# 150175.1
# 149911.1
# 2018-01-27
# 149811.1
# 149784.1
# 149766.1
# 149761.1
# 149757.35
# 149714.35
# 149705.35
# 149505.35
# 149465.35
# 149473.35
# 148793.35
# 148694.35
# 148620.35
# 147870.35
# 147855.35
# 147843.35
# 147113.35
# 147073.35
# 146623.35
# 146585.35
# 146449.35
# 146437.35
# 145683.6
# 145533.6
# 2018-01-27
# 145309.6
# 145281.6
# 145269.1
# 144456.1
# 144443.1
# 143692.1
# 143416.1
# 143255.1
# 2018-01-28
# 143555.1
# 143561.1
# 143666.1
# 143704.1
# 143717.1
# 143726.1
# 143799.6
# 144259.6
# 174989.51
# 175264.66
# 175302.66
# 175363.66
# 175963.66
# 176288.66
# 176738.66
# 2018-01-28
# 178145.66
# 178483.66
# 182268.66
# 182728.66
# 182852.16
# 182864.3
# 185317.18
# 185384.18
# 185672.18
# 186335.38
# 187015.38
# 187253.38
# 190453.38
# 190827.38
# 191087.38
# 191105.38
# 205388.58
# 207835.58
# 207930.08
# 208248.66
# 208501.66
# 209359.66
# 2018-01-29
# 210597.16
# 210598.68
# 210561.49
# 210562.49
# 2018-01-29
# 210146.49
# 210446.49
# 210477.49
# 210478.49
# 210473.49
# 210446.49
# 210441.49
# 211401.49
# 211410.99
# 210960.99
# 210948.99
# 210283.99
# 210244.99
# 209999.99
# 209959.99
# 209932.99
# 209926.49
# 209776.49
# 209770.49
# 2018-01-29
# 209762.99
# 209659.66
# 2018-01-30
# 209313.66
# 209257.66
# 209253.16
# 208767.13
# 2018-01-30
# 208867.13
# 208890.13
# 208893.13
# 208898.13
# 208874.13
# 208902.13
# 208910.13
# 208960.13
# 208920.13
# 208919.13
# 208283.13
# 208184.13
# 207659.13
# 207647.13
# 207620.13
# 207580.13
# 207130.13
# 207123.13
# 207111.13
# 207100.13
# 2018-01-30
# 207078.13
# 207098.13
# 206744.13
# 2018-01-31
# 206664.13
# 206652.13
# 206637.13
# 206344.13
# 205481.13
# 205461.13
# 205387.13
# 2018-01-31
# 204397.13
# 204297.13
# 204270.13
# 204265.13
# 204263.38
# 204226.38
# 204217.38
# 203767.38
# 203727.38
# 202854.74
# 202848.74
# 202836.74
# 202761.74
# 202695.74
# 202474.74
# 202459.24
# 202399.24
# 202319.24
# 2018-02-01
# 202219.24
# 202242.24
# 202244.24
# 202839.24
# 202863.24
# 203313.24
# 203264.24
# 203252.24
# 203259.24
# 203619.24
# 203105.24
# 202665.24
# 202646.61
# 202378.61
# 202384.86
# 202387.36
# 202325.36
# 2018-02-01
# 202415.36
# 202418.36
# 202429.36
# 202592.5
# 202833.5
# 2018-02-02
# 202824.5
# 202842.0
# 2018-02-02
# 202852.0
# 202932.0
# 202931.0
# 202526.0
# 202528.0
# 2018-02-02
# 202528.0
# 202528.0
# 202519.0
# 202492.0
# 202487.0
# 202484.5
# 202447.5
# 202435.5
# 201985.5
# 202005.5
# 201993.0
# 201344.0
# 201245.0
# 200486.72
# 200459.72
# 201141.72
# 201041.72
# 201049.72
# 201039.72
# 200988.72
# 200838.72
# 2018-02-03
# 200850.72
# 200838.72
# 200615.22
# 200601.72
# 199902.72
# 2018-02-03
# 199802.72
# 199802.72
# 199775.72
# 199778.72
# 199933.72
# 199983.72
# 199971.72
# 200026.72
# 200856.15
# 200807.15
# 201266.15
# 200826.15
# 200358.15
# 200356.65
# 200344.65
# 200044.65
# 200038.65
# 199998.65
# 199928.65
# 2018-02-04
# 199922.15
# 199869.59
# 199730.59
# 199274.59
# 199114.59
# 198967.59
# 2018-02-04
# 198964.59
# 198327.59
# 198315.59
# 198275.59
# 197825.59
# 196975.59
# 196966.59
# 196906.59
# 196908.59
# 196758.59
# 196704.59
# 196254.59
# 196194.59
# 2018-02-05
# 195744.59
# 195704.59
# 195692.59
# 195167.59
# 195138.59
# 195132.59
# 194564.59
# 193799.59
# 193344.41
# 193144.41
# 193141.41
# 193138.91
# 193099.91
# 193094.91
# 193127.91
# 192637.91
# 192687.91
# 192298.91
# 2018-02-05
# 192286.91
# 192278.91
# 192293.89
# 192297.47
# 192391.97
# 192255.04
# 2018-02-05
# 192236.54
# 191862.54
# 2018-02-06
# 191835.54
# 191735.54
# 191738.79
# 191743.79
# 191725.79
# 191716.79
# 191516.79
# 191476.79
# 191482.79
# 191294.41
# 191195.41
# 191789.91
# 191169.91
# 191601.91
# 191543.91
# 191516.91
# 191511.91
# 191629.91
# 2018-02-06
# 191662.91
# 191626.91
# 191630.91
# 191629.91
# 191371.91
# 190920.91
# 190907.91
# 190869.91
# 190619.91
# 2018-02-07
# ERROR
# 2018-02-07
# ERROR
# 2018-02-08
# 190592.91
# 190597.91
# 190601.16
# 190698.49
# 191098.49
# 191103.49
# 191069.49
# 191077.49
# 191539.44
# 191121.44
# 191071.44
# 191516.44
# 191555.99
# 191564.99
# 192064.99
# 192087.99
# 192095.99
# 192107.99
# 192152.99
# 192882.99
# 192974.49
# 2018-02-08
# 193036.49
# 193044.49
# 193032.49
# 192955.16
# 192980.91
# 193050.91
# 193060.34
# 2018-02-08
# 193123.84
# 193115.84
# 2018-02-09
# 193194.84
# 193190.84
# 193821.43
# 193849.19
# 194184.19
# 194176.19
# 2018-02-09
# COULD NOT GENERATE LINEUPS
# COULD NOT GENERATE LINEUPS
# COULD NOT GENERATE LINEUPS
# COULD NOT GENERATE LINEUPS
# COULD NOT GENERATE LINEUPS
# COULD NOT GENERATE LINEUPS
# COULD NOT GENERATE LINEUPS
# COULD NOT GENERATE LINEUPS
# COULD NOT GENERATE LINEUPS
# COULD NOT GENERATE LINEUPS
# COULD NOT GENERATE LINEUPS
# COULD NOT GENERATE LINEUPS
# COULD NOT GENERATE LINEUPS
# COULD NOT GENERATE LINEUPS
# COULD NOT GENERATE LINEUPS
# COULD NOT GENERATE LINEUPS
# COULD NOT GENERATE LINEUPS
# COULD NOT GENERATE LINEUPS
# COULD NOT GENERATE LINEUPS
# 2018-02-09
# 194170.19
# 194102.7
# 2018-02-10
# 194002.7
# 194005.7
# 193978.7
# 193979.45
# 193974.45
# 194001.45
# 195051.45
# 195035.45
# 195023.45
# 195083.45
# 194984.45
# 194994.95
# 194176.95
# 194228.95
# 193823.95
# 194522.95
# 194535.95
# 194585.95
# 194563.95
# 194493.95
# 2018-02-10
# 194499.95
# 194507.95
# 194972.95
# 194980.95
# 195620.6
# 195648.6
# 2018-02-11
# 195548.6
# 195543.6
# 195545.35
# 194972.35
# 194954.35
# 194914.35
# 194547.99
# 194535.99
# 194530.49
# 194430.49
# 194390.49
# 194378.49
# 194334.16
# 194329.16
# 193795.16
# 2018-02-11
# 193695.16
# 193697.91
# 193682.41
# 193685.41
# 193885.41
# 193825.41
# 197841.4
# 197829.4
# 197866.61
# 197826.61
# 197808.61
# 197440.61
# 197554.36
# 2018-02-12
# 197454.36
# 197455.11
# 197443.11
# 197899.11
# 197894.11
# 197867.11
# 198167.11
# 198155.11
# 198215.11
# 198296.11
# 200656.11
# 200036.11
# 200109.11
# 200106.11
# 201952.36
# 203032.03
# 203005.03
# 202754.03
# 2018-02-12
# 202959.82
# 202978.32
# 204337.32
# 205598.26
# 2018-02-13
# 205498.26
# 205499.76
# 205506.76
# 205529.76
# 205474.76
# 205465.76
# 205207.76
# 205195.76
# 204745.76
# 204705.76
# 204656.76
# 204663.26
# 204195.26
# 204193.26
# 203822.38
# 203817.38
# 203825.38
# 2018-02-13
# 203995.41
# 204284.41
# 204332.41
# 204894.41
# 204928.41
# 2018-02-14
# 204472.41
# 204372.41
# 204369.41
# 204371.91
# 204344.91
# 204347.91
# 204318.86
# 203318.86
# 202868.86
# 202856.86
# 202858.86
# 202918.86
# 202425.86
# 202386.86
# 202354.86
# 202364.06
# 202029.66
# 201837.66
# 201833.29
# 201633.29
# 201621.29
# 201755.62
# 2018-02-14
# 201979.62
# 201992.62
# 202024.12
# 202361.12
# 203876.91
# 2018-02-14
# 203794.91
# 203793.24
# 203694.24
# 2018-02-15
# 203720.57
# 203726.77
# 203736.77
# 203967.77
# 203975.77
# 204575.77
# 205165.96
# 205182.96
# 205202.96
# 205208.96
# 206227.29
# 208650.62
# 208656.62
# 208676.62
# 212376.62
# 212391.12
# 212606.12
# 212722.92
# 2018-02-22
# 212359.92
# 212304.92
# 212301.92
# 212289.92
# 211839.92
# 211799.92
# 211700.92
# 210990.92
# 210520.92
# 210420.92
# 210411.92
# 210409.67
# 210404.67
# 210377.67
# 210377.67
# 210364.67
# 210352.67
# 209897.67
# 209652.67
# 2018-02-22
# 209490.67
# 209481.17
# 209207.17
# 2018-02-22
# 209195.17
# 209217.17
# 209209.17
# 209216.92
# 210314.59
# 210600.13
# 2018-02-23
# 210500.13
# 210523.13
# 210514.13
# 210516.09
# 210511.09
# 210485.09
# 210385.09
# 210413.09
# 210314.09
# 210302.09
# 210262.09
# 210260.67
# 210258.67
# 210290.67
# 210030.67
# 2018-02-23
# 210038.67
# 210042.17
# 209988.17
# 209542.14
# 209396.14
# 209304.14
# 2018-02-24
# 210454.14
# 210489.14
# 210891.64
# 210956.64
# 210929.64
# 210974.64
# 211524.64
# 211552.64
# 211662.64
# 211663.64
# 211683.38
# 211717.78
# 211969.78
# 214160.89
# 218634.89
# 218758.89
# 220458.89
# 221418.89
# 221519.22
# 2018-02-24
# 221537.22
# 221855.55
# 221972.75
# 222967.75
# 223371.05
# 223490.05
# 2018-02-25
# 223390.05
# 223376.05
# 223371.05
# 222788.05
# 222741.05
# 222701.05
# 222689.05
# 221981.05
# 221962.55
# 221824.55
# 2018-02-25
# 221857.8
# 222057.8
# 224062.8
# 224082.8
# 224110.8
# 224114.8
# 224194.8
# 234214.8
# 234541.16
# 235261.16
# 235297.16
# 235352.16
# 235427.16
# 235990.36
# 235938.36
# 2018-02-26
# 235838.36
# 235838.61
# 235826.61
# 235807.61
# 235802.61
# 235775.61
# 235763.61
# 235313.61
# 235273.61
# 234816.61
# 234717.61
# 234700.11
# 234040.11
# 233370.11
# 233345.11
# 232794.11
# 232767.11
# 232755.11
# 2018-02-26
# 232539.11
# 232531.11
# 232519.11
# 232529.11
# 232301.51
# 2018-02-27
# 232201.51
# 232192.51
# 232188.26
# 232133.26
# 232128.26
# 232101.26
# 231651.26
# 231577.26
# 231565.26
# 231525.26
# 230537.26
# 230438.26
# 230419.76
# 229419.76
# 228523.76
# 228518.76
# 228506.76
# 2018-02-27
# 228494.76
# 228269.76
# 227835.76
# 227830.26
# 227804.26
# 227801.26
# 227697.26
# 2018-02-28
# 227597.26
# 227620.26
# 227619.26
# 227614.26
# 227633.26
# 227599.26
# 227149.26
# 227109.26
# 227010.26
# 226230.26
# 226194.26
# 226200.26
# 225775.26
# 225762.26
# 225076.26
# 224301.26
# 2018-02-28
# 224020.26
# 223973.26
# 223961.26
# 223946.45
# 223075.45
# 2018-02-28
# 223043.45
# 223042.16
# 225154.42
# 2018-03-01
# 225142.42
# 225527.42
# 225035.34
# 224975.34
# 224966.84
# 2018-03-01
# 224939.84
# 224934.84
# 224922.84
# 224867.84
# 224417.84
# 224387.84
# 224321.84
# 224319.34
# 224279.34
# 224267.34
# 223457.34
# 222557.34
# 221727.34
# 221723.84
# 221655.84
# 221638.34
# 221626.34
# 221190.34
# 221130.34
# 2018-03-02
# 221103.34
# 221108.34
# 221111.34
# 221192.34
# 221187.34
# 221187.34
# 221337.34
# 221351.84
# 221411.84
# 221417.84
# 221452.84
# 221439.1
# 221592.38
# 221943.21
# 222713.21
# 222946.54
# 2018-03-02
# 224366.44
# 2018-03-02
# 224292.44
# 223897.44
# 223885.44
# 223865.44
# 222925.44
# 222718.44
# 2018-03-03
# 222618.44
# 222591.44
# 222591.02
# 222692.02
# 222699.02
# 222727.22
# 222727.22
# 222277.22
# 222283.22
# 222303.22
# 222315.96
# 222294.4
# 221949.4
# 222128.4
# 221880.4
# 2018-03-03
# 221953.4
# 223153.43
# 2018-03-03
# 223125.43
# 223138.43
# 223137.43
# 222934.43
# 222561.59
# 222532.26
# 2018-03-04
# 222531.77
# 222505.77
# 222510.77
# 222310.77
# 222340.77
# 222333.77
# 222329.77
# 222289.77
# 222377.77
# 222192.77
# 221612.77
# 221606.27
# 2018-03-04
# 221706.27
# 221719.27
# 221724.61
# 221750.61
# 221612.61
# 221642.61
# 221438.72
# 221447.72
# 221347.72
# 221377.72
# 221400.22
# 221413.22
# 221303.22
# 2018-03-04
# 221256.22
# 221394.6
# 221328.6
# 221332.46
# 221299.46
# 2018-03-05
# 221265.46
# 221253.46
# 221277.39
# 221287.39
# 220897.94
# 220761.94
# 2018-03-05
# 220661.94
# 220652.94
# 220650.48
# 220551.48
# 220502.48
# 220497.48
# 220470.48
# 220458.48
# 220008.48
# 219968.48
# 219058.48
# 219044.48
# 218629.48
# 218586.48
# 217940.48
# 217225.48
# 217213.48
# 216962.48
# 2018-03-06
# 216862.48
# 216835.48
# 216826.48
# 216821.48
# 216816.98
# 216767.98
# 216692.98
# 216242.98
# 216230.98
# 216340.98
# 215475.98
# 215466.84
# 214776.84
# 214749.84
# 214199.84
# 214172.84
# 214114.84
# 214096.34
# 213756.34
# 213694.34
# 2018-03-06
# 213922.34
# 213930.88
# 214133.88
# 2018-03-06
# 214141.88
# 214351.38
# 214601.38
# 214777.38
# 214815.05
# 215058.38
# 215265.71
# 2018-03-07
# 215538.71
# 215559.71
# 215670.71
# 215685.71
# 215692.46
# 216074.46
# 222374.46
# 222394.46
# 224196.58
# 224234.58
# 224266.08
# 224341.08
# 226286.87
# 226359.87
# 228029.54
# 228017.54
# 230217.54
# 230261.04
# 230737.54
# 230989.73
# 2018-03-07
# 230997.73
# 231045.98
# 231124.31
# 231324.31
# 231286.14
# 231685.65
# 231733.15
# 233015.06
# 233101.39
# 233438.39
# 2018-03-08
# 234235.39
# 235031.39
# 235023.89
# 239205.89
# 2018-03-08
# 239228.89
# 239194.89
# 239199.89
# 239201.62
# 239240.62
# 239540.62
# 239528.62
# 239588.62
# 239576.62
# 239573.62
# 238948.62
# 238864.62
# 238332.98
# 239137.98
# 239097.98
# 239085.98
# 239097.98
# 239100.48
# 2018-03-09
# 239091.48
# 239072.48
# 239075.23
# 239031.23
# 239013.23
# 238563.23
# 238561.73
# 238521.73
# 238527.73
# 238147.73
# 237332.73
# 237562.73
# 237008.73
# 237388.73
# 237376.73
# 237220.73
# 237580.73
# 237780.73
# 237771.23
# 237255.53
# 237027.24
# 236896.24
# 2018-03-09
# 236904.24
# 236898.74
# 236584.74
# 236590.74
# 236379.61
# 235979.61
# 237238.78
# 237192.78
# 2018-03-09
# 237185.28
# 237575.28
# 2018-03-10
# 237415.28
# 237395.28
# 237399.8
# 236834.8
# 2018-03-10
# 236807.8
# 236788.8
# 236783.8
# 236785.05
# 236769.05
# 236755.05
# 236805.05
# 236811.05
# 236825.47
# 236865.47
# 236692.14
# 236212.92
# 235534.92
# 235234.92
# 235242.92
# 235235.92
# 2018-03-11
# 235175.92
# 235157.92
# 235154.67
# 235149.67
# 235119.67
# 235110.17
# 234650.17
# 234610.17
# 234619.17
# 234419.17
# 234125.17
# 2018-03-11
# 234123.17
# 233323.17
# 233314.17
# 232864.17
# 232809.17
# 232797.17
# 232120.17
# 232080.17
# 2018-03-11
# 232080.67
# 231769.67
# 2018-03-12
# 231768.92
# 231747.92
# 231720.92
# 231715.92
# 231671.92
# 231221.92
# 231161.92
# 231174.92
# 231214.92
# 231121.92
# 231311.92
# 231293.92
# 230980.92
# 230592.92
# 230605.92
# 230503.92
# 230203.92
# 230300.92
# 229900.92
# 2018-03-13
# 229012.92
# 228985.92
# 228886.92
# 228874.92
# 228870.92
# 228770.92
# 228759.92
# 228719.92
# 228707.92
# 228557.92
# 227812.92
# 227820.92
# 227094.92
# 227089.92
# 227084.92
# 2018-03-13
# 227024.92
# 227012.92
# 227004.92
# 226410.92
# 225675.45
# 2018-03-13
# 225808.45
# 225650.45
# 2018-03-14
# 225698.45
# 225731.45
# 225902.45
# 228407.45
# 229617.91
# 230317.91
# 2018-03-14
# 230365.91
# 230533.91
# 230554.41
# 230544.41
# 230559.91
# 230709.91
# 230777.91
# 230937.91
# 230941.91
# 233196.61
# 243146.61
# 244223.21
# 245901.49
# 245931.49
# 248046.49
# 250096.49
# 250191.23
# 252353.73
# 253298.73
# 2018-03-15
# 253271.73
# 253211.73
# 253212.73
# 253112.73
# 253120.73
# 253115.73
# 253077.73
# 253073.04
# 253133.04
# 252848.79
# 251943.79
# 252043.79
# 252034.29
# 252004.29
# 2018-03-15
# 251875.29
# 251821.29
# 251815.79
# 251378.79
# 251337.79
# 2018-03-15
# 251330.29
# 251196.29
# 2018-03-16
# 251169.29
# 251180.77
# 251233.77
# 251383.77
# 251397.94
# 251392.94
# 251452.94
# 251002.94
# 250692.94
# 250782.67
# 250788.67
# 250801.67
# 251261.67
# 251711.67
# 251765.17
# 252315.17
# 253236.17
# 253194.17
# 2018-03-16
# 253182.67
# 252782.67
# 252736.67
# 252301.67
# 251712.11
# 251697.61
# 251250.11
# 251070.11
# 2018-03-17
# 251066.36
# 250616.36
# 250516.36
# 250504.36
# 250464.36
# 250446.36
# 250124.36
# 249214.36
# 249142.36
# 248244.36
# 248239.36
# 248227.36
# 248077.36
# 248061.86
# 247999.86
# 2018-03-17
# 247715.86
# 247651.86
# 247638.36
# 246736.36
# 246110.36
# 2018-03-17
# 246177.3
# 246088.3
# 2018-03-17
# 2018-03-18
# 246088.8
# 245788.8
# 245833.8
# 245841.8
# 245886.8
# 245879.8
# 245989.8
# 245789.8
# 245639.8
# 245627.8
# 245626.8
# 246306.8
# 246274.8
# 2018-03-18
# 246362.8
# 246379.8
# 246149.86
# 2018-03-19
# 246485.19
# 246493.19
# 246756.44
# 246782.94
# 247930.91
# 247998.52
# 2018-03-19
# 247798.52
# 247047.52
# 246079.52
# 246076.02
# 245976.02
# 245877.02
# 245871.02
# 245844.02
# 245839.02
# 245823.02
# 245783.02
# 245771.02
# 245732.02
# 245709.02
# 245478.02
# 245252.02
# 2018-03-20
# 245225.02
# 245236.02
# 245239.02
# 245089.02
# 245095.02
# 245058.02
# 245057.02
# 245052.02
# 245112.02
# 244612.02
# 244328.67
# 244331.67
# 244326.67
# 244394.17
# 244594.17
# 244662.17
# 244692.57
# 244852.57
# 244594.57
# 244749.57
# 244742.57
# 244552.57
# 2018-03-20
# 244570.57
# 244670.57
# 244677.57
# 244277.57
# 244223.67
# 2018-03-21
# 244673.67
# 244646.67
# 244637.67
# 244588.67
# 244583.67
# 244578.67
# 244128.67
# 244110.67
# 244070.67
# 244058.67
# 243620.67
# 242715.67
# 242053.67
# 242022.67
# 242007.67
# 2018-03-21
# 241973.67
# 241962.67
# 241632.67
# 240865.67
# 2018-03-22
# 240883.67
# 241038.67
# 241043.67
# 244643.67
# 244698.67
# 244702.92
# 244758.92
# 244798.92
# 245148.92
# 245336.92
# 245170.24
# 245095.24
# 244895.24
# 244855.24
# 244843.24
# 250218.24
# 250230.24
# 250252.24
# 250293.74
# 250464.17
# 250452.17
# 250758.17
# 251033.17
# 251233.17
# 2018-03-22
# 251286.17
# 251768.67
# 251772.17
# 252037.31
# 252446.31
# 252514.31
# 2018-03-23
# 252414.31
# 252387.31
# 252288.31
# 252293.31
# 252292.31
# 251842.31
# 251830.31
# 251854.81
# 251819.81
# 251779.81
# 251039.81
# 250651.81
# 250551.81
# 250524.81
# 250512.81
# 250472.81
# 250712.81
# 250722.31
# 250572.31
# 250307.31
# 250265.31
# 2018-03-23
# 250245.31
# 249845.31
# 249765.31
# 249270.31
# 248290.31
# 248114.31
# 2018-03-23
# 248123.61
# 248559.61
# 2018-03-24
# 248630.61
# 248612.61
# 248464.61
# 248102.99
# 247982.99
# 247928.99
# 2018-03-24
# 247968.99
# 247971.99
# 247971.24
# 248121.24
# 248111.24
# 248131.24
# 247990.24
# 247978.24
# 247283.24
# 246525.24
# 246478.24
# 246438.24
# 246388.24
# 246588.24
# 246579.24
# 245986.24
# 245896.24
# 245836.24
# 245748.24
# 2018-03-25
# 245668.24
# 245140.24
# 244788.24
# 244612.24
# 2018-03-25
# 244812.24
# 244781.24
# 244769.24
# 244752.74
# 244409.74
# 243909.74
# 243903.24
# 2018-03-25
# 243453.24
# 243441.24
# 243401.24
# 243361.24
# 243346.24
# 243271.24
# 242331.24
# 241396.24
# 241096.24
# 241080.24
# 241006.24
# 240766.24
# 2018-03-26
# 240767.82
# 240753.82
# 240792.82
# 240673.01
# 2018-03-26
# 240672.01
# 240712.01
# 240685.01
# 240680.01
# 240230.01
# 240986.01
# 240998.01
# 241038.01
# 241346.77
# 241355.77
# 240767.77
# 240779.77
# 239891.77
# 239591.77
# 239625.77
# 239340.77
# 239300.77
# 239319.77
# 239307.77
# 2018-03-27
# 239207.77
# 239180.77
# 239081.77
# 239084.77
# 239347.27
# 239355.52
# 246155.52
# 246161.52
# 246247.52
# 246256.16
# 246216.16
# 247351.16
# 247912.51
# 247920.51
# 2018-03-27
# 248096.51
# 248149.88
# 249399.88
# 250038.88
# 250418.06
# 2018-03-27
# 250433.06
# 250629.06
# 2018-03-28
# 250529.06
# 250502.06
# 250403.06
# 250406.06
# 250158.06
# 250155.56
# 249705.56
# 249711.56
# 249711.56
# 249671.56
# 249127.56
# 248399.56
# 248354.56
# 248342.56
# 248330.56
# 247753.81
# 247588.81
# 247171.81
# 2018-03-28
# 247178.81
# 247073.81
# 247101.81
# 247001.81
# 246695.52
# 2018-03-29
# 246890.52
# 246923.82
# 246939.82
# 246696.36
# 246654.93
# 246635.93
# 246704.93
# 2018-03-29
# 246706.18
# 246596.18
# 246585.18
# 246545.18
# 246558.18
# 246585.56
# 246135.56
# 245708.29
# 245108.29
# 244996.29
# 2018-03-30
# 244994.79
# 245000.79
# 244960.79
# 244948.79
# 244956.79
# 244186.79
# 243986.79
# 243431.79
# 242806.79
# 242758.79
# 242752.79
# 242602.79
# 242412.79
# 242042.79
# 2018-03-30
# 242026.79
# 241973.5
# 241172.5
# 240534.5
# 240204.1
# 239934.1
# 239820.1
# 2018-03-30
# 239803.1
# 2018-03-31
# 239822.1
# 240007.1
# 240020.1
# 240029.6
# 242364.14
# 242293.14
# 2018-03-31
# 241897.14
# 2018-03-31
# 241910.14
# 241898.14
# 241858.14
# 241840.14
# 242000.14
# 241550.14
# 241090.14
# 241079.14
# 240938.14
# 2018-04-01
# 240914.14
# 240649.14
# 240637.14
# 240626.14
# 240435.14
# 240305.14
# 2018-04-01
# 240303.14
# 240291.14
# 240311.14
# 240532.14
# 240382.14
# 240006.94
# 240011.96
# 240386.96
# 240752.96
# 2018-04-01
# 240516.96
# 240360.96
# 240208.96
# 2018-04-01
# 240206.46
# 239589.13
# 239274.13
# 239198.13
# 239273.13
# 2018-04-03
# 239822.13
# 239863.13
# 240346.11
# 242739.57
# 2018-04-03
# 242745.32
# 242748.32
# 242698.32
# 242658.32
# 242703.09
# 242726.09
# 243221.09
# 243249.09
# 262711.09
# 263109.77
# 263116.27
# 263276.27
# 263288.27
# 263138.27
# 263765.72
# 263746.72
# 2018-04-03
# 263629.72
# 2018-04-03
# 264135.72
# 2018-04-04
# 264130.72
# 264128.47
# 264134.47
# 264080.47
# 264070.47
# 264110.47
# 263430.47
# 262830.47
# 262205.47
# 261660.47
# 261648.47
# 2018-04-04
# 261593.47
# 261593.47
# 261469.53
# 2018-04-05
# 262054.53
# 262163.0
# 262561.0
# 262566.0
# 2018-04-05
# 262761.0
# 262765.75
# 262763.75
# 262723.75
# 262729.75
# 261729.75
# 261175.75
# 260725.75
# 260484.71
# 260472.71
# 260512.21
# 260732.21
# 260719.71
# 260829.71
# 2018-04-06
# 261409.87
# 261597.54
# 261625.04
# 262361.09
# 264085.47
# 2018-04-06
# 264083.47
# 264086.47
# 264024.47
# 263984.47
# 263986.47
# 266886.47
# 266411.97
# 266761.97
# 266344.31
# 266332.31
# 266127.31
# 2018-04-07
# 266112.81
# 265256.56
# 265131.56
# 2018-04-07
# 265126.56
# 265122.56
# 264822.56
# 264780.56
# 264740.56
# 264728.56
# 263868.56
# 263856.56
# 263171.56
# 263021.56
# 262351.56
# 262346.56
# 2018-04-08
# 262343.31
# 262043.31
# 261963.31
# 261951.31
# 261911.31
# 261893.31
# 261093.31
# 260263.31
# 259903.31
# 259857.31
# 259752.31
# 2018-04-08
# 259923.31
# 259904.48
# 259907.98
# 259844.58
# 259854.08
# 260807.08
# 2018-04-09
# 260808.83
# 260811.83
# 260787.83
# 260792.33
# 260192.33
# 259640.33
# 259190.33
# 259178.33
# 259138.33
# 258761.98
# 2018-04-09
# 258585.98
# 2018-04-09
# 258570.48
# 258372.48
# 257592.92
# 257266.92
# 257142.92
# 2018-04-10
# 257129.92
# 2018-04-10
# 257119.92
# 256855.92
# 256035.92
# 2018-04-10
# 256045.92
# 256048.17
# 256071.17
# 256067.67
# 255617.67
# 255777.67
# 255765.67
# 255460.85
# 255420.85
# 255420.85
# 2018-04-11
# 255346.85
# 255016.85
# 254998.85
# 254125.85
# 253949.85
# 2018-04-11
# 253946.6
# 253866.6
# 253826.6
# 253809.6
# 254109.6
# 253109.6
# 253097.6
# 252152.6
# 252002.6
# 251922.6
# 251757.6
# 250907.6
# 2018-19
# Sun Jul  5 21:38:54 2020
# 2018-10-16
# ERROR
# 2018-10-17
# ERROR
# 2018-10-17
# ERROR
# 2018-10-17
# ERROR
# 2018-10-18
# ERROR
# 2018-10-19
# 250915.6
# 250990.6
# 251012.6
# 250912.6
# 250962.6
# 250972.35
# 250984.35
# 250944.35
# 250952.35
# 250950.35
# 250956.35
# 250994.35
# 251052.35
# 251063.35
# COULD NOT GENERATE LINEUPS
# COULD NOT GENERATE LINEUPS
# COULD NOT GENERATE LINEUPS
# 251663.35
# 2018-10-19
# 251609.35
# 251565.35
# 251543.35
# 251551.35
# 251539.35
# 251530.11
# 251522.11
# 251066.58
# 250166.58
# 249891.58
# 249892.08
# 249890.08
# 249990.08
# 2018-10-19
# 250016.71
# 250048.84
# 250182.84
# 250215.84
# 250700.84
# 250862.84
# 2018-10-20
# 250662.84
# 250212.84
# 250152.84
# 250149.34
# 250140.84
# 250134.84
# 250065.84
# 250053.84
# 250051.84
# 250101.84
# 250061.84
# 250027.58
# 249276.58
# 248376.58
# 247576.58
# 247526.58
# 247455.58
# 247230.58
# 2018-10-20
# 247374.58
# 247397.58
# 247694.58
# 247937.11
# 247897.11
# 247916.93
# 248249.43
# 2018-10-20
# 248257.24
# 248047.24
# 2018-10-21
# 247747.24
# 247687.24
# 247685.24
# 247673.24
# 247573.24
# 247533.24
# 247521.24
# 247504.24
# 247472.24
# 246664.24
# 245664.24
# 244776.24
# 2018-10-21
# 244759.74
# 244710.74
# 243875.3
# 2018-10-22
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2018-10-22
# nan
# nan
# nan
# nan
# nan
# nan
# 2018-10-22
# nan
# nan
# 2018-10-22
# nan
# nan
# 2018-10-23
# nan
# nan
# nan
# 2018-10-23
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2018-10-24
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2018-10-24
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2018-10-24
# nan
# nan
# nan
# nan
# 2018-10-25
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2018-10-25
# nan
# nan
# nan
# nan
# 2018-10-26
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2018-10-26
# nan
# nan
# nan
# nan
# 2018-10-26
# nan
# 2018-10-27
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2018-10-27
# nan
# nan
# nan
# nan
# 2018-10-27
# nan
# 2018-10-28
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2018-10-29
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2018-10-29
# nan
# nan
# nan
# 2018-10-29
# nan
# nan
# nan
# 2018-10-30
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2018-10-30
# nan
# nan
# nan
# nan
# nan
# 2018-10-31
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2018-10-31
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2018-10-31
# nan
# 2018-11-01
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2018-11-01
# nan
# nan
# nan
# nan
# 2018-11-02
# nan
# nan
# nan
# nan
# nan
# nan
# 2018-11-02
# nan
# nan
# nan
# nan
# COULD NOT GENERATE LINEUPS
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2018-11-02
# nan
# nan
# nan
# nan
# 2018-11-03
# nan
# 2018-11-03
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2018-11-03
# nan
# nan
# nan
# nan
# 2018-11-04
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2018-11-04
# nan
# nan
# nan
# nan
# 2018-11-04
# nan
# 2018-11-05
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2018-11-05
# nan
# nan
# nan
# nan
# nan
# 2018-11-05
# nan
# nan
# 2018-11-05
# nan
# 2018-11-06
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2018-11-06
# nan
# nan
# nan
# nan
# nan
# nan
# 2018-11-07
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2018-11-07
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2018-11-07
# nan
# nan
# nan
# 2018-11-08
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2018-11-08
# nan
# nan
# nan
# nan
# nan
# 2018-11-09
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2018-11-09
# nan
# nan
# nan
# 2018-11-09
# nan
# nan
# nan
# nan
# nan
# nan
# 2018-11-10
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2018-11-10
# nan
# 2018-11-10
# nan
# nan
# nan
# nan
# nan
# 2018-11-10
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2018-11-11
# nan
# nan
# nan
# nan
# 2018-11-11
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2018-11-12
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2018-11-12
# nan
# nan
# nan
# nan
# nan
# nan
# 2018-11-12
# nan
# 2018-11-13
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2018-11-13
# nan
# nan
# nan
# nan
# nan
# 2018-11-14
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2018-11-14
# nan
# nan
# nan
# nan
# nan
# nan
# 2018-11-14
# nan
# nan
# nan
# 2018-11-15
# nan
# nan
# nan
# 2018-11-15
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2018-11-16
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2018-11-16
# nan
# nan
# nan
# nan
# nan
# 2018-11-17
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2018-11-17
# nan
# 2018-11-17
# nan
# nan
# nan
# 2018-11-18
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2018-11-19
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2018-11-19
# nan
# nan
# nan
# 2018-11-20
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2018-11-20
# nan
# nan
# nan
# nan
# 2018-11-21
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2018-11-21
# nan
# nan
# 2018-11-21
# nan
# nan
# nan
# nan
# nan
# 2018-11-23
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2018-11-23
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2018-11-23
# nan
# nan
# 2018-11-23
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2018-11-24
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2018-11-24
# nan
# nan
# nan
# 2018-11-24
# nan
# 2018-11-25
# nan
# nan
# nan
# nan
# 2018-11-25
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2018-11-25
# nan
# nan
# nan
# 2018-11-26
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2018-11-26
# COULD NOT GENERATE LINEUPS
# nan
# nan
# nan
# 2018-11-26
# nan
# 2018-11-27
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2018-11-27
# nan
# 2018-11-27
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2018-11-28
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2018-11-28
# nan
# nan
# nan
# nan
# nan
# nan
# 2018-11-28
# nan
# nan
# 2018-11-29
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2018-11-29
# nan
# nan
# nan
# nan
# nan
# 2018-11-30
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2018-11-30
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2018-11-30
# nan
# nan
# 2018-12-01
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2018-12-01
# nan
# nan
# nan
# nan
# 2018-12-03
# ...
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2019-11-22
# nan
# nan
# nan
# nan
# nan
# 2019-11-22
# nan
# nan
# 2019-11-23
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2019-11-23
# nan
# nan
# nan
# nan
# 2019-11-23
# nan
# 2019-11-24
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2019-11-24
# nan
# nan
# nan
# 2019-11-25
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2019-11-25
# nan
# nan
# nan
# nan
# 2019-11-25
# nan
# 2019-11-26
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2019-11-27
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2019-11-27
# nan
# nan
# nan
# nan
# nan
# 2019-11-27
# nan
# 2019-11-27
# nan
# 2019-11-29
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2019-11-29
# nan
# nan
# nan
# nan
# nan
# 2019-11-29
# nan
# nan
# 2019-11-29
# nan
# 2019-11-30
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2019-11-30
# nan
# nan
# nan
# 2019-12-01
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2019-12-01
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2019-12-01
# nan
# nan
# 2019-12-02
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2019-12-02
# nan
# nan
# nan
# 2019-12-03
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2019-12-03
# nan
# nan
# 2019-12-03
# nan
# nan
# nan
# nan
# nan
# nan
# 2019-12-04
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2019-12-04
# nan
# nan
# nan
# nan
# nan
# 2019-12-04
# nan
# nan
# 2019-12-05
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2019-12-05
# nan
# nan
# 2019-12-06
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2019-12-06
# nan
# nan
# nan
# nan
# nan
# 2019-12-06
# nan
# nan
# 2019-12-07
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2019-12-07
# nan
# nan
# nan
# 2019-12-08
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2019-12-08
# nan
# nan
# nan
# nan
# 2019-12-08
# nan
# nan
# nan
# 2019-12-09
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2019-12-09
# nan
# nan
# nan
# 2019-12-09
# nan
# 2019-12-10
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2019-12-10
# nan
# nan
# nan
# nan
# 2019-12-11
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2019-12-11
# nan
# nan
# nan
# nan
# nan
# 2019-12-11
# nan
# nan
# 2019-12-11
# nan
# nan
# 2019-12-12
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2019-12-12
# nan
# nan
# nan
# 2019-12-13
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2019-12-13
# nan
# nan
# 2019-12-13
# nan
# 2019-12-14
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2019-12-14
# nan
# nan
# nan
# nan
# nan
# 2019-12-14
# nan
# 2019-12-15
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2019-12-15
# nan
# nan
# 2019-12-15
# nan
# nan
# 2019-12-16
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2019-12-16
# nan
# nan
# nan
# 2019-12-17
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2019-12-17
# nan
# nan
# nan
# nan
# nan
# 2019-12-17
# nan
# nan
# 2019-12-18
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2019-12-18
# nan
# nan
# nan
# nan
# nan
# nan
# 2019-12-18
# nan
# nan
# 2019-12-19
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2019-12-19
# nan
# nan
# nan
# 2019-12-20
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2019-12-20
# nan
# nan
# nan
# nan
# nan
# nan
# 2019-12-20
# nan
# 2019-12-21
# nan
# nan
# nan
# 2019-12-21
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2019-12-21
# nan
# nan
# nan
# 2019-12-21
# nan
# 2019-12-22
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2019-12-22
# nan
# 2019-12-23
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2019-12-23
# nan
# nan
# nan
# nan
# nan
# 2019-12-23
# nan
# 2019-12-25
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2019-12-25
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2019-12-25
# nan
# nan
# nan
# nan
# nan
# nan
# 2019-12-26
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2019-12-26
# nan
# nan
# nan
# nan
# nan
# 2019-12-26
# nan
# 2019-12-27
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2019-12-27
# nan
# nan
# nan
# nan
# 2019-12-28
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2019-12-28
# nan
# nan
# nan
# nan
# 2019-12-28
# nan
# 2019-12-28
# nan
# 2019-12-29
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2019-12-30
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2019-12-30
# nan
# nan
# 2019-12-30
# nan
# nan
# nan
# nan
# nan
# nan
# 2019-12-31
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2019-12-31
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-01-01
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-01-01
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-01-02
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-01-02
# nan
# nan
# 2020-01-02
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-01-03
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-01-03
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-01-04
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-01-04
# nan
# nan
# 2020-01-04
# nan
# 2020-01-04
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-01-05
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-01-05
# nan
# nan
# nan
# 2020-01-06
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-01-06
# nan
# nan
# nan
# nan
# nan
# 2020-01-06
# nan
# nan
# 2020-01-07
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-01-07
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-01-07
# nan
# nan
# 2020-01-08
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-01-08
# nan
# nan
# nan
# nan
# nan
# 2020-01-08
# nan
# nan
# nan
# 2020-01-10
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-01-10
# nan
# nan
# nan
# nan
# nan
# 2020-01-10
# nan
# nan
# 2020-01-10
# nan
# nan
# 2020-01-11
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-01-11
# nan
# nan
# nan
# 2020-01-11
# nan
# 2020-01-12
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-01-12
# nan
# nan
# 2020-01-12
# nan
# nan
# nan
# nan
# nan
# 2020-01-13
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-01-13
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-01-13
# nan
# nan
# 2020-01-14
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-01-14
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-01-14
# nan
# nan
# 2020-01-15
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-01-15
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-01-15
# nan
# nan
# 2020-01-16
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-01-16
# nan
# nan
# nan
# nan
# nan
# 2020-01-16
# nan
# nan
# 2020-01-17
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-01-17
# nan
# nan
# nan
# nan
# 2020-01-18
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-01-18
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-01-18
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-01-18
# nan
# 2020-01-19
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-01-20
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-01-20
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-01-20
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-01-20
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-01-22
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-01-22
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-01-22
# nan
# 2020-01-22
# nan
# 2020-01-23
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-01-23
# nan
# nan
# nan
# 2020-01-24
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-01-24
# nan
# nan
# nan
# nan
# nan
# 2020-01-25
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-01-25
# nan
# 2020-01-26
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-01-26
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-01-27
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-01-27
# nan
# nan
# nan
# nan
# nan
# 2020-01-28
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-01-28
# nan
# nan
# nan
# 2020-01-28
# nan
# nan
# 2020-01-29
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-01-29
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-01-29
# nan
# nan
# nan
# 2020-01-30
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-01-30
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-01-30
# nan
# nan
# 2020-01-31
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-01-31
# nan
# nan
# 2020-01-31
# nan
# nan
# nan
# nan
# 2020-02-01
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-02-01
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-02-01
# nan
# 2020-02-01
# nan
# 2020-02-02
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-02-03
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-02-03
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-02-03
# nan
# nan
# nan
# 2020-02-04
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-02-04
# nan
# nan
# nan
# nan
# nan
# 2020-02-05
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-02-05
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-02-05
# nan
# nan
# nan
# 2020-02-05
# nan
# 2020-02-06
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-02-06
# nan
# nan
# 2020-02-06
# nan
# nan
# nan
# nan
# nan
# 2020-02-07
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-02-07
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-02-07
# nan
# nan
# 2020-02-08
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-02-08
# nan
# nan
# nan
# nan
# 2020-02-08
# nan
# 2020-02-08
# nan
# 2020-02-09
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-02-09
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-02-10
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-02-10
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-02-10
# nan
# 2020-02-10
# nan
# 2020-02-11
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-02-11
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-02-12
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-02-12
# nan
# nan
# nan
# 2020-02-12
# nan
# nan
# 2020-02-12
# nan
# 2020-02-13
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-02-20
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-02-20
# nan
# nan
# 2020-02-20
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-02-21
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-02-21
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-02-21
# nan
# nan
# 2020-02-21
# nan
# 2020-02-22
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-02-22
# nan
# nan
# nan
# nan
# nan
# 2020-02-22
# nan
# 2020-02-23
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-02-23
# nan
# 2020-02-23
# nan
# 2020-02-24
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-02-24
# nan
# nan
# nan
# nan
# nan
# 2020-02-24
# nan
# 2020-02-25
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-02-25
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-02-25
# nan
# nan
# nan
# 2020-02-26
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-02-26
# nan
# nan
# nan
# nan
# 2020-02-26
# nan
# nan
# 2020-02-26
# nan
# nan
# 2020-02-27
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-02-27
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-02-28
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-02-28
# nan
# nan
# 2020-02-28
# nan
# 2020-02-28
# nan
# nan
# nan
# nan
# 2020-02-29
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-02-29
# nan
# nan
# nan
# nan
# 2020-02-29
# nan
# 2020-03-01
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-03-01
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-03-01
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-03-02
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-03-02
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-03-02
# nan
# 2020-03-03
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-03-03
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-03-03
# nan
# 2020-03-03
# nan
# 2020-03-04
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-03-04
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-03-04
# nan
# nan
# 2020-03-05
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-03-05
# nan
# nan
# nan
# nan
# nan
# 2020-03-06
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-03-06
# nan
# nan
# nan
# 2020-03-06
# nan
# 2020-03-07
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-03-07
# nan
# nan
# nan
# 2020-03-07
# nan
# 2020-03-08
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-03-08
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-03-08
# nan
# nan
# nan
# nan
# nan
# 2020-03-08
# nan
# 2020-03-09
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-03-09
# nan
# nan
# nan
# nan
# nan
# 2020-03-10
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-03-10
# nan
# nan
# nan
# nan
# nan
# nan
# 2020-03-10
# nan
# nan
# 2020-03-11
# ERROR
# 2020-03-11
# nan

# %% [markdown]
# Plot overall PNL.

# %%
fig = plt.figure(1, figsize=(30, 15))

# overall PNL
temp = results.copy()
temp['PNL'] = temp['PRIZE'] - temp['ENTRY_FEE']
pnl = temp.groupby(['DATE']).apply(
    lambda x: pd.Series({
        'ENTRY_FEE': x['ENTRY_FEE'].sum(),
        'PRIZE': x['PRIZE'].sum(),
        'PNL': x['PNL'].sum()
    })
).reset_index()
pnl['RUNNING_PNL'] = pnl['PNL'].cumsum()

pnl['COLOR'] = pnl['PNL'].apply(lambda x: 'green' if x > 0 else 'red')
ax1 = sns.barplot(x=pnl.index, y='PNL', data=pnl, palette=pnl['COLOR'])
ax1.set_title('Overall PNL', fontsize=28)

xcoords = {
    pnl.index.min(): ('2017-18 SEASON START', 'k'),
    pnl.index[pnl['DATE'] == '2018-02-08'][0]: ('2017-18 SEASON TRADE DEADLINE', 'm'),
    pnl.index[pnl['DATE'] == '2018-02-22'][0]: ('2017-18 SEASON ALL-STAR RETURN', 'y'),
    pnl.index[pnl['DATE'] == '2018-10-19'][0]: ('2018-19 SEASON START', 'k'),
    pnl.index[pnl['DATE'] == '2019-02-07'][0]: ('2018-19 SEASON TRADE DEADLINE', 'm'),
    pnl.index[pnl['DATE'] == '2019-02-21'][0]: ('2018-19 SEASON ALL-STAR RETURN', 'y'),
    pnl.index[pnl['DATE'] == '2019-10-25'][0]: ('2019-20 SEASON START', 'k'),
    pnl.index[pnl['DATE'] == '2020-02-06'][0]: ('2019-20 SEASON TRADE DEADLINE', 'm'),
    pnl.index[pnl['DATE'] == '2020-02-20'][0]: ('2019-20 SEASON ALL-STAR RETURN', 'y'),
    
}
for xcoord in xcoords:
    ax1.axvline(x=xcoord, label=xcoords[xcoord][0], color=xcoords[xcoord][1], linestyle='dashed')
ax1.legend(bbox_to_anchor=(1, 1.35), loc='upper right', prop={'size': 16})

ax2 = ax1.twinx()
sns.lineplot(x=pnl.index, y='RUNNING_PNL', data=pnl, sort=False, color='tab:blue', ax=ax2)

ax1.set_xlabel('Date', fontsize=22)
ax1.set_ylabel('Daily PNL', fontsize=22)
ax2.set_ylabel('Cumulative PNL', fontsize=22)
ax1.set_xticks([])

ax1.tick_params(axis='both', labelsize=16)
ax2.tick_params(axis='both', labelsize=16)

plt.show()

# %% [markdown]
# Break down ROI by contest type, entry fee, and number of games in the slate to determine where my projections generate the most return on investment.

# %%
fig = plt.figure(1, figsize=(40, 30))
gs = fig.add_gridspec(2, 3)

# ROI vs. Entry Fee
temp = results.copy()
temp['ENTRY_BIN'] = pd.cut(temp['ENTRY_FEE'], bins=[0, 5, 10, 25, 50, 100, 250], duplicates='drop')
pnl = temp.groupby(['DATE', 'ENTRY_BIN']).apply(
    lambda x: pd.Series({
        'ENTRY_FEE': x['ENTRY_FEE'].sum(),
        'PRIZE': x['PRIZE'].sum()
    })
).reset_index()
pnl = pnl.merge(boxscores[['DATE', 'SEASON']], on=['DATE'], how='left')
pnl['ROI'] = (pnl['PRIZE'] - pnl['ENTRY_FEE'])/pnl['ENTRY_FEE']

ax4 = fig.add_subplot(gs[1, 0])
sns.barplot(x="ENTRY_BIN", y="ROI", hue="SEASON", data=pnl, ax=ax4)
ax4.set(xlabel="Entry Fee", ylabel="Return on Investment", title="Cash ROI vs. Entry Fee")
ax4.legend()

# ROI vs. Game Count
temp = results.copy()
temp['GAME_BIN'] = pd.cut(temp['GAME_COUNT'], bins=[0, 3, 6, 9, 15], duplicates='drop')
pnl = temp.groupby(['DATE', 'GAME_BIN']).apply(
    lambda x: pd.Series({
        'ENTRY_FEE': x['ENTRY_FEE'].sum(),
        'PRIZE': x['PRIZE'].sum()
    })
).reset_index()
pnl = pnl.merge(boxscores[['DATE', 'SEASON']], on=['DATE'], how='left')
pnl['ROI'] = (pnl['PRIZE'] - pnl['ENTRY_FEE'])/pnl['ENTRY_FEE']

ax5 = fig.add_subplot(gs[1, 1])
sns.barplot(x="GAME_BIN", y="ROI", hue="SEASON", data=pnl, ax=ax5)
ax5.set(xlabel="Number of Games in Slate", ylabel="Return on Investment", title="Cash ROI vs. Game Count")
ax5.legend()

# ROI vs. Entry Fee & Game Count
temp = results.copy()
temp['ENTRY_BIN'] = pd.cut(temp['ENTRY_FEE'], bins=[0, 5, 10, 25, 50, 100, 250], duplicates='drop')
temp['GAME_BIN'] = pd.cut(temp['GAME_COUNT'], bins=[0, 3, 6, 9, 15], duplicates='drop')
pnl = temp.groupby(['DATE', 'ENTRY_BIN', 'GAME_BIN']).apply(
    lambda x: pd.Series({
        'ENTRY_FEE': x['ENTRY_FEE'].sum(),
        'PRIZE': x['PRIZE'].sum()
    })
).reset_index()
pnl = pnl.merge(boxscores[['DATE', 'SEASON']], on=['DATE'], how='left')
pnl['ROI'] = (pnl['PRIZE'] - pnl['ENTRY_FEE'])/pnl['ENTRY_FEE']

ax6 = fig.add_subplot(gs[1, 2])
pnl['UPPER_ENTRY_FEE'] = pnl['ENTRY_BIN'].apply(lambda x: x.right)
pnl['UPPER_GAME_BIN'] = pnl['GAME_BIN'].apply(lambda x: x.right)
scat = pnl.groupby(['UPPER_GAME_BIN', 'UPPER_ENTRY_FEE']).apply(
    lambda x: pd.Series({
        'ROI': x['ROI'].mean()
    })
).reset_index()
sns.scatterplot(x='UPPER_ENTRY_FEE', y="UPPER_GAME_BIN", data=scat, hue='ROI', s=200, palette='coolwarm', ax=ax6)
ax6.set(xlabel="Entry Fee", ylabel="Number of Games in Slate", title="Cash ROI vs. Entry Fee & Game Count")
ax6.legend()

plt.show()

# %% [markdown]
# It is important not to overfit by cherry picking the contests in which the projections made money. To try to avoid this, I bucketed the entry fees and slate game counts. I will also only isolate a subset of contests if it makes sense why they were more profitable. The results above show that virtually no subset of cash games are profitable. On the other hand, tournaments whose entry fees are at most $1000 and slate game counts are at most 6 look profitable. This makes sense: higher entry contests attract more intelligent players, and high game slates introduce more variance.
#
# Below I will graph the cumulative PNL of a strategy that only enters contests in the subset described above. I will also include cash games whose entry fees are at most $25 and slate game counts are at most 3 to verify the lack of edge.

# %%
fig, plt.figure(1, figsize=(30, 15))

temp = results.loc[(results['GAME_COUNT'] <= 6)]
temp['PNL'] = temp['PRIZE'] - temp['ENTRY_FEE']
pnl = temp.groupby(['DATE']).apply(
    lambda x: pd.Series({
        'ENTRY_FEE': x['ENTRY_FEE'].sum(),
        'PRIZE': x['PRIZE'].sum(),
        'PNL': x['PNL'].sum()
    })
).reset_index()
pnl['RUNNING_PNL'] = pnl['PNL'].cumsum()

pnl['COLOR'] = pnl['PNL'].apply(lambda x: 'green' if x > 0 else 'red')
ax1 = sns.barplot(x=pnl.index, y='PNL', data=pnl, palette=pnl['COLOR'])
ax1.set_title('Tournament PNL', fontsize=28)

xcoords = {
    pnl.index.min(): ('2017-18 SEASON START', 'k'),
    pnl.index[pnl['DATE'] == '2018-02-08'][0]: ('2017-18 SEASON TRADE DEADLINE', 'm'),
    pnl.index[pnl['DATE'] == '2018-02-22'][0]: ('2017-18 SEASON ALL-STAR RETURN', 'y'),
    pnl.index[pnl['DATE'] == '2018-10-19'][0]: ('2018-19 SEASON START', 'k'),
    pnl.index[pnl['DATE'] == '2019-02-07'][0]: ('2018-19 SEASON TRADE DEADLINE', 'm'),
    pnl.index[pnl['DATE'] == '2019-02-21'][0]: ('2018-19 SEASON ALL-STAR RETURN', 'y'),
    pnl.index[pnl['DATE'] == '2019-10-25'][0]: ('2019-20 SEASON START', 'k'),
    pnl.index[pnl['DATE'] == '2020-02-06'][0]: ('2019-20 SEASON TRADE DEADLINE', 'm'),
    pnl.index[pnl['DATE'] == '2020-02-20'][0]: ('2019-20 SEASON ALL-STAR RETURN', 'y'),
    
}
for xcoord in xcoords:
    ax1.axvline(x=xcoord, color=xcoords[xcoord][1], linestyle='dashed')

ax2 = ax1.twinx()
sns.lineplot(x=pnl.index, y='RUNNING_PNL', data=pnl, sort=False, color='tab:blue', ax=ax2)

ax1.set_xlabel('Date', fontsize=22)
ax1.set_ylabel('Daily PNL', fontsize=22)
ax2.set_ylabel('Cumulative PNL', fontsize=22)
ax1.set_xticks([])

ax1.tick_params(axis='both', labelsize=16)
ax2.tick_params(axis='both', labelsize=16)

plt.show()

# %% [markdown]
# I will only focus on tournament contests going forward. The tournament strategy seems like it may actually be profitable. However, there is a lot of variance in PNL, as the cumulative PNL depends entirely on a few days in which it hit big. Most days the strategy loses money, and there are some significant drawdowns.
#
# Below shows the distribution of daily returns of this strategy.

# %%
temp = results.loc[(results['GAME_COUNT'] <= 6)]
temp['PNL'] = temp['PRIZE'] - temp['ENTRY_FEE']
pnl = temp.groupby(['DATE']).apply(
    lambda x: pd.Series({
        'ENTRY_FEE': x['ENTRY_FEE'].sum(),
        'PRIZE': x['PRIZE'].sum(),
        'PNL': x['PNL'].sum()
    })
).reset_index()
pnl['ROI'] = pnl['PNL']/pnl['ENTRY_FEE']
ax = sns.distplot(pnl['ROI'])
ax.set_title('PNL Distribution', fontsize=18)
plt.rcParams["figure.figsize"] = (20, 10)
plt.show()

print('ROI Statistics:')
pnl['ROI'].describe()
# Out:
# ROI Statistics:
# count    455.000000
# mean       0.333922
# std        2.484237
# min       -0.991577
# 25%       -0.625724
# 50%       -0.254949
# 75%        0.428801
# max       36.040069
# Name: ROI, dtype: float64

# %%
print(pnl['PRIZE'].mean())
print(pnl['ENTRY_FEE'].mean())
# Out:
# 3.827303302435907
# 316.33773482751377
