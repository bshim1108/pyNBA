# %% [markdown]
# # Backtest
# In this section, I will backtest an investment strategy that enters Draftkings DFS contests based on my player statistic projections. I *temporarily* limit the backtest to Draftkings contests due to the current lack of data on the historical results of DFS contests on other sites. The methods that determine which contests I will enter and the lineups that enter each contest will be explored in this notebook.

# %% [markdown]
# ## Setup
#
# Import the necessary libraries.

# %%
# for data
from pyNBA.Data.constants import ROTO_NAME_TO_NBA_NAME, DB_TEAM_TO_NBA_TEAM, BAD_CONTEST_SUBSTRINGS, OWNERSHIP_NAME_TO_NBA_NAME
from pyNBA.Data.data import QueryData
from pyNBA.Models.helpers import CleanData
import pandas as pd
import numpy as np
from numpy.random import normal
from datetime import datetime, timedelta

# for models
from pyNBA.DFS.rules import FPCalculator
from pyNBA.DFS.constants import Site
from pyNBA.Models.fantasy_points import FPModel
from pyNBA.Models.variance import VarianceModel
from pyNBA.Models.ownership import OwnershipModel
from pyNBA.Models.top_score import TopScoreModel
import pulp
from pydfs_lineup_optimizer.solvers.pulp_solver import PuLPSolver

# for backtesting
from pyNBA.Models.features import FeatureCreation
import time
from pydfs_lineup_optimizer import get_optimizer, Sport
from pydfs_lineup_optimizer import Player
from numpy.random import normal
from numpy.random import choice
import scipy.stats as st
import random
from random import sample
from collections import Counter
import bisect

# for plotting
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
# %matplotlib inline
from datetime import datetime
import seaborn as sns; sns.set()

# misc
import warnings
warnings.filterwarnings('ignore')
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %% [markdown]
# ## Data
# Collect all data necessary to perform the backtest.

# %%
query_data = QueryData()
clean_data = CleanData()

# pull boxscore data
boxscores = query_data.query_boxscore_data()

# we are only interested in the boxscores of healthy and non-resting players
boxscores = clean_data.drop_rows_player_injured(boxscores)
boxscores = clean_data.drop_rows_player_rest(boxscores)

# historical DFS salary data
salary_data = query_data.query_salary_data()
salary_data = salary_data.rename(columns={'POSITION': 'DFS_POSITION'})
salary_data['NAME'] = salary_data['PLAYER'].apply(clean_data.roto_name_to_nba_name)

# historical DFS contest data. I am only interested in predicting ownership in Classic GPP compeititions.
contest_data = query_data.query_contest_data()
contest_data['MAXROI'] = contest_data['TOPPRIZE']/contest_data['ENTRYFEE']
contest_data = contest_data.loc[
    (contest_data['SLATETYPE'] == 'Classic') & (contest_data['CASHLINE'] > 200) & (contest_data['MAXROI'] > 2) &
    (~contest_data['CONTESTNAME'].str.lower().str.contains('|'.join(BAD_CONTEST_SUBSTRINGS)))
].dropna(subset=['CASHLINE'])

# contest payout structure
contest_info = query_data.query_contest_info_data()

# historical player ownership
ownership_data = query_data.query_ownership_data()
ownership_data['NAME'] = ownership_data['PLAYERNAME'].apply(
    lambda x: x if x not in OWNERSHIP_NAME_TO_NBA_NAME else OWNERSHIP_NAME_TO_NBA_NAME[x]
    )

# historical vegas odds data
odds_data = query_data.query_odds_data()

# historical quarterly boxscore data
quarterly_boxscore_data = query_data.query_quarterly_boxscore_data()
# Out:
# /Users/brandonshimiaie/Projects/pyNBA/sqlite/db/nba.db
# 2.6.0

# %% [markdown]
# ## Strategy
# Determine viable contests and how to enter each contest.

# %% [markdown]
# Initilize data.

# %%
season_list = list(boxscores['SEASON'].unique())

# to calculate fantasy points
DKFPCalculator = FPCalculator(Site.DRAFTKINGS)

# isolate Draftkings salaries
boxscores['REB'] = boxscores['DREB'] + boxscores['OREB']
    
# optimize Draftkings NBA lineups
class CustomPuLPSolver(PuLPSolver):
    LP_SOLVER = pulp.GLPK_CMD(msg=0)
optimizer = get_optimizer(Site.DRAFTKINGS, Sport.BASKETBALL, solver=CustomPuLPSolver)

# %% [markdown]
# Helper Functions.

# %%
def get_contest_prize(contest_info, score):
    prize = contest_info.loc[contest_info['MINPOINTS'] <= score, 'PRIZE'].max()
    return prize

def get_complete_positions(position_list):
    if bool(set(position_list).intersection(['PG', 'SG'])):
        position_list.append('G')
    if bool(set(position_list).intersection(['SF', 'PF'])):
        position_list.append('F')
    position_list.append('U')
    return position_list

def first_valid_position(l1, l2):
    for i in l1:
        if i not in l2:
            return l2 | {i}
        
def get_n_opponent_generations(max_contest_total_entries):
    if max_contest_total_entries < 10000:
        return 3.5
    elif max_contest_total_entries < 50000:
        return 2.5
    elif max_contest_total_entries < 100000:
        return 1.5
    else: 
        return 1
    
def get_prizes(my_scores, opponent_scores, n_opponent_scores, rank_to_prize, entry_fee):
    my_prizes = []

    prev_rank = 0
    for my_score in my_scores:
        if prev_rank == n_opponent_scores:
            my_prizes.append(0 - entry_fee)
        else:
            rank = prev_rank + bisect.bisect_left(opponent_scores[prev_rank:], my_score)
            prize = rank_to_prize[rank+1] if rank+1 in rank_to_prize else 0
            my_prizes.append(prize - entry_fee)
            prev_rank = rank
    
    return my_prizes

# %% [markdown]
# Enter contests.

# %%
print(time.ctime())

max_entry_fee_per_contest = 1000
randomness_factor = 2
min_salary = 49200
salary_room = 1000
n_opponent_split = 3
max_n_samples = 5
n_simulations = 1000
timeout_minutes = 10

results = pd.DataFrame(columns = [
    'DATE', 'GAME_COUNT', 'CONTEST_TYPE', 'MAX_ENTRIES', 'TOTAL_ENTRIES',
    'ENTRY_FEE', 'CASHLINE', 'SCORE', 'TOP_SCORE', 'PRIZE', 'TOP_PRIZE'
])
pnl = 0

for i in range(1, len(season_list)):
    print(season_list[i])
    fp_train_data = boxscores.loc[boxscores['SEASON'].isin(season_list[0:i])]
    ownership_train_data = boxscores.loc[~(boxscores['SEASON'] == season_list[i])]
    test_data = boxscores.loc[boxscores['SEASON'] == season_list[i]]

    # projected contest top scores
    contest_test_data = contest_data.loc[
        (contest_data['DATE'] >= test_data['DATE'].min()) & (contest_data['DATE'] <= test_data['DATE'].max())
    ]
    contest_train_data = contest_data.loc[
        ~((contest_data['DATE'] >= test_data['DATE'].min()) & (contest_data['DATE'] <= test_data['DATE'].max()))
    ]
    if contest_test_data.empty:
        continue

    # projected fantasy points
    fp_model = FPModel(fp_train_data, test_data, Site.DRAFTKINGS)
    fp_model.train_model(quarterly_boxscore_data, odds_data)
    predictions, fp_hat_column = fp_model.predict()
    predictions = predictions.dropna(subset=[fp_hat_column])

    # actual fantasy points
    predictions['DKFP'] = predictions.apply(
        lambda x: DKFPCalculator.calculate_fantasy_points(
            x['SEASON'], x['PTS'], x['REB'], x['AST'], x['TOV'], x['BLK'], x['STL'], x['FG3M']
        ), 
        axis=1
    )

    # fantasy point variance
    variance_model = VarianceModel(predictions)
    predictions, variance_column = variance_model.predict('DKFP')
    pct_variance_column = 'RESIDUAL_PCT'
    predictions[pct_variance_column] = predictions[variance_column]/predictions[fp_hat_column]
    predictions[pct_variance_column] = predictions[pct_variance_column].replace([np.inf, -np.inf], np.nan)
    predictions[pct_variance_column] = predictions[pct_variance_column].fillna(0.35)
    predictions[pct_variance_column] = predictions[pct_variance_column].clip(lower=0.15)

    # projected ownership
    ownership_model = OwnershipModel(ownership_train_data, test_data, Site.DRAFTKINGS)
    ownership_model.create_features(salary_data, contest_data, ownership_data, odds_data)
    ownership_model.train_model()
    ownership_predictions, ownership_column = ownership_model.predict()

    # merge projections to data
    dk_salary_data = salary_data.loc[salary_data['SITE'] == Site.DRAFTKINGS]
    predictions = predictions.merge(dk_salary_data, on=['DATE', 'NAME'], how='left')
    predictions = predictions.dropna(subset=['SALARY', 'DFS_POSITION'])

    ownership_predictions = ownership_predictions.merge(
        predictions[['DATE', 'NAME', fp_hat_column, pct_variance_column, 'SALARY']],
        on=['DATE', 'NAME'], how='left'
    )

    print(time.ctime())

    # iterate through each slate in the season
    a = contest_test_data.loc[contest_test_data['TOTALENTRIES'] <= 250000].sort_values(by='DATE')
    for (date, slate_id), slate_contest_data in a.groupby(['DATE', 'SLATEID']):
        print(time.ctime(), date, slate_id)

        # get players in slate
        slate_teams = slate_contest_data.iloc[0]['TEAMS'].split('_')
        slate_teams = [i if i not in DB_TEAM_TO_NBA_TEAM else DB_TEAM_TO_NBA_TEAM[i] for i in slate_teams]
        board = predictions.loc[
            (predictions['DATE'] == date) &
            (predictions['TEAM'].isin(slate_teams))
        ]

        board_teams = list(board['TEAM'].unique())
        game_count = slate_contest_data.iloc[0]['GAMECOUNT']
        sym_dif = (set(board_teams).symmetric_difference(set(slate_teams)))
        if bool(sym_dif) or len(slate_teams) != game_count*2:
            print('ERROR: MISSING TEAM DATA')
            continue

        slate_ownership_predictions = ownership_predictions.loc[ownership_predictions['SLATEID'] == slate_id]
        slate_board = slate_ownership_predictions[['DATE', 'NAME', ownership_column]].merge(board, on=['DATE', 'NAME'], how='left')
        slate_board = slate_board.dropna(subset=['SALARY', 'DFS_POSITION', fp_hat_column, pct_variance_column, ownership_column])
        ownership_sum = slate_board[ownership_column].sum()
        slate_board[ownership_column] = slate_board[ownership_column].map(lambda x: 8*x/ownership_sum)
            
        # generate opponent lineups for slate
        max_contest_total_entries = slate_contest_data['TOTALENTRIES'].max()
        opponent_players = slate_board.loc[slate_board[ownership_column]*max_contest_total_entries >= 1]
        opponent_players['DFS_POSITIONS'] = opponent_players['DFS_POSITION'].map(lambda x: x.split('_'))
        opponent_players['DFS_POSITIONS'] = opponent_players['DFS_POSITIONS'].map(lambda x: get_complete_positions(x))

        player_counter = Counter()
        max_salary = opponent_players['SALARY'].max()
        n_opponent_generations = get_n_opponent_generations(max_contest_total_entries)
        n_rows = int(max_contest_total_entries/n_opponent_split)
        prev_n_valid_opponent_lineups = 0

        all_opponent_lineups = pd.DataFrame()
        min_lineups = n_opponent_generations*max_contest_total_entries
        end_time = datetime.now() + timedelta(minutes=timeout_minutes)
        while len(all_opponent_lineups) < min_lineups and datetime.now() < end_time:
            opponent_lineups = pd.DataFrame(
                {'PLAYERIDS': np.nan, 'SPOTS_REMAINING': 8, 'POSITIONS_FILLED': np.nan, 'SALARY_REMAINING': 50000},
                index = [i for i in range(n_rows)]
            )
            opponent_lineups['PLAYERIDS'] = [list()] * len(opponent_lineups)
            opponent_lineups['POSITIONS_FILLED'] = [set()] * len(opponent_lineups)
            n_opponent_lineups = len(opponent_lineups)
            
            if prev_n_valid_opponent_lineups == 0:
                opponent_players = opponent_players.sample(frac=1)
            else:
                opponent_players['COUNT'] = opponent_players['PLAYERID'].map(lambda x: player_counter[x])
                opponent_players['EXPECTED_COUNT'] = opponent_players[ownership_column]*len(all_opponent_lineups)
                opponent_players['REP'] = opponent_players['COUNT'] - opponent_players['EXPECTED_COUNT']
                opponent_players = opponent_players.sort_values(by='REP')
            for _, player in opponent_players.iterrows():
                valid_indexes = opponent_lineups.loc[
                    ~(opponent_lineups['POSITIONS_FILLED'].map(set(player['DFS_POSITIONS']).issubset)) &
                    (opponent_lineups['SALARY_REMAINING'] > player['SALARY']) & 
                    (opponent_lineups['SALARY_REMAINING'] - (opponent_lineups['SPOTS_REMAINING']-1)*max_salary - salary_room < player['SALARY'])
                ].index.to_list()
                n = len(valid_indexes)
                len_subset = int(min(n, (n_rows*player[ownership_column])))

                subset = sample(valid_indexes, len_subset)
                opponent_lineups.loc[subset, 'PLAYERIDS'] = opponent_lineups.loc[subset, 'PLAYERIDS'].map(lambda x: x + [player['PLAYERID']])
                opponent_lineups.loc[subset, 'SPOTS_REMAINING'] -= 1
                opponent_lineups.loc[subset, 'POSITIONS_FILLED'] = opponent_lineups.loc[subset, 'POSITIONS_FILLED'].map(
                    lambda x: first_valid_position(player['DFS_POSITIONS'], x)
                )  
                opponent_lineups.loc[subset, 'SALARY_REMAINING'] -= player['SALARY']

            valid_opponent_lineups = opponent_lineups.loc[opponent_lineups['SPOTS_REMAINING'] == 0]
            finished_lineups = valid_opponent_lineups['PLAYERIDS'].to_list()
            for lineup in finished_lineups:
                for player in lineup:
                    player_counter[player] += 1
            
            prev_n_valid_opponent_lineups = len(valid_opponent_lineups)
            all_opponent_lineups = all_opponent_lineups.append(valid_opponent_lineups)
            
        if len(all_opponent_lineups) < min_lineups:
            print('COULD NOT GENERATE {} OPPONENT LINEUPS'.format(min_lineups), time.ctime())
            continue

        print('GENERATED {} OPPONENT LINEUPS'.format(min_lineups), time.ctime())

        # generate potential lineups for slate
        players = []
        for _, player in slate_board.iterrows():
            player_id = player['PLAYERID']
            name = player['NAME'].split()
            first_name = name[0]
            last_name = name[1] if len(name) > 1 else ''
            positions = player['DFS_POSITION'].split('_')
            team = player['TEAM']
            mu = player[fp_hat_column]
            salary =  player['SALARY']
            std = player[pct_variance_column]*(1 - player[ownership_column])

            player = Player(player_id, first_name, last_name, positions, team, salary, mu, standard_deviation=std/randomness_factor)
            players.append(player)

        optimizer.load_players(players)
        optimizer.set_max_deviation(randomness_factor)
        optimizer.set_min_salary_cap(min_salary)

        total_max_entries = slate_contest_data['MAXENTRIES'].sum()
        n = int(max(2*total_max_entries, 400))
        lineups = optimizer.optimize(n=n, randomness=True)
        
        potential_lineups = pd.DataFrame()
        try:
            for lineup in lineups:
                player_ids = [i.id for i in lineup.lineup]
                real_score = slate_board.loc[slate_board['PLAYERID'].isin(player_ids), 'DKFP'].sum()
                potential_lineups = potential_lineups.append(
                    pd.DataFrame({'PLAYERIDS': [player_ids], 'REALSCORE': [real_score]})
                )
        except:
            print('ERROR: COULD NOT GENERATE LINEUPS')
            continue
            
        print('GENERATED {} POTENTIAL LINEUPS'.format(n), time.ctime())

        # iterate through each contest in the slate
        slate_contest_data = slate_contest_data.loc[
            (slate_contest_data['ENTRYFEE'] <= 250) & (slate_contest_data['ENTRYFEE'] > 1)
        ].sort_values(by='ENTRYFEE', ascending=False)
        for _, contest in slate_contest_data.iterrows():
            contest_id = contest['CONTESTID']
            contest_total_entries = contest['TOTALENTRIES']
            contest_max_entries = contest['MAXENTRIES']
            contest_entry_fee = contest['ENTRYFEE']
            
            result = {} 
            result['DATE'] = date
            result['GAME_COUNT'] = game_count
            result['MAX_ENTRIES'] = contest_max_entries
            result['TOTAL_ENTRIES'] = contest_total_entries
            result['ENTRY_FEE'] = contest_entry_fee
            result['CASHLINE'] = contest['CASHLINE']
            result['TOP_PRIZE'] = contest['TOPPRIZE']
            result['TOP_SCORE'] = contest['TOPSCORE']

            # simulate winnings
            entered_contest_info = contest_info.loc[contest_info['CONTESTID'] == contest_id]
            entered_contest_info['MINPOINTS'] = entered_contest_info['MINPOINTS'].fillna(0)
            rank_to_prize = {}
            prev_i = 0
            prev_prize = 0
            for _, row in entered_contest_info.loc[entered_contest_info['PRIZE'] > 0].iterrows():
                min_rank = int(row['MINRANK'])
                max_rank = int(row['MAXRANK'])
                prize = row['PRIZE']
                for i in range(prev_i+1, min_rank):
                    rank_to_prize[i] = (prize + prev_prize)/2
                for i in range(min_rank, max_rank+1):
                    rank_to_prize[i] = prize
                prev_i = i
                prev_prize = prize

            potential_lineups['WINNINGS'] = 0
            n_samples = int(min(max_n_samples, round(len(all_opponent_lineups)/contest_total_entries)))
            n_simulations_per_sample = int(n_simulations/n_samples)
            for i in range(n_samples):
                opponent_sample = all_opponent_lineups.sample(contest_total_entries)
                for i in range(n_simulations_per_sample):
                    slate_board['SAMPLE'] = slate_board[fp_hat_column]*(1 + normal(0, slate_board[pct_variance_column]))
                    player_performance = slate_board.set_index('PLAYERID')['SAMPLE'].to_dict()

                    opponent_sample['SAMPLE_SCORE'] = opponent_sample['PLAYERIDS'].map(lambda x: -1*sum([player_performance[i] for i in x]))
                    opponent_scores = np.sort(opponent_sample['SAMPLE_SCORE'].to_numpy())[:max_rank]

                    potential_lineups['SAMPLE_SCORE'] = potential_lineups['PLAYERIDS'].map(lambda x: -1*sum([player_performance[i] for i in x]))
                    potential_lineups = potential_lineups.sort_values(by='SAMPLE_SCORE')
                    my_scores = potential_lineups['SAMPLE_SCORE'].to_numpy()

                    prizes = get_prizes(my_scores, opponent_scores, max_rank, rank_to_prize, contest_entry_fee)
                    potential_lineups['WINNINGS'] += prizes

            # enter best lineups
            potential_lineups = potential_lineups.sort_values(by='WINNINGS', ascending=False)
            n_entries = int(min(contest_max_entries, max_entry_fee_per_contest/contest_entry_fee))
            best_lineups = potential_lineups.loc[potential_lineups['WINNINGS'] > 0].head(n_entries)
            n_best_lineups = len(best_lineups)
            potential_lineups = potential_lineups[n_best_lineups:]
            current_pnl = 0
            for _, lineup in best_lineups.iterrows():
                score = lineup['REALSCORE']
                prize = get_contest_prize(entered_contest_info, score)
                
                result['SCORE'] = score
                result['PRIZE'] = prize
                results = results.append(result, ignore_index=True)
                
                contest_pnl = prize - contest_entry_fee
                if not np.isnan(contest_pnl):
                    current_pnl += (prize - contest_entry_fee)

            pnl += current_pnl
            pnl = round(pnl, 2)
            print('{} ({})'.format(str(pnl), str(current_pnl)))
# Out:
# Tue Aug  4 22:49:20 2020
# 2015-16
# 2016-17
# 2017-18
# Tue Aug  4 23:25:16 2020
# Tue Aug  4 23:25:16 2020 2017-10-18 5ae4d5805689223dfa12d8ad
# ERROR: MISSING TEAM DATA
# Tue Aug  4 23:25:16 2020 2017-10-18 5ae4dbdb78af173dfeff7c39
# ERROR: MISSING TEAM DATA
# Tue Aug  4 23:25:16 2020 2017-10-18 5ae4e8b05689223dfa4d3bd7
# ERROR: MISSING TEAM DATA
# Tue Aug  4 23:25:16 2020 2017-10-19 5ae4d09dc074cf3dff3e3d91
# ERROR: MISSING TEAM DATA
# Tue Aug  4 23:25:16 2020 2017-10-19 5ae515ee589eaa73373fe802
# ERROR: MISSING TEAM DATA
# Tue Aug  4 23:25:16 2020 2017-10-20 5ae4cbe2c074cf3dff32fa1b
# GENERATED 95365.0 OPPONENT LINEUPS Tue Aug  4 23:27:16 2020
# GENERATED 500 POTENTIAL LINEUPS Tue Aug  4 23:27:40 2020
# 350.0 (350.0)
# 6465.0 (6115.0)
# 6591.77 (126.77000000000001)
# Tue Aug  4 23:28:35 2020 2017-10-20 5ae4d5895689223dfa12e192
# GENERATED 118905.0 OPPONENT LINEUPS Tue Aug  4 23:30:44 2020
# GENERATED 522 POTENTIAL LINEUPS Tue Aug  4 23:31:17 2020
# 6141.77 (-450.0)
# 5841.77 (-300.0)
# 5741.77 (-100.0)
# 5591.77 (-150.0)
# 5551.77 (-40.0)
# 5524.77 (-27.0)
# 5464.77 (-60.0)
# 5452.77 (-12.0)
# 5425.77 (-27.0)
# 5269.77 (-156.0)
# 4712.77 (-557.0)
# 4709.77 (-3.0)
# 4649.77 (-60.0)
# 4647.77 (-2.0)
# Tue Aug  4 23:32:54 2020 2017-10-20 5ae4e281f69c5a3e00465e39
# GENERATED 26008.5 OPPONENT LINEUPS Tue Aug  4 23:36:26 2020
# GENERATED 500 POTENTIAL LINEUPS Tue Aug  4 23:36:47 2020
# 4525.77 (-122.0)
# 4580.44 (54.67)
# Tue Aug  4 23:37:02 2020 2017-10-20 5ae5fabbfd67640e26d6e70b
# GENERATED 19869.5 OPPONENT LINEUPS Tue Aug  4 23:37:47 2020
# GENERATED 500 POTENTIAL LINEUPS Tue Aug  4 23:38:11 2020
# 4584.44 (4.0)
# Tue Aug  4 23:38:21 2020 2017-10-21 5ae4d389f69c5a3e001f7dcd
# GENERATED 110344 OPPONENT LINEUPS Tue Aug  4 23:40:01 2020
# GENERATED 1036 POTENTIAL LINEUPS Tue Aug  4 23:41:38 2020
# 4284.44 (-300.0)
# 3834.44 (-450.0)
# 3734.44 (-100.0)
# 3634.44 (-100.0)
# 3146.44 (-488.0)
# 2761.44 (-385.0)
# 2701.44 (-60.0)
# 2641.44 (-60.0)
# 2629.44 (-12.0)
# 2617.44 (-12.0)
# 2590.44 (-27.0)
# 2272.44 (-318.0)
# 2661.44 (389.0)
# 2640.2 (-21.240000000000002)
# 2592.2 (-48.0)
# 2583.2 (-9.0)
# 2581.2 (-2.0)
# Tue Aug  4 23:46:05 2020 2017-10-21 5ae4f17bd69dcc3dfd26e607
# GENERATED 57567.5 OPPONENT LINEUPS Tue Aug  4 23:47:12 2020
# GENERATED 500 POTENTIAL LINEUPS Tue Aug  4 23:47:35 2020
# 2831.2 (250.0)
# 3012.87 (181.67000000000002)
# 2980.87 (-32.0)
# Tue Aug  4 23:48:13 2020 2017-10-22 5ae4d673d69dcc3dfdee6e65
# GENERATED 37157.5 OPPONENT LINEUPS Tue Aug  4 23:49:50 2020
# GENERATED 500 POTENTIAL LINEUPS Tue Aug  4 23:50:12 2020
# 2883.87 (-97.0)
# 2827.87 (-56.0)
# 2765.87 (-62.0)
# 2703.87 (-62.0)
# Tue Aug  4 23:50:48 2020 2017-10-22 5ae4eb66f69c5a3e00636b22
# GENERATED 111472.5 OPPONENT LINEUPS Tue Aug  4 23:53:25 2020
# GENERATED 500 POTENTIAL LINEUPS Tue Aug  4 23:53:48 2020
# 2553.87 (-150.0)
# 2104.87 (-449.0)
# 1940.87 (-164.0)
# 1901.16 (-39.71)
# 1879.16 (-22.0)
# Tue Aug  4 23:55:03 2020 2017-10-23 5ae4ca6278af173dfed6b754
# GENERATED 118905.0 OPPONENT LINEUPS Tue Aug  4 23:56:42 2020
# GENERATED 520 POTENTIAL LINEUPS Tue Aug  4 23:57:15 2020
# 1429.16 (-450.0)
# 1129.16 (-300.0)
# 1029.16 (-100.0)
# 929.16 (-100.0)
# 854.16 (-75.0)
# 704.16 (-150.0)
# 644.16 (-60.0)
# 652.16 (8.0)
# 640.16 (-12.0)
# 613.16 (-27.0)
# -156.96 (-770.12)
# -203.96 (-47.0)
# -212.96 (-9.0)
# -214.96 (-2.0)
# Tue Aug  4 23:58:49 2020 2017-10-23 5ae4ca655689223dfafaeaf6
# GENERATED 64282.5 OPPONENT LINEUPS Wed Aug  5 00:00:21 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 00:00:44 2020
# -264.96 (-50.0)
# -276.96 (-12.0)
# Wed Aug  5 00:01:21 2020 2017-10-23 5ae4daef78af173dfefd620f
# GENERATED 23866.5 OPPONENT LINEUPS Wed Aug  5 00:01:47 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 00:02:08 2020
# -398.96 (-122.0)
# -478.96 (-80.0)
# Wed Aug  5 00:02:22 2020 2017-10-24 5ae4c90ec074cf3dff2f29c9
# GENERATED 118905.0 OPPONENT LINEUPS Wed Aug  5 00:03:53 2020
# GENERATED 612 POTENTIAL LINEUPS Wed Aug  5 00:04:31 2020
# -678.96 (-200.0)
# -628.96 (50.0)
# -203.96 (425.0)
# -278.96 (-75.0)
# -258.96 (20.0)
# 201.04 (460.0)
# 252.04 (51.0)
# 253.04 (1.0)
# 301.04 (48.0)
# 319.04 (18.0)
# 307.04 (-12.0)
# 345.04 (38.0)
# 1946.71 (1601.67)
# 1943.71 (-3.0)
# 1966.71 (23.0)
# 2036.71 (70.0)
# 2039.71 (3.0)
# 2103.71 (64.0)
# 2101.71 (-2.0)
# Wed Aug  5 00:06:28 2020 2017-10-24 5ae4dbd5c074cf3dff5b9ed0
# GENERATED 98037.5 OPPONENT LINEUPS Wed Aug  5 00:08:43 2020
# GENERATED 676 POTENTIAL LINEUPS Wed Aug  5 00:09:19 2020
# 2348.71 (247.0)
# 3408.71 (1060.0)
# 3258.71 (-150.0)
# 3549.71 (291.0)
# 3978.71 (429.0)
# Wed Aug  5 00:10:30 2020 2017-10-24 5ae50e3f5381987332de58e6
# GENERATED 16646.0 OPPONENT LINEUPS Wed Aug  5 00:11:05 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 00:11:27 2020
# 6032.21 (2053.5)
# Wed Aug  5 00:11:36 2020 2017-10-25 5ae4c910d69dcc3dfdd2b27b
# GENERATED 118905.0 OPPONENT LINEUPS Wed Aug  5 00:13:30 2020
# GENERATED 1660 POTENTIAL LINEUPS Wed Aug  5 00:16:50 2020
# 5582.21 (-450.0)
# 5132.21 (-450.0)
# 4832.21 (-300.0)
# 4732.21 (-100.0)
# 4632.21 (-100.0)
# 4482.21 (-150.0)
# 4332.21 (-150.0)
# 4372.21 (40.0)
# 4332.21 (-40.0)
# 3592.21 (-740.0)
# 3487.21 (-105.0)
# 3510.21 (23.0)
# 3490.21 (-20.0)
# 3470.21 (-20.0)
# 3410.21 (-60.0)
# 3398.21 (-12.0)
# 3406.21 (8.0)
# 3424.21 (18.0)
# 3049.77 (-374.44)
# 2835.77 (-214.0)
# 2462.77 (-373.0)
# 2075.77 (-387.0)
# 2070.77 (-5.0)
# 2026.27 (-44.5)
# 1655.27 (-371.0)
# 1610.27 (-45.0)
# 1606.27 (-4.0)
# 1604.27 (-2.0)
# Wed Aug  5 00:20:44 2020 2017-10-25 5ae4d1a3dd71203dfc4d2153
# GENERATED 26008.5 OPPONENT LINEUPS Wed Aug  5 00:21:38 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 00:22:01 2020
# 1454.27 (-150.0)
# 2097.27 (643.0)
# 2069.27 (-28.0)
# Wed Aug  5 00:22:19 2020 2017-10-25 5ae4dafaf69c5a3e003192a1
# GENERATED 91910.0 OPPONENT LINEUPS Wed Aug  5 00:24:17 2020
# GENERATED 860 POTENTIAL LINEUPS Wed Aug  5 00:25:07 2020
# 1919.27 (-150.0)
# 2166.27 (247.0)
# 3366.6 (1200.33)
# 3724.6 (358.0)
# 4138.93 (414.33)
# 4291.33 (152.4)
# 4257.33 (-34.0)
# 4223.33 (-34.0)
# 4226.08 (2.75)
# Wed Aug  5 00:26:42 2020 2017-10-26 5ae4c91c95356d3dfb3930f8
# GENERATED 97220.0 OPPONENT LINEUPS Wed Aug  5 00:28:15 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 00:28:36 2020
# 4076.08 (-150.0)
# 3793.08 (-283.0)
# 3540.99 (-252.09)
# 3514.99 (-26.0)
# Wed Aug  5 00:29:43 2020 2017-10-26 5ae4cfd9dd71203dfc48cdbf
# GENERATED 118905.0 OPPONENT LINEUPS Wed Aug  5 00:31:33 2020
# GENERATED 648 POTENTIAL LINEUPS Wed Aug  5 00:32:12 2020
# 3064.99 (-450.0)
# 2614.99 (-450.0)
# 2514.99 (-100.0)
# 2364.99 (-150.0)
# 2324.99 (-40.0)
# 1631.99 (-693.0)
# 1654.99 (23.0)
# 1624.99 (-30.0)
# 1564.99 (-60.0)
# 1552.99 (-12.0)
# 1540.99 (-12.0)
# 1513.99 (-27.0)
# 1357.99 (-156.0)
# 463.99 (-894.0)
# 459.99 (-4.0)
# 399.99 (-60.0)
# 397.99 (-2.0)
# Wed Aug  5 00:34:08 2020 2017-10-27 5ae4d4a295356d3dfb51c91f
# GENERATED 91910.0 OPPONENT LINEUPS Wed Aug  5 00:35:51 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 00:36:13 2020
# 247.99 (-150.0)
# 185.99 (-62.0)
# 12.99 (-173.0)
# -361.61 (-374.6)
# -354.07 (7.539999999999996)
# Wed Aug  5 00:37:20 2020 2017-10-27 5ae4e5fff69c5a3e005003d5
# GENERATED 20807.5 OPPONENT LINEUPS Wed Aug  5 00:38:04 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 00:38:27 2020
# -1021.07 (-667.0)
# Wed Aug  5 00:38:36 2020 2017-10-27 5ae4f8aa5689223dfa81bfec
# GENERATED 118905.0 OPPONENT LINEUPS Wed Aug  5 00:40:42 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 00:41:11 2020
# -1471.07 (-450.0)
# -1571.07 (-100.0)
# -1671.07 (-100.0)
# -1711.07 (-40.0)
# -1738.07 (-27.0)
# -1798.07 (-60.0)
# -1810.07 (-12.0)
# -1837.07 (-27.0)
# -2726.07 (-889.0)
# -2729.07 (-3.0)
# -2766.07 (-37.0)
# -2770.07 (-4.0)
# -2772.07 (-2.0)
# Wed Aug  5 00:42:53 2020 2017-10-28 5ae4cabec074cf3dff31351b
# GENERATED 124851.0 OPPONENT LINEUPS Wed Aug  5 00:44:48 2020
# GENERATED 1200 POTENTIAL LINEUPS Wed Aug  5 00:46:42 2020
# -3222.07 (-450.0)
# -3322.07 (-100.0)
# -2872.07 (450.0)
# -3672.07 (-800.0)
# -3699.07 (-27.0)
# -3726.07 (-27.0)
# -3736.07 (-10.0)
# -3748.07 (-12.0)
# -3742.07 (6.0)
# -3754.07 (-12.0)
# -4384.89 (-630.8199999999999)
# -4745.18 (-360.28999999999996)
# -4750.18 (-5.0)
# -4741.18 (9.0)
# -4750.18 (-9.0)
# -4780.18 (-30.0)
# -4782.18 (-2.0)
# Wed Aug  5 00:50:30 2020 2017-10-28 5ae4eb6f5689223dfa563b20
# GENERATED 55145.0 OPPONENT LINEUPS Wed Aug  5 00:51:23 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 00:51:45 2020
# -4966.18 (-184.0)
# -5560.53 (-594.35)
# -5608.53 (-48.0)
# -5632.53 (-24.0)
# Wed Aug  5 00:52:29 2020 2017-10-28 5ae512af085a6773356ab662
# GENERATED 10293.5 OPPONENT LINEUPS Wed Aug  5 00:53:00 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 00:53:21 2020
# -4368.15 (1264.38)
# -4289.65 (78.5)
# Wed Aug  5 00:53:33 2020 2017-10-29 5ae4cef95689223dfa02f3a7
# GENERATED 118905.0 OPPONENT LINEUPS Wed Aug  5 00:55:25 2020
# GENERATED 966 POTENTIAL LINEUPS Wed Aug  5 00:56:37 2020
# -4439.65 (-150.0)
# -4589.65 (-150.0)
# -5109.65 (-520.0)
# -5149.65 (-40.0)
# -5189.65 (-40.0)
# -5201.65 (-12.0)
# -5228.65 (-27.0)
# -5303.65 (-75.0)
# -5683.65 (-380.0)
# -5701.15 (-17.5)
# -5647.15 (54.0)
# Wed Aug  5 00:58:37 2020 2017-10-29 5ae51523589eaa73373d82a0
# GENERATED 25732.0 OPPONENT LINEUPS Wed Aug  5 00:59:38 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 01:00:00 2020
# -5706.15 (-59.0)
# -5853.15 (-147.0)
# -6693.15 (-840.0)
# Wed Aug  5 01:00:20 2020 2017-10-29 5ae6045cfd67640e26f38b1c
# GENERATED 25732.0 OPPONENT LINEUPS Wed Aug  5 01:01:15 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 01:01:37 2020
# -6407.44 (285.71)
# Wed Aug  5 01:01:49 2020 2017-10-30 5ae4c91ff69c5a3e00128218
# GENERATED 118905.0 OPPONENT LINEUPS Wed Aug  5 01:04:03 2020
# GENERATED 1210 POTENTIAL LINEUPS Wed Aug  5 01:06:04 2020
# -6857.44 (-450.0)
# -6907.44 (-50.0)
# -6207.44 (700.0)
# -6257.44 (-50.0)
# -6407.44 (-150.0)
# -6447.44 (-40.0)
# -6487.44 (-40.0)
# -6467.44 (20.0)
# -7327.44 (-860.0)
# -7527.44 (-200.0)
# -7554.44 (-27.0)
# -7546.44 (8.0)
# -7558.44 (-12.0)
# -7502.44 (56.0)
# -8097.32 (-594.88)
# -8545.32 (-448.0)
# -8938.32 (-393.0)
# -8947.32 (-9.0)
# -8992.32 (-45.0)
# -8994.32 (-2.0)
# Wed Aug  5 01:08:24 2020 2017-10-30 5ae4d74078af173dfef5c87f
# GENERATED 20807.5 OPPONENT LINEUPS Wed Aug  5 01:08:47 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 01:09:11 2020
# -9706.32 (-712.0)
# Wed Aug  5 01:09:20 2020 2017-10-30 5ae50093d69dcc3dfd4acde6
# GENERATED 55145.0 OPPONENT LINEUPS Wed Aug  5 01:10:52 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 01:11:14 2020
# -9716.32 (-10.0)
# -9694.92 (21.4)
# -9747.92 (-53.0)
# Wed Aug  5 01:11:51 2020 2017-10-31 5ae4ce0e0f94ac3e01848b76
# GENERATED 118905.0 OPPONENT LINEUPS Wed Aug  5 01:14:17 2020
# GENERATED 982 POTENTIAL LINEUPS Wed Aug  5 01:15:27 2020
# -9897.92 (-150.0)
# -7697.92 (2200.0)
# -7597.92 (100.0)
# -7637.92 (-40.0)
# -7577.92 (60.0)
# -785.92 (6792.0)
# -812.92 (-27.0)
# -839.92 (-27.0)
# -824.92 (15.0)
# -836.92 (-12.0)
# -848.92 (-12.0)
# -765.92 (83.0)
# 569.41 (1335.33)
# 576.91 (7.5)
# 662.41 (85.5)
# 1134.41 (472.0)
# 1084.41 (-50.0)
# 1090.41 (6.0)
# 1087.41 (-3.0)
# 1085.41 (-2.0)
# Wed Aug  5 01:17:31 2020 2017-10-31 5ae51c44589eaa7337532963
# GENERATED 36762.5 OPPONENT LINEUPS Wed Aug  5 01:18:32 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 01:18:54 2020
# 1002.41 (-83.0)
# 1646.24 (643.8299999999999)
# 1601.1 (-45.139999999999986)
# Wed Aug  5 01:19:23 2020 2017-11-01 5ae4ce11dd71203dfc44abc1
# GENERATED 118905.0 OPPONENT LINEUPS Wed Aug  5 01:21:02 2020
# GENERATED 1030 POTENTIAL LINEUPS Wed Aug  5 01:22:46 2020
# 1801.1 (200.0)
# 4351.1 (2550.0)
# 4251.1 (-100.0)
# 4076.1 (-175.0)
# 4036.1 (-40.0)
# 4081.1 (45.0)
# 3868.1 (-213.0)
# 4387.1 (519.0)
# 4360.1 (-27.0)
# 4330.1 (-30.0)
# 4318.1 (-12.0)
# 4306.1 (-12.0)
# 4294.1 (-12.0)
# 4372.1 (78.0)
# 5494.52 (1122.42)
# 5403.52 (-91.0)
# 5379.12 (-24.4)
# 5374.12 (-5.0)
# 5371.12 (-3.0)
# 5564.12 (193.0)
# 5555.12 (-9.0)
# 5553.12 (-2.0)
# Wed Aug  5 01:25:09 2020 2017-11-01 5ae4d275c074cf3dff42ffa1
# GENERATED 24969.0 OPPONENT LINEUPS Wed Aug  5 01:26:10 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 01:26:34 2020
# 5238.12 (-315.0)
# Wed Aug  5 01:26:41 2020 2017-11-01 5ae4e8ead69dcc3dfd1104cf
# GENERATED 55145.0 OPPONENT LINEUPS Wed Aug  5 01:28:51 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 01:29:14 2020
# 5088.12 (-150.0)
# 4868.12 (-220.0)
# 7427.45 (2559.33)
# Wed Aug  5 01:29:50 2020 2017-11-02 5ae4c9255689223dfaf87e3e
# GENERATED 118905.0 OPPONENT LINEUPS Wed Aug  5 01:31:45 2020
# GENERATED 790 POTENTIAL LINEUPS Wed Aug  5 01:32:30 2020
# 6977.45 (-450.0)
# 6877.45 (-100.0)
# 6837.45 (-40.0)
# 6812.45 (-25.0)
# 6800.45 (-12.0)
# 6788.45 (-12.0)
# 6926.45 (138.0)
# 7581.95 (655.5)
# 7606.95 (25.0)
# 9820.45 (2213.5)
# 9781.45 (-39.0)
# 9772.45 (-9.0)
# 9773.16 (0.7100000000000009)
# 9771.16 (-2.0)
# Wed Aug  5 01:34:00 2020 2017-11-03 5ae4c925f69c5a3e001286bf
# GENERATED 118905.0 OPPONENT LINEUPS Wed Aug  5 01:35:38 2020
# GENERATED 618 POTENTIAL LINEUPS Wed Aug  5 01:36:30 2020
# 9321.16 (-450.0)
# 8871.16 (-450.0)
# 8771.16 (-100.0)
# 8621.16 (-150.0)
# 8546.16 (-75.0)
# 8586.16 (40.0)
# 8421.16 (-165.0)
# 7828.16 (-593.0)
# 7801.16 (-27.0)
# 7741.16 (-60.0)
# 7729.16 (-12.0)
# 7702.16 (-27.0)
# 7013.16 (-689.0)
# 6912.16 (-101.0)
# 6907.16 (-5.0)
# 6847.16 (-60.0)
# 6785.16 (-62.0)
# 6753.16 (-32.0)
# 6750.16 (-3.0)
# 6748.16 (-2.0)
# Wed Aug  5 01:38:39 2020 2017-11-03 5ae4d4a95689223dfa113b10
# GENERATED 73527.5 OPPONENT LINEUPS Wed Aug  5 01:40:36 2020
# GENERATED 536 POTENTIAL LINEUPS Wed Aug  5 01:41:00 2020
# 6848.16 (100.0)
# 6593.16 (-255.0)
# 6124.13 (-469.03)
# 6128.13 (4.0)
# 6089.13 (-39.0)
# 6051.13 (-38.0)
# Wed Aug  5 01:42:01 2020 2017-11-03 5ae517a0589eaa7337433d68
# GENERATED 12866.0 OPPONENT LINEUPS Wed Aug  5 01:42:25 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 01:42:46 2020
# 5886.13 (-165.0)
# 5339.13 (-547.0)
# Wed Aug  5 01:42:57 2020 2017-11-04 5ae4c9c35689223dfaf9e94e
# GENERATED 77205.0 OPPONENT LINEUPS Wed Aug  5 01:44:49 2020
# GENERATED 1186 POTENTIAL LINEUPS Wed Aug  5 01:46:26 2020
# 5039.13 (-300.0)
# 4589.13 (-450.0)
# 4489.13 (-100.0)
# 3856.13 (-633.0)
# 3691.13 (-165.0)
# 3664.13 (-27.0)
# 3604.13 (-60.0)
# 3592.13 (-12.0)
# 3316.63 (-275.5)
# 3363.63 (47.0)
# 3366.63 (3.0)
# 3362.63 (-4.0)
# 3302.63 (-60.0)
# 3262.63 (-40.0)
# 3265.63 (3.0)
# Wed Aug  5 01:49:56 2020 2017-11-04 5ae4cfd5d69dcc3dfde16070
# GENERATED 36762.5 OPPONENT LINEUPS Wed Aug  5 01:51:13 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 01:51:37 2020
# 2935.63 (-330.0)
# 2493.06 (-442.57)
# 2471.06 (-22.0)
# Wed Aug  5 01:52:06 2020 2017-11-05 5ae4ca8dd69dcc3dfdd5e728
# GENERATED 7717.5 OPPONENT LINEUPS Wed Aug  5 01:52:34 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 01:52:56 2020
# 2337.31 (-133.75)
# Wed Aug  5 01:53:02 2020 2017-11-05 5ae4d1ab95356d3dfb4b8af6
# GENERATED 27572.5 OPPONENT LINEUPS Wed Aug  5 01:53:46 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 01:54:07 2020
# 2389.31 (52.0)
# 2260.31 (-129.0)
# 1506.26 (-754.05)
# 1461.26 (-45.0)
# Wed Aug  5 01:54:36 2020 2017-11-05 5ae4d284c074cf3dff431c45
# GENERATED 82720.0 OPPONENT LINEUPS Wed Aug  5 01:56:10 2020
# GENERATED 820 POTENTIAL LINEUPS Wed Aug  5 01:57:15 2020
# 1011.26 (-450.0)
# 861.26 (-150.0)
# 21.26 (-840.0)
# -143.74 (-165.0)
# -155.74 (-12.0)
# -1053.74 (-898.0)
# -1595.24 (-541.5)
# -1607.24 (-12.0)
# -1643.24 (-36.0)
# -1678.24 (-35.0)
# Wed Aug  5 01:59:07 2020 2017-11-05 5ae4d5955689223dfa1300d7
# GENERATED 36762.5 OPPONENT LINEUPS Wed Aug  5 01:59:57 2020
# GENERATED 526 POTENTIAL LINEUPS Wed Aug  5 02:00:21 2020
# -1793.24 (-115.0)
# -2415.24 (-622.0)
# -2739.24 (-324.0)
# Wed Aug  5 02:00:52 2020 2017-11-06 5ae4c92d78af173dfed466b3
# GENERATED 118905.0 OPPONENT LINEUPS Wed Aug  5 02:02:59 2020
# GENERATED 518 POTENTIAL LINEUPS Wed Aug  5 02:03:24 2020
# -889.24 (1850.0)
# -189.24 (700.0)
# -89.24 (100.0)
# 510.76 (600.0)
# 470.76 (-40.0)
# 530.76 (60.0)
# 2302.76 (1772.0)
# 2345.76 (43.0)
# 2318.76 (-27.0)
# 2318.76 (0.0)
# 2381.76 (63.0)
# 2389.76 (8.0)
# 2831.76 (442.0)
# 2827.76 (-4.0)
# 2873.76 (46.0)
# 2880.76 (7.0)
# 2885.76 (5.0)
# Wed Aug  5 02:04:52 2020 2017-11-06 5ae4e3bbc074cf3dff707cf1
# GENERATED 51165.0 OPPONENT LINEUPS Wed Aug  5 02:05:38 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 02:06:00 2020
# 2865.76 (-20.0)
# 3173.76 (308.0)
# 3170.76 (-3.0)
# Wed Aug  5 02:06:36 2020 2017-11-07 5ae4ce5778af173dfedf4cb6
# GENERATED 118905.0 OPPONENT LINEUPS Wed Aug  5 02:08:03 2020
# GENERATED 628 POTENTIAL LINEUPS Wed Aug  5 02:08:53 2020
# 2720.76 (-450.0)
# 2270.76 (-450.0)
# 2170.76 (-100.0)
# 1970.76 (-200.0)
# 1820.76 (-150.0)
# 1670.76 (-150.0)
# 1630.76 (-40.0)
# 1432.76 (-198.0)
# 924.76 (-508.0)
# 897.76 (-27.0)
# 870.76 (-27.0)
# 995.76 (125.0)
# 983.76 (-12.0)
# 956.76 (-27.0)
# 815.76 (-141.0)
# 34.76 (-781.0)
# 29.76 (-5.0)
# 31.76 (2.0)
# -17.24 (-49.0)
# -57.24 (-40.0)
# -95.24 (-38.0)
# -97.24 (-2.0)
# Wed Aug  5 02:10:51 2020 2017-11-07 5ae4d0afc074cf3dff3e7853
# GENERATED 29130.5 OPPONENT LINEUPS Wed Aug  5 02:11:38 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 02:12:01 2020
# -717.24 (-620.0)
# Wed Aug  5 02:12:10 2020 2017-11-07 5ae4d75378af173dfef5cfb5
# GENERATED 73527.5 OPPONENT LINEUPS Wed Aug  5 02:13:46 2020
# GENERATED 536 POTENTIAL LINEUPS Wed Aug  5 02:14:11 2020
# -1212.24 (-495.0)
# -2134.24 (-922.0)
# -2310.24 (-176.0)
# -2384.24 (-74.0)
# -2458.24 (-74.0)
# Wed Aug  5 02:15:08 2020 2017-11-08 5ae4cc0c0f94ac3e01808d1a
# GENERATED 118905.0 OPPONENT LINEUPS Wed Aug  5 02:17:15 2020
# GENERATED 838 POTENTIAL LINEUPS Wed Aug  5 02:18:13 2020
# -2908.24 (-450.0)
# -3058.24 (-150.0)
# -2958.24 (100.0)
# -3108.24 (-150.0)
# -3148.24 (-40.0)
# -4088.24 (-940.0)
# -4656.24 (-568.0)
# -4804.24 (-148.0)
# -4791.24 (13.0)
# -4806.24 (-15.0)
# -4826.24 (-20.0)
# -4838.24 (-12.0)
# -5090.44 (-252.2)
# -5769.44 (-679.0)
# -5774.44 (-5.0)
# -5786.44 (-12.0)
# -5841.44 (-55.0)
# -5887.44 (-46.0)
# -5917.44 (-30.0)
# -5935.73 (-18.29)
# -5937.73 (-2.0)
# Wed Aug  5 02:20:18 2020 2017-11-08 5ae4f1bfd69dcc3dfd279719
# GENERATED 55145.0 OPPONENT LINEUPS Wed Aug  5 02:21:18 2020
# GENERATED 582 POTENTIAL LINEUPS Wed Aug  5 02:21:46 2020
# -6143.73 (-206.0)
# -6520.73 (-377.0)
# -6868.73 (-348.0)
# -6924.23 (-55.5)
# Wed Aug  5 02:22:32 2020 2017-11-09 5ae4c92e0f94ac3e017aba25
# GENERATED 20807.5 OPPONENT LINEUPS Wed Aug  5 02:23:15 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 02:23:39 2020
# -7200.66 (-276.43)
# Wed Aug  5 02:23:47 2020 2017-11-09 5ae4da4078af173dfefc1aee
# GENERATED 73840.0 OPPONENT LINEUPS Wed Aug  5 02:25:07 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 02:25:29 2020
# -7100.66 (100.0)
# -5691.99 (1408.67)
# -2510.74 (3181.25)
# -2523.74 (-13.0)
# Wed Aug  5 02:26:20 2020 2017-11-09 5ae4e6fec074cf3dff7a4bc7
# GENERATED 118905.0 OPPONENT LINEUPS Wed Aug  5 02:28:58 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 02:29:26 2020
# -2623.74 (-100.0)
# -2663.74 (-40.0)
# -2690.74 (-27.0)
# -2717.74 (-27.0)
# -2792.74 (-75.0)
# -2804.74 (-12.0)
# -2831.74 (-27.0)
# -2836.74 (-5.0)
# -2834.74 (2.0)
# -2884.74 (-50.0)
# -2879.74 (5.0)
# Wed Aug  5 02:30:25 2020 2017-11-10 5ae4c930d69dcc3dfdd30857
# GENERATED 118905.0 OPPONENT LINEUPS Wed Aug  5 02:32:21 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 02:32:53 2020
# -2679.74 (200.0)
# -2779.74 (-100.0)
# -2979.74 (-200.0)
# -3019.74 (-40.0)
# -3717.74 (-698.0)
# -3744.74 (-27.0)
# -3819.74 (-75.0)
# -3831.74 (-12.0)
# -3843.74 (-12.0)
# -3870.74 (-27.0)
# -3875.74 (-5.0)
# -3887.74 (-12.0)
# -3906.74 (-19.0)
# -3956.74 (-50.0)
# -3958.74 (-2.0)
# Wed Aug  5 02:34:07 2020 2017-11-10 5ae512c8589eaa73373353ac
# GENERATED 55007.5 OPPONENT LINEUPS Wed Aug  5 02:34:56 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 02:35:23 2020
# -4108.74 (-150.0)
# -4352.74 (-244.0)
# -5133.74 (-781.0)
# -5199.74 (-66.0)
# Wed Aug  5 02:36:04 2020 2017-11-10 5ae5f0a65641740e2337d423
# GENERATED 10293.5 OPPONENT LINEUPS Wed Aug  5 02:36:45 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 02:37:06 2020
# -5552.74 (-353.0)
# Wed Aug  5 02:37:13 2020 2017-11-11 5ae4c9cef69c5a3e00141c65
# GENERATED 36692.5 OPPONENT LINEUPS Wed Aug  5 02:38:34 2020
# GENERATED 1224 POTENTIAL LINEUPS Wed Aug  5 02:40:09 2020
# -5467.74 (85.0)
# -5682.74 (-215.0)
# -5847.74 (-165.0)
# -5897.74 (-50.0)
# -6127.74 (-230.0)
# -6275.74 (-148.0)
# -6922.74 (-647.0)
# -7301.74 (-379.0)
# -7897.74 (-596.0)
# -8467.74 (-570.0)
# -8739.04 (-271.3)
# Wed Aug  5 02:41:32 2020 2017-11-11 5ae50b53085a6773355861e0
# GENERATED 20772.5 OPPONENT LINEUPS Wed Aug  5 02:42:04 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 02:42:29 2020
# -8666.04 (73.0)
# Wed Aug  5 02:42:34 2020 2017-11-12 5ae4c931d69dcc3dfdd30962
# GENERATED 72822.5 OPPONENT LINEUPS Wed Aug  5 02:44:00 2020
# GENERATED 546 POTENTIAL LINEUPS Wed Aug  5 02:44:28 2020
# -9116.04 (-450.0)
# -8861.04 (255.0)
# -8873.04 (-12.0)
# -8954.29 (-81.25)
# -8956.29 (-2.0)
# -8959.29 (-3.0)
# Wed Aug  5 02:45:42 2020 2017-11-12 5ae4e4f2c074cf3dff7402c4
# GENERATED 25732.0 OPPONENT LINEUPS Wed Aug  5 02:46:24 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 02:46:47 2020
# -8233.29 (726.0)
# -7077.86 (1155.43)
# Wed Aug  5 02:47:03 2020 2017-11-13 5ae4cd7378af173dfedda265
# GENERATED 118905.0 OPPONENT LINEUPS Wed Aug  5 02:49:30 2020
# GENERATED 514 POTENTIAL LINEUPS Wed Aug  5 02:50:06 2020
# -7377.86 (-300.0)
# -7477.86 (-100.0)
# -7577.86 (-100.0)
# -7652.86 (-75.0)
# -7626.19 (26.67)
# -7666.19 (-40.0)
# -7847.19 (-181.0)
# -8440.19 (-593.0)
# -8342.19 (98.0)
# -8369.19 (-27.0)
# -8389.19 (-20.0)
# -8401.19 (-12.0)
# -8413.19 (-12.0)
# -8732.19 (-319.0)
# -8993.19 (-261.0)
# -8998.19 (-5.0)
# -9002.19 (-4.0)
# -9040.19 (-38.0)
# Wed Aug  5 02:51:26 2020 2017-11-13 5ae508f35aba697338af2729
# GENERATED 20807.5 OPPONENT LINEUPS Wed Aug  5 02:52:02 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 02:52:23 2020
# -9690.19 (-650.0)
# Wed Aug  5 02:52:31 2020 2017-11-13 5ae5239a5381987332084550
# GENERATED 69975.0 OPPONENT LINEUPS Wed Aug  5 02:53:45 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 02:54:07 2020
# -9905.19 (-215.0)
# -10352.19 (-447.0)
# -10356.19 (-4.0)
# Wed Aug  5 02:54:54 2020 2017-11-13 5ae607f43825540e24d06b4c
# GENERATED 20807.5 OPPONENT LINEUPS Wed Aug  5 02:56:05 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 02:56:26 2020
# -10631.55 (-275.36)
# Wed Aug  5 02:56:34 2020 2017-11-14 5ae4cd6ad69dcc3dfddc5962
# GENERATED 118905.0 OPPONENT LINEUPS Wed Aug  5 02:59:07 2020
# GENERATED 528 POTENTIAL LINEUPS Wed Aug  5 02:59:32 2020
# -11081.55 (-450.0)
# -11231.55 (-150.0)
# -11331.55 (-100.0)
# -11371.55 (-40.0)
# -11542.55 (-171.0)
# -11569.55 (-27.0)
# -11594.55 (-25.0)
# -11606.55 (-12.0)
# -11457.55 (149.0)
# -11971.55 (-514.0)
# -11976.55 (-5.0)
# -11988.55 (-12.0)
# -12038.55 (-50.0)
# -12052.55 (-14.0)
# -12054.55 (-2.0)
# Wed Aug  5 03:00:55 2020 2017-11-14 5ae4fde35689223dfa963def
# GENERATED 44340.0 OPPONENT LINEUPS Wed Aug  5 03:02:05 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 03:02:27 2020
# -12083.55 (-29.0)
# -12715.95 (-632.4)
# Wed Aug  5 03:02:54 2020 2017-11-15 5ae4c935dd71203dfc399baf
# GENERATED 118905.0 OPPONENT LINEUPS Wed Aug  5 03:04:31 2020
# GENERATED 644 POTENTIAL LINEUPS Wed Aug  5 03:05:24 2020
# -13165.95 (-450.0)
# -13615.95 (-450.0)
# -13715.95 (-100.0)
# -13755.95 (-40.0)
# -14200.95 (-445.0)
# -14365.95 (-165.0)
# -15180.95 (-815.0)
# -15207.95 (-27.0)
# -15234.95 (-27.0)
# -15309.95 (-75.0)
# -15321.95 (-12.0)
# -15505.16 (-183.21)
# -15791.16 (-286.0)
# -15786.16 (5.0)
# -15798.16 (-12.0)
# -15853.16 (-55.0)
# -15897.16 (-44.0)
# -15899.16 (-2.0)
# Wed Aug  5 03:07:04 2020 2017-11-15 5ae4dec2c074cf3dff641753
# GENERATED 73527.5 OPPONENT LINEUPS Wed Aug  5 03:08:04 2020
# GENERATED 504 POTENTIAL LINEUPS Wed Aug  5 03:08:27 2020
# -16292.16 (-393.0)
# -16152.16 (140.0)
# -16791.16 (-639.0)
# -16819.16 (-28.0)
# Wed Aug  5 03:09:19 2020 2017-11-16 5ae4c93778af173dfed468ea
# GENERATED 118905.0 OPPONENT LINEUPS Wed Aug  5 03:13:20 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 03:13:41 2020
# -17269.16 (-450.0)
# -17369.16 (-100.0)
# -17409.16 (-40.0)
# -17484.16 (-75.0)
# -17496.16 (-12.0)
# -17501.16 (-5.0)
# -17513.16 (-12.0)
# -17562.16 (-49.0)
# -17622.16 (-60.0)
# Wed Aug  5 03:14:30 2020 2017-11-17 5ae4d1bb95356d3dfb4bb01a
# GENERATED 118905.0 OPPONENT LINEUPS Wed Aug  5 03:16:18 2020
# GENERATED 846 POTENTIAL LINEUPS Wed Aug  5 03:17:37 2020
# -17722.16 (-100.0)
# -17822.16 (-100.0)
# -17222.16 (600.0)
# -16972.16 (250.0)
# -17122.16 (-150.0)
# -17197.16 (-75.0)
# -17237.16 (-40.0)
# -17277.16 (-40.0)
# -17722.16 (-445.0)
# -18042.16 (-320.0)
# -18069.16 (-27.0)
# -18104.16 (-35.0)
# -18081.16 (23.0)
# -18093.16 (-12.0)
# -18090.16 (3.0)
# -18129.16 (-39.0)
# -17651.91 (477.25)
# -17656.91 (-5.0)
# -17662.91 (-6.0)
# -17675.91 (-13.0)
# -17694.91 (-19.0)
# -17691.91 (3.0)
# -17693.91 (-2.0)
# Wed Aug  5 03:19:46 2020 2017-11-17 5ae4d4af95356d3dfb51ccdd
# GENERATED 73527.5 OPPONENT LINEUPS Wed Aug  5 03:21:32 2020
# GENERATED 636 POTENTIAL LINEUPS Wed Aug  5 03:22:04 2020
# -17685.91 (8.0)
# -17500.91 (185.0)
# -17841.91 (-341.0)
# -17869.91 (-28.0)
# -17874.91 (-5.0)
# Wed Aug  5 03:23:02 2020 2017-11-17 5ae507c2085a677335512e58
# GENERATED 10293.5 OPPONENT LINEUPS Wed Aug  5 03:23:24 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 03:23:46 2020
# -17039.51 (835.4)
# Wed Aug  5 03:23:53 2020 2017-11-17 5ae607f8fd67640e2603d061
# GENERATED 10293.5 OPPONENT LINEUPS Wed Aug  5 03:24:29 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 03:24:50 2020
# -17159.0 (-119.49000000000001)
# Wed Aug  5 03:24:57 2020 2017-11-18 5ae4c939f69c5a3e0012a55b
# GENERATED 77205.0 OPPONENT LINEUPS Wed Aug  5 03:26:19 2020
# GENERATED 1326 POTENTIAL LINEUPS Wed Aug  5 03:28:33 2020
# -16609.0 (550.0)
# -17059.0 (-450.0)
# -17159.0 (-100.0)
# -17359.0 (-200.0)
# -18197.0 (-838.0)
# -18890.0 (-693.0)
# -18867.0 (23.0)
# -18894.0 (-27.0)
# -18929.0 (-35.0)
# -18941.0 (-12.0)
# -18933.0 (8.0)
# -19211.0 (-278.0)
# -19817.0 (-606.0)
# -20566.6 (-749.6)
# -20571.6 (-5.0)
# -20577.6 (-6.0)
# -20615.6 (-38.0)
# -20657.6 (-42.0)
# -20659.6 (-2.0)
# Wed Aug  5 03:32:50 2020 2017-11-18 5ae4e3c7f69c5a3e004a4976
# GENERATED 45955.0 OPPONENT LINEUPS Wed Aug  5 03:34:00 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 03:34:23 2020
# -20983.6 (-324.0)
# -21169.6 (-186.0)
# -21848.46 (-678.86)
# -21928.46 (-80.0)
# Wed Aug  5 03:35:01 2020 2017-11-19 5ae4cd6edd71203dfc438848
# GENERATED 36762.5 OPPONENT LINEUPS Wed Aug  5 03:35:45 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 03:36:07 2020
# -21460.46 (468.0)
# -21798.46 (-338.0)
# Wed Aug  5 03:36:30 2020 2017-11-19 5ae4e628d69dcc3dfd0c50b2
# GENERATED 36162.5 OPPONENT LINEUPS Wed Aug  5 03:37:12 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 03:37:34 2020
# -21033.46 (765.0)
# -20494.16 (539.3)
# -20383.16 (111.0)
# Wed Aug  5 03:38:04 2020 2017-11-19 5ae4e62c5689223dfa43cfa9
# GENERATED 80832.5 OPPONENT LINEUPS Wed Aug  5 03:39:23 2020
# GENERATED 502 POTENTIAL LINEUPS Wed Aug  5 03:39:48 2020
# -20583.16 (-200.0)
# -21098.16 (-515.0)
# -21110.16 (-12.0)
# -20347.49 (762.67)
# -20368.49 (-21.0)
# Wed Aug  5 03:40:59 2020 2017-11-20 5ae4d1c095356d3dfb4bb945
# GENERATED 118905.0 OPPONENT LINEUPS Wed Aug  5 03:42:35 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 03:43:13 2020
# -20568.49 (-200.0)
# -20668.49 (-100.0)
# -20068.49 (600.0)
# -20218.49 (-150.0)
# -20008.49 (210.0)
# -20048.49 (-40.0)
# -20075.49 (-27.0)
# -20102.49 (-27.0)
# -20132.49 (-30.0)
# -20144.49 (-12.0)
# -20134.49 (10.0)
# -20140.49 (-6.0)
# -20159.49 (-19.0)
# -20161.49 (-2.0)
# Wed Aug  5 03:44:22 2020 2017-11-20 5ae512ee5381987332eeefbe
# GENERATED 36762.5 OPPONENT LINEUPS Wed Aug  5 03:53:28 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 03:53:51 2020
# -20034.74 (126.75)
# -20557.74 (-523.0)
# Wed Aug  5 03:54:15 2020 2017-11-20 5ae5fafd3825540e24a6f491
# GENERATED 9075.5 OPPONENT LINEUPS Wed Aug  5 03:54:59 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 03:55:23 2020
# -20725.63 (-167.89)
# Wed Aug  5 03:55:30 2020 2017-11-22 5ae4cd72d69dcc3dfddc5d14
# GENERATED 118905.0 OPPONENT LINEUPS Wed Aug  5 03:57:48 2020
# GENERATED 758 POTENTIAL LINEUPS Wed Aug  5 03:59:01 2020
# -21175.63 (-450.0)
# -20375.63 (800.0)
# -20525.63 (-150.0)
# -20165.63 (360.0)
# -20205.63 (-40.0)
# -20848.63 (-643.0)
# -20875.63 (-27.0)
# -20902.63 (-27.0)
# -20937.63 (-35.0)
# -20949.63 (-12.0)
# -21213.63 (-264.0)
# -21225.63 (-12.0)
# -21490.63 (-265.0)
# -22294.63 (-804.0)
# -22299.63 (-5.0)
# -22303.63 (-4.0)
# -22353.63 (-50.0)
# -22385.63 (-32.0)
# -22445.63 (-60.0)
# Wed Aug  5 04:00:52 2020 2017-11-22 5ae50f4ab819ea73344dc117
# COULD NOT GENERATE 55145.0 OPPONENT LINEUPS Wed Aug  5 04:10:53 2020
# Wed Aug  5 04:10:53 2020 2017-11-22 5b8387527dcd3b33003b26b8
# GENERATED 10013.5 OPPONENT LINEUPS Wed Aug  5 04:11:27 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 04:11:53 2020
# -22698.63 (-253.0)
# Wed Aug  5 04:12:00 2020 2017-11-24 5ae4cd75dd71203dfc439bfa
# GENERATED 118905.0 OPPONENT LINEUPS Wed Aug  5 04:13:31 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 04:14:05 2020
# -22248.63 (450.0)
# -22348.63 (-100.0)
# -22498.63 (-150.0)
# -22138.63 (360.0)
# -22118.63 (20.0)
# -22316.63 (-198.0)
# -22726.63 (-410.0)
# -22753.63 (-27.0)
# -22828.63 (-75.0)
# -22903.63 (-75.0)
# -22875.63 (28.0)
# -22817.63 (58.0)
# -22822.63 (-5.0)
# -22834.63 (-12.0)
# -22884.63 (-50.0)
# -22852.63 (32.0)
# Wed Aug  5 04:15:44 2020 2017-11-24 5ae4d1c595356d3dfb4bc08f
# GENERATED 71832.5 OPPONENT LINEUPS Wed Aug  5 04:17:17 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 04:17:40 2020
# -22136.63 (716.0)
# -21242.45 (894.1800000000001)
# -20994.7 (247.75)
# Wed Aug  5 04:18:28 2020 2017-11-24 5ae4d6abf69c5a3e00275b0d
# GENERATED 12866.0 OPPONENT LINEUPS Wed Aug  5 04:19:04 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 04:19:28 2020
# -21179.7 (-185.0)
# -21473.2 (-293.5)
# -21718.37 (-245.17000000000002)
# Wed Aug  5 04:19:47 2020 2017-11-25 5ae4c94add71203dfc39ba29
# GENERATED 82720.5 OPPONENT LINEUPS Wed Aug  5 04:20:55 2020
# GENERATED 1338 POTENTIAL LINEUPS Wed Aug  5 04:23:24 2020
# -21918.37 (-200.0)
# -22068.37 (-150.0)
# -22518.37 (-450.0)
# -22618.37 (-100.0)
# -23586.37 (-968.0)
# -23856.37 (-270.0)
# -23883.37 (-27.0)
# -23958.37 (-75.0)
# -23958.37 (0.0)
# -23970.37 (-12.0)
# -23982.37 (-12.0)
# -24940.37 (-958.0)
# -25889.37 (-949.0)
# -26136.37 (-247.0)
# -26141.37 (-5.0)
# -26153.37 (-12.0)
# -26176.37 (-23.0)
# -26231.37 (-55.0)
# -26291.37 (-60.0)
# -26293.37 (-2.0)
# Wed Aug  5 04:27:49 2020 2017-11-25 5ae4d2b878af173dfee9f658
# GENERATED 41972.5 OPPONENT LINEUPS Wed Aug  5 04:28:53 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 04:29:16 2020
# -26428.37 (-135.0)
# -26601.13 (-172.76)
# Wed Aug  5 04:29:42 2020 2017-11-25 5ae4d4bfdd71203dfc54711f
# GENERATED 20807.5 OPPONENT LINEUPS Wed Aug  5 04:30:35 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 04:30:58 2020
# -27082.13 (-481.0)
# Wed Aug  5 04:31:06 2020 2017-11-25 5ae4e634d69dcc3dfd0c51b5
# GENERATED 20807.5 OPPONENT LINEUPS Wed Aug  5 04:31:51 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 04:32:12 2020
# -26982.13 (100.0)
# Wed Aug  5 04:32:16 2020 2017-11-26 5ae4e1c9f69c5a3e00446eb4
# GENERATED 63185.0 OPPONENT LINEUPS Wed Aug  5 04:34:47 2020
# GENERATED 534 POTENTIAL LINEUPS Wed Aug  5 04:35:13 2020
# -27282.13 (-300.0)
# -27792.13 (-510.0)
# -27804.13 (-12.0)
# -28414.13 (-610.0)
# -28448.13 (-34.0)
# Wed Aug  5 04:36:19 2020 2017-11-27 5ae4c94c95356d3dfb39cff3
# GENERATED 91117.5 OPPONENT LINEUPS Wed Aug  5 04:45:27 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 04:45:48 2020
# -28778.13 (-330.0)
# -29203.07 (-424.94)
# -29241.07 (-38.0)
# -29249.07 (-8.0)
# Wed Aug  5 04:46:52 2020 2017-11-27 5ae4cc2b95356d3dfb40088a
# GENERATED 118905.0 OPPONENT LINEUPS Wed Aug  5 04:49:00 2020
# GENERATED 666 POTENTIAL LINEUPS Wed Aug  5 04:49:49 2020
# -29549.07 (-300.0)
# -29649.07 (-100.0)
# -29799.07 (-150.0)
# -29874.07 (-75.0)
# -29914.07 (-40.0)
# -29954.07 (-40.0)
# -30262.07 (-308.0)
# -30214.07 (48.0)
# -30229.07 (-15.0)
# -30241.07 (-12.0)
# -30233.07 (8.0)
# -30287.07 (-54.0)
# -30479.4 (-192.32999999999998)
# -30484.4 (-5.0)
# -30496.4 (-12.0)
# -30515.4 (-19.0)
# -30403.4 (112.0)
# Wed Aug  5 04:51:19 2020 2017-11-27 5ae51104085a677335664e85
# GENERATED 7717.5 OPPONENT LINEUPS Wed Aug  5 04:52:09 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 04:52:30 2020
# -30323.77 (79.63)
# Wed Aug  5 04:52:36 2020 2017-11-28 5ae4c94c5689223dfaf8e401
# GENERATED 89177.5 OPPONENT LINEUPS Wed Aug  5 04:54:11 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 04:54:38 2020
# -30473.77 (-150.0)
# -30573.77 (-100.0)
# -30613.77 (-40.0)
# -30640.77 (-27.0)
# -30542.77 (98.0)
# -30577.77 (-35.0)
# -30549.77 (28.0)
# -31039.77 (-490.0)
# -31034.77 (5.0)
# -31031.77 (3.0)
# -31033.77 (-2.0)
# -30856.77 (177.0)
# Wed Aug  5 04:55:40 2020 2017-11-28 5ae4d9725689223dfa1c36c1
# GENERATED 82570.0 OPPONENT LINEUPS Wed Aug  5 04:57:50 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 04:58:13 2020
# -30800.77 (56.0)
# -30962.77 (-162.0)
# -31655.77 (-693.0)
# -31668.77 (-13.0)
# -31718.77 (-50.0)
# Wed Aug  5 04:59:14 2020 2017-11-29 5ae4c94ef69c5a3e00131475
# GENERATED 118905.0 OPPONENT LINEUPS Wed Aug  5 05:00:53 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 05:01:31 2020
# -31618.77 (100.0)
# -31718.77 (-100.0)
# -31868.77 (-150.0)
# -32545.77 (-677.0)
# -32578.77 (-33.0)
# -32611.77 (-33.0)
# -32638.77 (-27.0)
# -32665.77 (-27.0)
# -32740.77 (-75.0)
# -32752.77 (-12.0)
# -33087.46 (-334.69)
# -33092.46 (-5.0)
# -33097.46 (-5.0)
# -33109.46 (-12.0)
# -33164.46 (-55.0)
# Wed Aug  5 05:02:43 2020 2017-11-29 5ae4cf3b78af173dfee1232c
# GENERATED 55145.0 OPPONENT LINEUPS Wed Aug  5 05:04:10 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 05:04:34 2020
# -33378.46 (-214.0)
# -34130.93 (-752.47)
# Wed Aug  5 05:05:08 2020 2017-11-29 5ae4d779f69c5a3e0029273a
# COULD NOT GENERATE 20807.5 OPPONENT LINEUPS Wed Aug  5 05:15:08 2020
# Wed Aug  5 05:15:08 2020 2017-11-30 5ae4c9e178af173dfed5a105
# GENERATED 118900.0 OPPONENT LINEUPS Wed Aug  5 05:17:18 2020
# GENERATED 534 POTENTIAL LINEUPS Wed Aug  5 05:17:48 2020
# -34430.93 (-300.0)
# -34530.93 (-100.0)
# -34680.93 (-150.0)
# -34720.93 (-40.0)
# -34760.93 (-40.0)
# -35175.93 (-415.0)
# -35152.93 (23.0)
# -35187.93 (-35.0)
# -35199.93 (-12.0)
# -35211.93 (-12.0)
# -35841.26 (-629.3299999999999)
# -35846.26 (-5.0)
# -35858.26 (-12.0)
# -35902.04 (-43.78)
# -35947.04 (-45.0)
# -35950.04 (-3.0)
# -35952.04 (-2.0)
# Wed Aug  5 05:19:16 2020 2017-11-30 5ae4cac85689223dfafbd8ec
# GENERATED 66177.5 OPPONENT LINEUPS Wed Aug  5 05:20:38 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 05:21:01 2020
# -36114.04 (-162.0)
# -36398.04 (-284.0)
# -37069.04 (-671.0)
# -37127.04 (-58.0)
# -37171.04 (-44.0)
# Wed Aug  5 05:21:53 2020 2017-12-01 5ae4c9ddf69c5a3e00141e2d
# GENERATED 118905.0 OPPONENT LINEUPS Wed Aug  5 05:23:32 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 05:24:05 2020
# -37271.04 (-100.0)
# -37421.04 (-150.0)
# -37161.04 (260.0)
# -37201.04 (-40.0)
# -37153.04 (48.0)
# -37178.04 (-25.0)
# -37169.04 (9.0)
# -37166.04 (3.0)
# -37151.04 (15.0)
# -37154.04 (-3.0)
# -37196.04 (-42.0)
# -37198.04 (-2.0)
# Wed Aug  5 05:25:08 2020 2017-12-01 5ae4d5d978af173dfef1afb4
# GENERATED 36762.5 OPPONENT LINEUPS Wed Aug  5 05:25:46 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 05:26:13 2020
# -37320.04 (-122.0)
# -37748.29 (-428.25)
# Wed Aug  5 05:26:38 2020 2017-12-02 5ae4c952d69dcc3dfdd35950
# GENERATED 77205.0 OPPONENT LINEUPS Wed Aug  5 05:27:54 2020
# GENERATED 1110 POTENTIAL LINEUPS Wed Aug  5 05:29:25 2020
# -37348.29 (400.0)
# -37498.29 (-150.0)
# -37598.29 (-100.0)
# -37816.29 (-218.0)
# -37856.29 (-40.0)
# -38071.29 (-215.0)
# -38098.29 (-27.0)
# -38173.29 (-75.0)
# -38185.29 (-12.0)
# -38817.29 (-632.0)
# -39150.91 (-333.62)
# -39155.91 (-5.0)
# -39167.91 (-12.0)
# -39214.45 (-46.54)
# -39231.45 (-17.0)
# -39264.45 (-33.0)
# Wed Aug  5 05:32:47 2020 2017-12-02 5ae4cc580f94ac3e0180e043
# GENERATED 36762.5 OPPONENT LINEUPS Wed Aug  5 05:34:00 2020
# GENERATED 858 POTENTIAL LINEUPS Wed Aug  5 05:34:53 2020
# -39324.45 (-60.0)
# -39438.45 (-114.0)
# -39553.45 (-115.0)
# -39565.45 (-12.0)
# -40041.45 (-476.0)
# -39660.45 (381.0)
# -39695.45 (-35.0)
# -39725.45 (-30.0)
# -39702.45 (23.0)
# Wed Aug  5 05:36:05 2020 2017-12-02 5ae4d975c074cf3dff54c67f
# GENERATED 45955.0 OPPONENT LINEUPS Wed Aug  5 05:37:05 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 05:37:27 2020
# -39672.45 (30.0)
# -39716.45 (-44.0)
# -40370.45 (-654.0)
# Wed Aug  5 05:38:01 2020 2017-12-03 5ae4cc5bdd71203dfc4123a3
# GENERATED 73527.5 OPPONENT LINEUPS Wed Aug  5 05:39:47 2020
# GENERATED 800 POTENTIAL LINEUPS Wed Aug  5 05:40:40 2020
# -40820.45 (-450.0)
# -41390.45 (-570.0)
# -40376.45 (1014.0)
# -40388.45 (-12.0)
# -40392.71 (-4.260000000000005)
# -40172.71 (220.0)
# -39803.71 (369.0)
# -39816.71 (-13.0)
# -39761.71 (55.0)
# Wed Aug  5 05:42:12 2020 2017-12-03 5ae4e81cd69dcc3dfd0f5427
# ERROR: MISSING TEAM DATA
# Wed Aug  5 05:42:12 2020 2017-12-04 5ae4cd850f94ac3e0183300a
# GENERATED 118905.0 OPPONENT LINEUPS Wed Aug  5 05:44:12 2020
# GENERATED 508 POTENTIAL LINEUPS Wed Aug  5 05:44:51 2020
# -40211.71 (-450.0)
# -40311.71 (-100.0)
# -40411.71 (-100.0)
# -40451.71 (-40.0)
# -40491.71 (-40.0)
# -41201.71 (-710.0)
# -41390.71 (-189.0)
# -41347.71 (43.0)
# -41324.71 (23.0)
# -41399.71 (-75.0)
# -41411.71 (-12.0)
# -41423.71 (-12.0)
# -41602.71 (-179.0)
# -41679.71 (-77.0)
# -41684.71 (-5.0)
# -41696.71 (-12.0)
# -41734.71 (-38.0)
# -41782.71 (-48.0)
# Wed Aug  5 05:46:18 2020 2017-12-04 5ae4f2595689223dfa6e8d42
# COULD NOT GENERATE 45955.0 OPPONENT LINEUPS Wed Aug  5 05:56:20 2020
# Wed Aug  5 05:56:20 2020 2017-12-05 5ae4c94f5689223dfaf8e4b5
# COULD NOT GENERATE 118905.0 OPPONENT LINEUPS Wed Aug  5 06:06:22 2020
# Wed Aug  5 06:06:22 2020 2017-12-05 5ae5efbefd67640e26c4213e
# GENERATED 33202.5 OPPONENT LINEUPS Wed Aug  5 06:07:27 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 06:07:50 2020
# -41946.71 (-164.0)
# -42514.71 (-568.0)
# Wed Aug  5 06:08:12 2020 2017-12-06 5ae4c96b5689223dfaf97070
# GENERATED 118905.0 OPPONENT LINEUPS Wed Aug  5 06:09:57 2020
# GENERATED 748 POTENTIAL LINEUPS Wed Aug  5 06:11:00 2020
# -42814.71 (-300.0)
# -42914.71 (-100.0)
# -43886.71 (-972.0)
# -44086.71 (-200.0)
# -44126.71 (-40.0)
# -44166.71 (-40.0)
# -44193.71 (-27.0)
# -44220.71 (-27.0)
# -44295.71 (-75.0)
# -44307.71 (-12.0)
# -44319.71 (-12.0)
# -45139.71 (-820.0)
# -45869.71 (-730.0)
# -45874.71 (-5.0)
# -45879.71 (-5.0)
# -45891.71 (-12.0)
# -45951.71 (-60.0)
# -46006.71 (-55.0)
# -46056.71 (-50.0)
# -46059.71 (-3.0)
# -46061.71 (-2.0)
# Wed Aug  5 06:12:57 2020 2017-12-06 5ae4dbee78af173dfeff92d9
# GENERATED 36762.5 OPPONENT LINEUPS Wed Aug  5 06:13:42 2020
# GENERATED 620 POTENTIAL LINEUPS Wed Aug  5 06:14:12 2020
# -46341.71 (-280.0)
# -47083.71 (-742.0)
# -47765.71 (-682.0)
# Wed Aug  5 06:14:45 2020 2017-12-06 5b83773a2488fa3196f9a9ef
# GENERATED 5145.0 OPPONENT LINEUPS Wed Aug  5 06:15:08 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 06:15:30 2020
# -47855.71 (-90.0)
# Wed Aug  5 06:15:35 2020 2017-12-07 5ae4c9e7f69c5a3e00142149
# GENERATED 118905.0 OPPONENT LINEUPS Wed Aug  5 06:18:27 2020
# GENERATED 694 POTENTIAL LINEUPS Wed Aug  5 06:19:08 2020
# -48155.71 (-300.0)
# -48255.71 (-100.0)
# -48145.71 (110.0)
# -48185.71 (-40.0)
# -48570.71 (-385.0)
# -48597.71 (-27.0)
# -48624.71 (-27.0)
# -48699.71 (-75.0)
# -48711.71 (-12.0)
# -48723.71 (-12.0)
# -48749.71 (-26.0)
# -49167.71 (-418.0)
# -49172.71 (-5.0)
# -49176.71 (-4.0)
# -49203.71 (-27.0)
# -49211.71 (-8.0)
# Wed Aug  5 06:20:36 2020 2017-12-07 5ae4e1d75689223dfa349c4e
# GENERATED 65537.5 OPPONENT LINEUPS Wed Aug  5 06:22:14 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 06:22:36 2020
# -49535.71 (-324.0)
# -50428.71 (-893.0)
# -50508.71 (-80.0)
# Wed Aug  5 06:23:20 2020 2017-12-08 5ae4c9e995356d3dfb3b312d
# GENERATED 89177.5 OPPONENT LINEUPS Wed Aug  5 06:25:00 2020
# GENERATED 572 POTENTIAL LINEUPS Wed Aug  5 06:25:39 2020
# -50308.71 (200.0)
# -50408.71 (-100.0)
# -51050.71 (-642.0)
# -51200.71 (-150.0)
# -51240.71 (-40.0)
# -50980.71 (260.0)
# -50979.71 (1.0)
# -51006.71 (-27.0)
# -51145.71 (-139.0)
# -51172.71 (-27.0)
# -51184.71 (-12.0)
# -51176.71 (8.0)
# -51699.13 (-522.4200000000001)
# -51704.13 (-5.0)
# -51696.13 (8.0)
# -51744.13 (-48.0)
# -51793.13 (-49.0)
# Wed Aug  5 06:27:03 2020 2017-12-08 5ae4cf41c074cf3dff3b8fd8
# GENERATED 36762.5 OPPONENT LINEUPS Wed Aug  5 06:27:51 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 06:28:17 2020
# -51562.13 (231.0)
# -49296.13 (2266.0)
# -49389.13 (-93.0)
# Wed Aug  5 06:28:46 2020 2017-12-09 5ae4cacac074cf3dff313dca
# GENERATED 77205.0 OPPONENT LINEUPS Wed Aug  5 06:29:56 2020
# GENERATED 1160 POTENTIAL LINEUPS Wed Aug  5 06:31:46 2020
# -49089.13 (300.0)
# -48689.13 (400.0)
# -48789.13 (-100.0)
# -49085.13 (-296.0)
# -49221.13 (-136.0)
# -49204.13 (17.0)
# -49231.13 (-27.0)
# -49266.13 (-35.0)
# -49278.13 (-12.0)
# -49570.63 (-292.5)
# -49944.63 (-374.0)
# -49929.63 (15.0)
# -49941.63 (-12.0)
# -49962.63 (-21.0)
# -50003.63 (-41.0)
# -50053.63 (-50.0)
# Wed Aug  5 06:35:15 2020 2017-12-09 5ae4dbf478af173dfeffa04d
# GENERATED 45955.0 OPPONENT LINEUPS Wed Aug  5 06:39:25 2020
# GENERATED 782 POTENTIAL LINEUPS Wed Aug  5 06:40:07 2020
# -50317.63 (-264.0)
# -50860.63 (-543.0)
# -50872.63 (-12.0)
# -51216.93 (-344.3)
# -51641.87 (-424.94)
# -51686.87 (-45.0)
# -51693.76 (-6.890000000000001)
# Wed Aug  5 06:41:15 2020 2017-12-09 5ae4dda2f69c5a3e00380e4e
# GENERATED 45955.0 OPPONENT LINEUPS Wed Aug  5 06:42:20 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 06:42:45 2020
# -51627.76 (66.0)
# -51694.27 (-66.50999999999999)
# Wed Aug  5 06:43:15 2020 2017-12-10 5ae4d1dc95356d3dfb4befd2
# GENERATED 73527.5 OPPONENT LINEUPS Wed Aug  5 06:44:43 2020
# GENERATED 554 POTENTIAL LINEUPS Wed Aug  5 06:45:10 2020
# -51644.27 (50.0)
# -51629.27 (15.0)
# -50609.27 (1020.0)
# -50621.27 (-12.0)
# -50474.27 (147.0)
# -50345.36 (128.91)
# -50368.36 (-23.0)
# Wed Aug  5 06:46:29 2020 2017-12-10 5ae4d2d05689223dfa0d60ff
# GENERATED 36762.5 OPPONENT LINEUPS Wed Aug  5 06:47:04 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 06:47:28 2020
# -50363.36 (5.0)
# -50680.03 (-316.67)
# -50648.86 (31.17)
# Wed Aug  5 06:47:58 2020 2017-12-11 5ae4d10178af173dfee50723
# GENERATED 85122.5 OPPONENT LINEUPS Wed Aug  5 06:50:49 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 06:51:12 2020
# -50698.86 (-50.0)
# -50421.54 (277.32)
# -50389.54 (32.0)
# Wed Aug  5 06:52:06 2020 2017-12-11 5ae4d3fa95356d3dfb50a972
# GENERATED 118905.0 OPPONENT LINEUPS Wed Aug  5 06:54:35 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 06:55:05 2020
# -50589.54 (-200.0)
# -50689.54 (-100.0)
# -50789.54 (-100.0)
# -50829.54 (-40.0)
# -50809.54 (20.0)
# -51292.54 (-483.0)
# -51319.54 (-27.0)
# -51508.54 (-189.0)
# -51460.54 (48.0)
# -51495.54 (-35.0)
# -51507.54 (-12.0)
# -51929.54 (-422.0)
# -51926.54 (3.0)
# -51931.54 (-5.0)
# -51943.54 (-12.0)
# -51949.54 (-6.0)
# -52009.54 (-60.0)
# -52056.54 (-47.0)
# Wed Aug  5 06:56:27 2020 2017-12-12 5ae4cf445689223dfa03940f
# GENERATED 118905.0 OPPONENT LINEUPS Wed Aug  5 06:59:25 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 06:59:56 2020
# -52156.54 (-100.0)
# -52896.54 (-740.0)
# -53046.54 (-150.0)
# -53086.54 (-40.0)
# -53185.54 (-99.0)
# -53212.54 (-27.0)
# -53154.54 (58.0)
# -53166.54 (-12.0)
# -53163.54 (3.0)
# -53168.54 (-5.0)
# -53248.54 (-80.0)
# -53269.54 (-21.0)
# -53313.54 (-44.0)
# Wed Aug  5 07:00:57 2020 2017-12-12 5ae4df14c074cf3dff64c5b1
# GENERATED 51470.0 OPPONENT LINEUPS Wed Aug  5 07:01:53 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 07:02:16 2020
# -52233.54 (1080.0)
# -52241.54 (-8.0)
# -52151.54 (90.0)
# -52113.23 (38.31)
# Wed Aug  5 07:02:56 2020 2017-12-12 5ae62efc940f5a209072cea8
# GENERATED 7717.5 OPPONENT LINEUPS Wed Aug  5 07:03:12 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 07:03:33 2020
# -51883.31 (229.92000000000002)
# Wed Aug  5 07:03:39 2020 2017-12-13 5ae4c953f69c5a3e001316f0
# GENERATED 118905.0 OPPONENT LINEUPS Wed Aug  5 07:06:04 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 07:06:38 2020
# -52783.31 (-900.0)
# -53233.31 (-450.0)
# -53183.31 (50.0)
# -53283.31 (-100.0)
# -53323.31 (-40.0)
# -53648.31 (-325.0)
# -53675.31 (-27.0)
# -53750.31 (-75.0)
# -53762.31 (-12.0)
# -53774.31 (-12.0)
# -53956.31 (-182.0)
# -53961.31 (-5.0)
# -53967.31 (-6.0)
# -53991.31 (-24.0)
# -54041.31 (-50.0)
# Wed Aug  5 07:07:48 2020 2017-12-13 5ae4cad0c074cf3dff314d7e
# GENERATED 51470.0 OPPONENT LINEUPS Wed Aug  5 07:09:04 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 07:09:25 2020
# -54206.31 (-165.0)
# -53738.31 (468.0)
# -54568.31 (-830.0)
# -54596.31 (-28.0)
# Wed Aug  5 07:10:06 2020 2017-12-13 5b834df0dc114c2ea02f5d80
# GENERATED 5145.0 OPPONENT LINEUPS Wed Aug  5 07:10:28 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 07:10:50 2020
# -54210.97 (385.34000000000003)
# Wed Aug  5 07:10:55 2020 2017-12-14 5ae4c96c0f94ac3e017b55b2
# GENERATED 80260.5 OPPONENT LINEUPS Wed Aug  5 07:12:16 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 07:12:44 2020
# -54310.97 (-100.0)
# -54460.97 (-150.0)
# -54500.97 (-40.0)
# -54599.97 (-99.0)
# -54626.97 (-27.0)
# -54638.97 (-12.0)
# -54643.97 (-5.0)
# -54655.97 (-12.0)
# -54709.97 (-54.0)
# -54763.97 (-54.0)
# -54813.97 (-50.0)
# -54868.97 (-55.0)
# Wed Aug  5 07:14:53 2020 2017-12-14 5ae4f667c074cf3dffaa4910
# GENERATED 35277.5 OPPONENT LINEUPS Wed Aug  5 07:15:37 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 07:16:01 2020
# -55198.97 (-330.0)
# -55819.97 (-621.0)
# Wed Aug  5 07:16:25 2020 2017-12-15 5ae4cad0dd71203dfc3dc5f3
# GENERATED 118905.0 OPPONENT LINEUPS Wed Aug  5 07:18:47 2020
# GENERATED 694 POTENTIAL LINEUPS Wed Aug  5 07:19:44 2020
# -55969.97 (-150.0)
# -56069.97 (-100.0)
# -56119.97 (-50.0)
# -56159.97 (-40.0)
# -55354.97 (805.0)
# -55403.97 (-49.0)
# -56133.97 (-730.0)
# -56160.97 (-27.0)
# -56172.97 (-12.0)
# -56460.97 (-288.0)
# -56465.97 (-5.0)
# -56477.97 (-12.0)
# -56532.97 (-55.0)
# -56576.97 (-44.0)
# -56618.97 (-42.0)
# Wed Aug  5 07:21:10 2020 2017-12-15 5ae4cd8c5689223dfa0033ee
# GENERATED 7717.5 OPPONENT LINEUPS Wed Aug  5 07:21:33 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 07:21:55 2020
# -56612.47 (6.5)
# Wed Aug  5 07:22:01 2020 2017-12-15 5ae5226e538198733203feca
# GENERATED 37157.5 OPPONENT LINEUPS Wed Aug  5 07:23:13 2020
# GENERATED 572 POTENTIAL LINEUPS Wed Aug  5 07:23:40 2020
# -56362.47 (250.0)
# -56868.47 (-506.0)
# -56886.14 (-17.67)
# -56817.89 (68.25)
# -56811.22 (6.670000000000002)
# Wed Aug  5 07:24:23 2020 2017-12-16 5ae4d79578af173dfef66d2c
# GENERATED 75514.5 OPPONENT LINEUPS Wed Aug  5 07:25:57 2020
# GENERATED 870 POTENTIAL LINEUPS Wed Aug  5 07:27:08 2020
# -57261.22 (-450.0)
# -57361.22 (-100.0)
# -57341.22 (20.0)
# -57901.22 (-560.0)
# -57976.22 (-75.0)
# -57988.22 (-12.0)
# -57970.22 (18.0)
# -57653.22 (317.0)
# -57659.22 (-6.0)
# -57656.22 (3.0)
# -57698.22 (-42.0)
# Wed Aug  5 07:29:56 2020 2017-12-16 5ae4f297d69dcc3dfd2928f7
# GENERATED 34780.0 OPPONENT LINEUPS Wed Aug  5 07:31:08 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 07:31:29 2020
# -56985.55 (712.67)
# -15851.81 (41133.74)
# Wed Aug  5 07:31:53 2020 2017-12-17 5ae4cacf5689223dfafbeb83
# GENERATED 36762.5 OPPONENT LINEUPS Wed Aug  5 07:33:09 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 07:33:31 2020
# -15963.81 (-112.0)
# -16475.14 (-511.33)
# -16639.14 (-164.0)
# Wed Aug  5 07:33:59 2020 2017-12-17 5ae4d84bf69c5a3e002accd5
# GENERATED 59452.5 OPPONENT LINEUPS Wed Aug  5 07:35:16 2020
# GENERATED 514 POTENTIAL LINEUPS Wed Aug  5 07:35:43 2020
# -16939.14 (-300.0)
# -17532.14 (-593.0)
# -17544.14 (-12.0)
# -18308.14 (-764.0)
# -18333.14 (-25.0)
# -18393.14 (-60.0)
# Wed Aug  5 07:36:41 2020 2017-12-18 5ae4cad7c074cf3dff3150f5
# GENERATED 118905.0 OPPONENT LINEUPS Wed Aug  5 07:38:47 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 07:39:22 2020
# -18693.14 (-300.0)
# -18793.14 (-100.0)
# -18993.14 (-200.0)
# -19033.14 (-40.0)
# -19132.14 (-99.0)
# -19567.14 (-435.0)
# -19594.14 (-27.0)
# -19606.14 (-12.0)
# -19618.14 (-12.0)
# -20079.14 (-461.0)
# -20076.14 (3.0)
# -20088.14 (-12.0)
# -20148.14 (-60.0)
# -20203.14 (-55.0)
# -20205.14 (-2.0)
# Wed Aug  5 07:40:39 2020 2017-12-18 5ae4db52d69dcc3dfdf6260f
# GENERATED 45450.0 OPPONENT LINEUPS Wed Aug  5 07:42:24 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 07:42:47 2020
# -20535.14 (-330.0)
# -21475.14 (-940.0)
# Wed Aug  5 07:43:16 2020 2017-12-19 5ae4ce4795356d3dfb43daaf
# GENERATED 118905.0 OPPONENT LINEUPS Wed Aug  5 07:46:45 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 07:47:09 2020
# -15925.14 (5550.0)
# -16025.14 (-100.0)
# -16005.14 (20.0)
# -16045.14 (-40.0)
# -16094.14 (-49.0)
# -15659.14 (435.0)
# -15651.14 (8.0)
# -15663.14 (-12.0)
# -15693.14 (-30.0)
# -14533.14 (1160.0)
# -14545.14 (-12.0)
# -14518.14 (27.0)
# Wed Aug  5 07:48:02 2020 2017-12-20 5ae4c96fd69dcc3dfdd3e82a
# GENERATED 118905.0 OPPONENT LINEUPS Wed Aug  5 07:49:55 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 07:50:34 2020
# -14968.14 (-450.0)
# -15068.14 (-100.0)
# -15573.14 (-505.0)
# -15613.14 (-40.0)
# -15688.14 (-75.0)
# -15700.14 (-12.0)
# -15712.14 (-12.0)
# -15709.14 (3.0)
# -15714.64 (-5.5)
# -15716.64 (-2.0)
# -15770.64 (-54.0)
# Wed Aug  5 07:51:31 2020 2017-12-20 5ae4c9f678af173dfed5b8c5
# GENERATED 91910.0 OPPONENT LINEUPS Wed Aug  5 07:54:18 2020
# GENERATED 622 POTENTIAL LINEUPS Wed Aug  5 07:54:49 2020
# -15666.64 (104.0)
# -16101.58 (-434.94)
# -16162.25 (-60.66999999999999)
# -16179.25 (-17.0)
# Wed Aug  5 07:55:55 2020 2017-12-20 5ae5136c5381987332f1625d
# GENERATED 5145.0 OPPONENT LINEUPS Wed Aug  5 07:56:50 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 07:57:13 2020
# -16344.25 (-165.0)
# Wed Aug  5 07:57:18 2020 2017-12-20 5ae5f8d7fd67640e26d4dae8
# GENERATED 5145.0 OPPONENT LINEUPS Wed Aug  5 07:57:33 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 07:57:54 2020
# -16428.05 (-83.8)
# Wed Aug  5 07:57:59 2020 2017-12-21 5ae4d84df69c5a3e002ad8d8
# GENERATED 118905.0 OPPONENT LINEUPS Wed Aug  5 08:00:14 2020
# GENERATED 500 POTENTIAL LINEUPS Wed Aug  5 08:00:40 2020
# -16528.05 (-100.0)
# -16467.05 (61.0)
# -15294.05 (1173.0)
# -15321.05 (-27.0)
# -15333.05 (-12.0)
# -15338.05 (-5.0)
# -15335.05 (3.0)
# Wed Aug  5 08:01:13 2020 2017-12-21 5ae51683589eaa73374115e2
# COULD NOT GENERATE 51470.0 OPPONENT LINEUPS Wed Aug  5 08:11:14 2020
# Wed Aug  5 08:11:14 2020 2017-12-22 5ae4c95af69c5a3e00131c90
# GENERATED 118905.0 OPPONENT LINEUPS Wed Aug  5 08:13:35 2020
# GENERATED 782 POTENTIAL LINEUPS Wed Aug  5 08:14:46 2020
# -14935.05 (400.0)
# -15385.05 (-450.0)
# -15485.05 (-100.0)
# -15525.05 (-40.0)
# -15564.05 (-39.0)
# -15744.05 (-180.0)
# -15771.05 (-27.0)
# -15798.05 (-27.0)
# -15810.05 (-12.0)
# -15822.05 (-12.0)
# -15939.05 (-117.0)
# -16007.05 (-68.0)
# -16480.05 (-473.0)
# -16485.05 (-5.0)
# -16497.05 (-12.0)
# -16523.05 (-26.0)
# -16535.05 (-12.0)
# ...
# GENERATED 506 POTENTIAL LINEUPS Sat Aug  8 23:13:21 2020
# 101560.67 (-720.0)
# 100865.67 (-695.0)
# 100270.67 (-595.0)
# 100209.67 (-61.0)
# Sat Aug  8 23:13:52 2020 2020-02-24 5e553a82cf13b87bb49ee65c
# GENERATED 10297.0 OPPONENT LINEUPS Sat Aug  8 23:14:21 2020
# GENERATED 500 POTENTIAL LINEUPS Sat Aug  8 23:14:43 2020
# 104880.69 (4671.02)
# Sat Aug  8 23:14:53 2020 2020-02-25 5e55b5e44b36497bbb3f5ece
# GENERATED 91717.5 OPPONENT LINEUPS Sat Aug  8 23:16:52 2020
# GENERATED 2126 POTENTIAL LINEUPS Sat Aug  8 23:21:33 2020
# 104280.69 (-600.0)
# 103920.69 (-360.0)
# 103820.69 (-100.0)
# 103720.69 (-100.0)
# 103020.69 (-700.0)
# 102487.36 (-533.33)
# 102462.36 (-25.0)
# 102312.36 (-150.0)
# 102162.36 (-150.0)
# 101810.36 (-352.0)
# 100982.36 (-828.0)
# 100942.36 (-40.0)
# 100915.36 (-27.0)
# 100888.36 (-27.0)
# 100888.36 (0.0)
# 100703.36 (-185.0)
# 100691.36 (-12.0)
# 100103.36 (-588.0)
# 99599.36 (-504.0)
# 99594.36 (-5.0)
# 99523.07 (-71.28999999999999)
# 99514.07 (-9.0)
# 99335.07 (-179.0)
# 99333.07 (-2.0)
# Sat Aug  8 23:27:09 2020 2020-02-25 5e568f78d3df4b4483fa7d2a
# GENERATED 44590.0 OPPONENT LINEUPS Sat Aug  8 23:28:15 2020
# GENERATED 550 POTENTIAL LINEUPS Sat Aug  8 23:28:41 2020
# 98445.07 (-888.0)
# 98346.07 (-99.0)
# 98219.4 (-126.67)
# 97824.4 (-395.0)
# 97084.4 (-740.0)
# 97055.17 (-29.23)
# 96983.17 (-72.0)
# Sat Aug  8 23:29:34 2020 2020-02-25 5e568f80c458d844775121e1
# GENERATED 29949.5 OPPONENT LINEUPS Sat Aug  8 23:30:27 2020
# GENERATED 500 POTENTIAL LINEUPS Sat Aug  8 23:30:50 2020
# 96229.42 (-753.75)
# 96224.42 (-5.0)
# Sat Aug  8 23:31:06 2020 2020-02-26 5e57075dc458d844775150aa
# GENERATED 89181.0 OPPONENT LINEUPS Sat Aug  8 23:32:41 2020
# GENERATED 2058 POTENTIAL LINEUPS Sat Aug  8 23:37:29 2020
# 96180.42 (-44.0)
# 95992.42 (-188.0)
# 95812.42 (-180.0)
# 95362.42 (-450.0)
# 95462.42 (100.0)
# 95387.42 (-75.0)
# 95437.42 (50.0)
# 95041.42 (-396.0)
# 94223.42 (-818.0)
# 94183.42 (-40.0)
# 94156.42 (-27.0)
# 94174.42 (18.0)
# 94434.42 (260.0)
# 93754.42 (-680.0)
# 93108.42 (-646.0)
# 93128.42 (20.0)
# 92520.42 (-608.0)
# 92460.42 (-60.0)
# 92389.42 (-71.0)
# 92386.42 (-3.0)
# 92384.42 (-2.0)
# 92219.13 (-165.29000000000002)
# Sat Aug  8 23:42:40 2020 2020-02-26 5e5727c1c458d844775300f1
# GENERATED 29727.5 OPPONENT LINEUPS Sat Aug  8 23:43:32 2020
# GENERATED 500 POTENTIAL LINEUPS Sat Aug  8 23:43:55 2020
# 91919.13 (-300.0)
# 91312.41 (-606.72)
# 91361.03 (48.62)
# Sat Aug  8 23:44:21 2020 2020-02-26 5e5818a5c8619e02df0afd4a
# GENERATED 20811.0 OPPONENT LINEUPS Sat Aug  8 23:45:07 2020
# GENERATED 500 POTENTIAL LINEUPS Sat Aug  8 23:45:29 2020
# 91389.21 (28.180000000000007)
# Sat Aug  8 23:45:40 2020 2020-02-26 5e5818a5da7bea02d9e06459
# GENERATED 20811.0 OPPONENT LINEUPS Sat Aug  8 23:46:22 2020
# GENERATED 500 POTENTIAL LINEUPS Sat Aug  8 23:46:45 2020
# 91230.31 (-158.9)
# Sat Aug  8 23:46:55 2020 2020-02-27 5e5858741dc8aa02d2ac3c24
# GENERATED 89181.0 OPPONENT LINEUPS Sat Aug  8 23:49:08 2020
# GENERATED 2160 POTENTIAL LINEUPS Sat Aug  8 23:53:34 2020
# 91930.31 (700.0)
# 92030.31 (100.0)
# 91930.31 (-100.0)
# 91855.31 (-75.0)
# 91855.31 (0.0)
# 91342.31 (-513.0)
# 90946.31 (-396.0)
# 91481.31 (535.0)
# 91441.31 (-40.0)
# 91414.31 (-27.0)
# 91354.31 (-60.0)
# 90518.31 (-836.0)
# 90506.31 (-12.0)
# 90494.31 (-12.0)
# 89689.31 (-805.0)
# 89574.31 (-115.0)
# 88838.31 (-736.0)
# 88180.31 (-658.0)
# 88250.31 (70.0)
# 88178.31 (-72.0)
# 88104.31 (-74.0)
# 88095.31 (-9.0)
# 87845.31 (-250.0)
# 87843.31 (-2.0)
# Sat Aug  8 23:58:52 2020 2020-02-27 5e5931fbf8d69e4c1d399edb
# GENERATED 37160.0 OPPONENT LINEUPS Sat Aug  8 23:59:43 2020
# GENERATED 500 POTENTIAL LINEUPS Sun Aug  9 00:00:08 2020
# 87803.31 (-40.0)
# 87704.31 (-99.0)
# 87564.31 (-140.0)
# 87038.9 (-525.41)
# 87029.9 (-9.0)
# Sun Aug  9 00:00:41 2020 2020-02-28 5e59aa7af8d69e4c1d39e67b
# GENERATED 88798.5 OPPONENT LINEUPS Sun Aug  9 00:02:36 2020
# GENERATED 2152 POTENTIAL LINEUPS Sun Aug  9 00:07:50 2020
# 86829.9 (-200.0)
# 86729.9 (-100.0)
# 86629.9 (-100.0)
# 86121.9 (-508.0)
# 85896.9 (-225.0)
# 86121.9 (225.0)
# 85797.9 (-324.0)
# 85757.9 (-40.0)
# 85730.9 (-27.0)
# 85021.84 (-709.0600000000004)
# 84656.84 (-365.0)
# 84644.84 (-12.0)
# 92533.84 (7889.0)
# 92528.84 (-5.0)
# 98186.44 (5657.6)
# 98194.44 (8.0)
# 98265.05 (70.61)
# 98256.05 (-9.0)
# 98259.05 (3.0)
# 98215.05 (-44.0)
# Sun Aug  9 00:12:29 2020 2020-02-28 5e5bdb978986063ed85c862e
# GENERATED 10297.0 OPPONENT LINEUPS Sun Aug  9 00:12:52 2020
# GENERATED 500 POTENTIAL LINEUPS Sun Aug  9 00:13:13 2020
# 97666.05 (-549.0)
# 97565.05 (-101.0)
# Sun Aug  9 00:13:28 2020 2020-02-28 5e5bdb998986063ed85c8c76
# GENERATED 10297.0 OPPONENT LINEUPS Sun Aug  9 00:14:01 2020
# GENERATED 500 POTENTIAL LINEUPS Sun Aug  9 00:14:26 2020
# 97028.8 (-536.25)
# Sun Aug  9 00:14:36 2020 2020-02-28 5e5bdb9a8986063ed85c8cfc
# GENERATED 37160.0 OPPONENT LINEUPS Sun Aug  9 00:15:24 2020
# GENERATED 500 POTENTIAL LINEUPS Sun Aug  9 00:15:49 2020
# 103328.8 (6300.0)
# 102833.8 (-495.0)
# 102821.13 (-12.67)
# Sun Aug  9 00:16:15 2020 2020-02-29 5e5b17bc6312c20c092df4b6
# GENERATED 118907.5 OPPONENT LINEUPS Sun Aug  9 00:18:47 2020
# GENERATED 2438 POTENTIAL LINEUPS Sun Aug  9 00:24:50 2020
# 102521.13 (-300.0)
# 102161.13 (-360.0)
# 102061.13 (-100.0)
# 101961.13 (-100.0)
# 101811.13 (-150.0)
# 101319.13 (-492.0)
# 101301.13 (-18.0)
# 101261.13 (-40.0)
# 101279.13 (18.0)
# 101619.13 (340.0)
# 101359.13 (-260.0)
# 100889.13 (-470.0)
# 100877.13 (-12.0)
# 100883.13 (6.0)
# 100563.13 (-320.0)
# 100558.13 (-5.0)
# 105528.13 (4970.0)
# 105492.13 (-36.0)
# 105470.13 (-22.0)
# 105491.13 (21.0)
# 105482.13 (-9.0)
# 105421.05 (-61.08)
# Sun Aug  9 00:29:48 2020 2020-02-29 5e5c6f1b28b5893ed2b54195
# GENERATED 37160.0 OPPONENT LINEUPS Sun Aug  9 00:30:42 2020
# GENERATED 500 POTENTIAL LINEUPS Sun Aug  9 00:31:06 2020
# 105101.05 (-320.0)
# 104597.05 (-504.0)
# 104580.05 (-17.0)
# Sun Aug  9 00:31:30 2020 2020-02-29 5e5c6f268986063ed85f480c
# GENERATED 7721.0 OPPONENT LINEUPS Sun Aug  9 00:31:49 2020
# GENERATED 500 POTENTIAL LINEUPS Sun Aug  9 00:32:12 2020
# 104100.05 (-480.0)
# Sun Aug  9 00:32:20 2020 2020-03-01 5e5c471f28b5893ed2b3b372
# GENERATED 118907.5 OPPONENT LINEUPS Sun Aug  9 00:33:41 2020
# GENERATED 1652 POTENTIAL LINEUPS Sun Aug  9 00:36:25 2020
# 103500.05 (-600.0)
# 103320.05 (-180.0)
# 103220.05 (-100.0)
# 102340.05 (-880.0)
# 102300.05 (-40.0)
# 102333.05 (33.0)
# 102273.05 (-60.0)
# 101408.05 (-865.0)
# 100518.05 (-890.0)
# 100506.05 (-12.0)
# 100494.05 (-12.0)
# 99864.05 (-630.0)
# 99859.05 (-5.0)
# 99779.05 (-80.0)
# 99732.05 (-47.0)
# 99723.05 (-9.0)
# 99507.05 (-216.0)
# Sun Aug  9 00:39:35 2020 2020-03-01 5e5c96e86177c726b6e80697
# GENERATED 88030.0 OPPONENT LINEUPS Sun Aug  9 00:40:55 2020
# GENERATED 518 POTENTIAL LINEUPS Sun Aug  9 00:41:19 2020
# 98619.05 (-888.0)
# 98669.05 (50.0)
# 98141.05 (-528.0)
# 98101.05 (-40.0)
# 97851.05 (-250.0)
# 97021.05 (-830.0)
# 97009.05 (-12.0)
# 97004.05 (-5.0)
# 96952.05 (-52.0)
# Sun Aug  9 00:42:25 2020 2020-03-01 5e5c96ec6177c726b6e80e4f
# GENERATED 37160.0 OPPONENT LINEUPS Sun Aug  9 00:43:05 2020
# GENERATED 500 POTENTIAL LINEUPS Sun Aug  9 00:43:26 2020
# 96712.05 (-240.0)
# 96547.05 (-165.0)
# 96277.05 (-270.0)
# 96032.05 (-245.0)
# 95167.05 (-865.0)
# 95121.05 (-46.0)
# Sun Aug  9 00:44:08 2020 2020-03-02 5e5d9e8702c92706d76ee0c2
# GENERATED 89181.0 OPPONENT LINEUPS Sun Aug  9 00:45:43 2020
# GENERATED 2038 POTENTIAL LINEUPS Sun Aug  9 00:50:09 2020
# 94521.05 (-600.0)
# 94161.05 (-360.0)
# 94061.05 (-100.0)
# 93836.05 (-225.0)
# 93406.05 (-430.0)
# 93256.05 (-150.0)
# 93392.05 (136.0)
# 93352.05 (-40.0)
# 93385.05 (33.0)
# 93358.05 (-27.0)
# 93298.05 (-60.0)
# 93286.05 (-12.0)
# 93026.05 (-260.0)
# 92230.25 (-795.8)
# 91889.25 (-341.0)
# 91884.25 (-5.0)
# 91836.25 (-48.0)
# 91834.25 (-2.0)
# 91678.25 (-156.0)
# 91676.25 (-2.0)
# Sun Aug  9 00:55:07 2020 2020-03-02 5e5dc045a248ff06d976c485
# GENERATED 37160.0 OPPONENT LINEUPS Sun Aug  9 00:56:42 2020
# GENERATED 500 POTENTIAL LINEUPS Sun Aug  9 00:57:06 2020
# 91136.25 (-540.0)
# 91121.25 (-15.0)
# 90851.25 (-270.0)
# 90089.25 (-762.0)
# 90063.25 (-26.0)
# Sun Aug  9 00:57:38 2020 2020-03-02 5e5e6b6daa7d504203755d67
# GENERATED 10297.0 OPPONENT LINEUPS Sun Aug  9 00:58:07 2020
# GENERATED 500 POTENTIAL LINEUPS Sun Aug  9 00:58:29 2020
# 90068.92 (5.670000000000016)
# Sun Aug  9 00:58:39 2020 2020-03-03 5e5ef085d700cb42050a3d9e
# GENERATED 89181.0 OPPONENT LINEUPS Sun Aug  9 00:59:53 2020
# GENERATED 2096 POTENTIAL LINEUPS Sun Aug  9 01:04:40 2020
# 89680.92 (-388.0)
# 90080.92 (400.0)
# 89980.92 (-100.0)
# 90055.92 (75.0)
# 90305.92 (250.0)
# 89687.92 (-618.0)
# 89707.92 (20.0)
# 89680.92 (-27.0)
# 89045.92 (-635.0)
# 89033.92 (-12.0)
# 88568.92 (-465.0)
# 87976.42 (-592.5)
# 87971.42 (-5.0)
# 87591.17 (-380.25)
# 87606.17 (15.0)
# 87604.17 (-2.0)
# 87512.17 (-92.0)
# Sun Aug  9 01:09:18 2020 2020-03-03 5e5f25396022f5329ed6b847
# GENERATED 52022.5 OPPONENT LINEUPS Sun Aug  9 01:10:25 2020
# GENERATED 500 POTENTIAL LINEUPS Sun Aug  9 01:10:47 2020
# 88290.84 (778.67)
# 88191.84 (-99.0)
# 88161.84 (-30.0)
# 87671.84 (-490.0)
# 87666.84 (-5.0)
# 87629.84 (-37.0)
# Sun Aug  9 01:11:32 2020 2020-03-03 5e5fbdbf148e127ded2f70de
# GENERATED 7721.0 OPPONENT LINEUPS Sun Aug  9 01:11:46 2020
# GENERATED 500 POTENTIAL LINEUPS Sun Aug  9 01:12:07 2020
# 87906.84 (277.0)
# Sun Aug  9 01:12:16 2020 2020-03-03 5e5fbdc222fc3a7df46630a5
# GENERATED 10297.0 OPPONENT LINEUPS Sun Aug  9 01:12:35 2020
# GENERATED 500 POTENTIAL LINEUPS Sun Aug  9 01:12:56 2020
# 88439.84 (533.0)
# Sun Aug  9 01:13:06 2020 2020-03-04 5e60416c5b20f57df7db0b3a
# GENERATED 135129 OPPONENT LINEUPS Sun Aug  9 01:15:49 2020
# GENERATED 1442 POTENTIAL LINEUPS Sun Aug  9 01:18:28 2020
# 87839.84 (-600.0)
# 87739.84 (-100.0)
# 87514.84 (-225.0)
# 87364.84 (-150.0)
# 87891.84 (527.0)
# 87864.84 (-27.0)
# 87804.84 (-60.0)
# 89144.84 (1340.0)
# 89132.84 (-12.0)
# 89105.84 (-27.0)
# 89100.84 (-5.0)
# 89011.84 (-89.0)
# 89002.84 (-9.0)
# 88857.22 (-145.62)
# 88855.22 (-2.0)
# Sun Aug  9 01:23:27 2020 2020-03-04 5e60ed2d3c63462e10bfb6ae
# GENERATED 37160.0 OPPONENT LINEUPS Sun Aug  9 01:25:22 2020
# GENERATED 500 POTENTIAL LINEUPS Sun Aug  9 01:25:44 2020
# 88667.22 (-188.0)
# 88668.22 (1.0)
# 88528.22 (-140.0)
# 88159.41 (-368.81)
# 87884.41 (-275.0)
# Sun Aug  9 01:26:22 2020 2020-03-04 5e60edb08e77912e0827804f
# GENERATED 24972.5 OPPONENT LINEUPS Sun Aug  9 01:26:51 2020
# GENERATED 500 POTENTIAL LINEUPS Sun Aug  9 01:27:15 2020
# 88192.41 (308.0)
# Sun Aug  9 01:27:26 2020 2020-03-05 5e61930d8e77912e08278d5a
# GENERATED 84481.5 OPPONENT LINEUPS Sun Aug  9 01:28:37 2020
# GENERATED 1976 POTENTIAL LINEUPS Sun Aug  9 01:32:27 2020
# 87304.41 (-888.0)
# 86854.41 (-450.0)
# 86754.41 (-100.0)
# 87604.41 (850.0)
# 87379.41 (-225.0)
# 87229.41 (-150.0)
# 86771.41 (-458.0)
# 86731.41 (-40.0)
# 86764.41 (33.0)
# 86764.41 (0.0)
# 86752.41 (-12.0)
# 86181.41 (-571.0)
# 85682.41 (-499.0)
# 85689.41 (7.0)
# 85187.41 (-502.0)
# 85197.41 (10.0)
# 85159.41 (-38.0)
# 85156.41 (-3.0)
# 85154.41 (-2.0)
# 85008.41 (-146.0)
# Sun Aug  9 01:36:57 2020 2020-03-05 5e626aedfe52a85f26509c80
# GENERATED 44590.0 OPPONENT LINEUPS Sun Aug  9 01:37:42 2020
# GENERATED 500 POTENTIAL LINEUPS Sun Aug  9 01:38:04 2020
# 84508.41 (-500.0)
# 84343.41 (-165.0)
# 84338.41 (-5.0)
# 84393.41 (55.0)
# Sun Aug  9 01:38:23 2020 2020-03-06 5e62e4e51d940e5f1f69c4f3
# GENERATED 85612.5 OPPONENT LINEUPS Sun Aug  9 01:40:00 2020
# GENERATED 2120 POTENTIAL LINEUPS Sun Aug  9 01:45:11 2020
# 86793.41 (2400.0)
# 86693.41 (-100.0)
# 86593.41 (-100.0)
# 85775.41 (-818.0)
# 85550.41 (-225.0)
# 85400.41 (-150.0)
# 85084.41 (-316.0)
# 85044.41 (-40.0)
# 85137.41 (93.0)
# 85077.41 (-60.0)
# 84162.41 (-915.0)
# 83972.41 (-190.0)
# 84145.74 (173.32999999999993)
# 84308.74 (163.0)
# 83487.74 (-821.0)
# 83492.74 (5.0)
# 82833.74 (-659.0)
# 82772.74 (-61.0)
# 82700.74 (-72.0)
# 82691.74 (-9.0)
# 82415.34 (-276.4)
# Sun Aug  9 01:49:57 2020 2020-03-06 5e63ea940d11793aa2068d43
# GENERATED 37160.0 OPPONENT LINEUPS Sun Aug  9 01:51:32 2020
# GENERATED 500 POTENTIAL LINEUPS Sun Aug  9 01:51:55 2020
# 81645.34 (-770.0)
# 81653.84 (8.5)
# Sun Aug  9 01:52:18 2020 2020-03-06 5e63ea9832c96d3ab03eda22
# GENERATED 20811.0 OPPONENT LINEUPS Sun Aug  9 01:52:42 2020
# GENERATED 500 POTENTIAL LINEUPS Sun Aug  9 01:53:07 2020
# Sun Aug  9 01:53:07 2020 2020-03-07 5e6435f6fe34dd3aa3dc134a
# GENERATED 118907.5 OPPONENT LINEUPS Sun Aug  9 01:55:05 2020
# GENERATED 2236 POTENTIAL LINEUPS Sun Aug  9 01:59:59 2020
# 81053.84 (-600.0)
# 80953.84 (-100.0)
# 80803.84 (-150.0)
# 79901.84 (-902.0)
# 79725.84 (-176.0)
# 79685.84 (-40.0)
# 79658.84 (-27.0)
# 79598.84 (-60.0)
# 78698.84 (-900.0)
# 77768.84 (-930.0)
# 77756.84 (-12.0)
# 76892.84 (-864.0)
# 76887.84 (-5.0)
# 76215.17 (-672.6700000000001)
# 76141.17 (-74.0)
# 76132.17 (-9.0)
# 75854.39 (-277.78)
# Sun Aug  9 02:04:01 2020 2020-03-07 5e65cefe7dbbc67594a4c8cb
# GENERATED 27454.0 OPPONENT LINEUPS Sun Aug  9 02:04:29 2020
# GENERATED 500 POTENTIAL LINEUPS Sun Aug  9 02:04:51 2020
# 76309.39 (455.0)
# 76144.39 (-165.0)
# 75202.39 (-942.0)
# Sun Aug  9 02:05:13 2020 2020-03-07 5e65cefea65ac875a2041fd5
# GENERATED 7721.0 OPPONENT LINEUPS Sun Aug  9 02:05:31 2020
# GENERATED 500 POTENTIAL LINEUPS Sun Aug  9 02:05:52 2020
# 74740.39 (-462.0)
# Sun Aug  9 02:06:01 2020 2020-03-08 5e65a1ab7dbbc67594a23550
# GENERATED 118907.5 OPPONENT LINEUPS Sun Aug  9 02:07:49 2020
# GENERATED 1492 POTENTIAL LINEUPS Sun Aug  9 02:10:30 2020
# 74140.39 (-600.0)
# 74040.39 (-100.0)
# 73890.39 (-150.0)
# 73002.39 (-888.0)
# 72962.39 (-40.0)
# 72935.39 (-27.0)
# 72875.39 (-60.0)
# 72115.39 (-760.0)
# 72015.39 (-100.0)
# 72003.39 (-12.0)
# 72018.39 (15.0)
# 71320.39 (-698.0)
# 71263.39 (-57.0)
# 71191.39 (-72.0)
# 71182.39 (-9.0)
# 70946.39 (-236.0)
# Sun Aug  9 02:13:26 2020 2020-03-08 5e66b53a8305f42cdd3a5264
# GENERATED 74317.5 OPPONENT LINEUPS Sun Aug  9 02:14:22 2020
# GENERATED 520 POTENTIAL LINEUPS Sun Aug  9 02:14:47 2020
# 70558.39 (-388.0)
# 70458.39 (-100.0)
# 69824.39 (-634.0)
# 69784.39 (-40.0)
# 69569.39 (-215.0)
# 68754.39 (-815.0)
# 68742.39 (-12.0)
# 68737.39 (-5.0)
# 68675.39 (-62.0)
# Sun Aug  9 02:15:53 2020 2020-03-08 5e66b56dcb9f602ccfe9f327
# GENERATED 44590.0 OPPONENT LINEUPS Sun Aug  9 02:16:45 2020
# GENERATED 500 POTENTIAL LINEUPS Sun Aug  9 02:17:09 2020
# 68635.39 (-40.0)
# 68616.39 (-19.0)
# 67826.39 (-790.0)
# 67831.39 (5.0)
# Sun Aug  9 02:17:39 2020 2020-03-08 5e66b5f38305f42cdd3aa367
# GENERATED 6177.5 OPPONENT LINEUPS Sun Aug  9 02:18:07 2020
# GENERATED 500 POTENTIAL LINEUPS Sun Aug  9 02:18:31 2020
# 67666.39 (-165.0)
# Sun Aug  9 02:18:38 2020 2020-03-09 5e66d1fa670a492cd5e8cf3f
# GENERATED 89181.0 OPPONENT LINEUPS Sun Aug  9 02:20:29 2020
# GENERATED 2122 POTENTIAL LINEUPS Sun Aug  9 02:24:38 2020
# 72228.39 (4562.0)
# 73528.39 (1300.0)
# 74378.39 (850.0)
# 74978.39 (600.0)
# 75778.39 (800.0)
# 170540.39 (94762.0)
# 177313.39 (6773.0)
# 177473.39 (160.0)
# 177491.39 (18.0)
# 178291.39 (800.0)
# 195034.06 (16742.67)
# 199136.0 (4101.9400000000005)
# 215846.0 (16710.0)
# 215874.0 (28.0)
# 216062.0 (188.0)
# 222665.16 (6603.16)
# 222700.16 (35.0)
# 228002.49 (5302.33)
# 228228.49 (226.0)
# 228469.33 (240.84)
# 234504.3 (6034.969999999999)
# Sun Aug  9 02:29:29 2020 2020-03-09 5e6709e7670a492cd5ebb523
# GENERATED 29727.5 OPPONENT LINEUPS Sun Aug  9 02:30:04 2020
# GENERATED 500 POTENTIAL LINEUPS Sun Aug  9 02:30:26 2020
# 234616.3 (112.0)
# 235733.12 (1116.82)
# 236363.12 (630.0)
# 236545.95 (182.82999999999998)
# Sun Aug  9 02:30:58 2020 2020-03-10 5e681cebdd839863a48fab20
# GENERATED 89181.0 OPPONENT LINEUPS Sun Aug  9 02:32:41 2020
# GENERATED 2176 POTENTIAL LINEUPS Sun Aug  9 02:37:55 2020
# 236745.95 (200.0)
# 236845.95 (100.0)
# 237320.95 (475.0)
# 237230.95 (-90.0)
# 237580.95 (350.0)
# 237660.95 (80.0)
# 237753.95 (93.0)
# 237793.95 (40.0)
# 238499.68 (705.73)
# 238532.68 (33.0)
# 238412.68 (-120.0)
# 238147.68 (-265.0)
# 243747.93 (5600.25)
# 243742.93 (-5.0)
# 243815.37 (72.44)
# 243828.37 (13.0)
# 244085.54 (257.17)
# 244088.54 (3.0)
# Sun Aug  9 02:42:25 2020 2020-03-10 5e6848d27d5fbf639eca4f34
# GENERATED 44590.0 OPPONENT LINEUPS Sun Aug  9 02:43:19 2020
# GENERATED 500 POTENTIAL LINEUPS Sun Aug  9 02:43:44 2020
# 245673.54 (1585.0)
# 245747.47 (73.93)
# 245742.47 (-5.0)
# 246247.47 (505.0)
# 247255.47 (1008.0)
# Sun Aug  9 02:44:26 2020 2020-03-10 5e68ed31722ce41dc59e9190
# GENERATED 24972.5 OPPONENT LINEUPS Sun Aug  9 02:45:09 2020
# GENERATED 500 POTENTIAL LINEUPS Sun Aug  9 02:45:33 2020
# 247134.47 (-121.0)
# Sun Aug  9 02:45:44 2020 2020-03-11 5e696e13f4053b1dcb589c40
# ERROR: MISSING TEAM DATA
# Sun Aug  9 02:45:44 2020 2020-03-11 5e6a282ee286d854732c3174
# GENERATED 10297.0 OPPONENT LINEUPS Sun Aug  9 02:46:09 2020
# GENERATED 500 POTENTIAL LINEUPS Sun Aug  9 02:46:31 2020
# 248437.81 (1303.3400000000001)
# Sun Aug  9 02:46:41 2020 2020-07-30 5f234ab5a728cd05439c999b
# COULD NOT GENERATE 83922.0 OPPONENT LINEUPS Sun Aug  9 02:56:41 2020

# %% [markdown]
# Plot overall PNL.

# %%
fig = plt.figure(1, figsize=(30, 15))

# overall PNL
temp = results.copy()
temp['PNL'] = temp['PRIZE'] - temp['ENTRY_FEE']
pnl = temp.groupby(['DATE']).apply(
    lambda x: pd.Series({
        'ENTRY_FEE': x['ENTRY_FEE'].sum(),
        'PRIZE': x['PRIZE'].sum(),
        'PNL': x['PNL'].sum()
    })
).reset_index()
pnl['RUNNING_PNL'] = pnl['PNL'].cumsum()

pnl['COLOR'] = pnl['PNL'].apply(lambda x: 'green' if x > 0 else 'red')
ax1 = sns.barplot(x=pnl.index, y='PNL', data=pnl, palette=pnl['COLOR'])
ax1.set_title('Overall PNL', fontsize=28)

xcoords = {
    pnl.index.min(): ('2017-18 SEASON START', 'k'),
    pnl.index[pnl['DATE'] == '2018-02-08'][0]: ('2017-18 SEASON TRADE DEADLINE', 'm'),
    pnl.index[pnl['DATE'] == '2018-02-22'][0]: ('2017-18 SEASON ALL-STAR RETURN', 'y'),
    pnl.index[pnl['DATE'] == '2018-10-19'][0]: ('2018-19 SEASON START', 'k'),
    pnl.index[pnl['DATE'] == '2019-02-07'][0]: ('2018-19 SEASON TRADE DEADLINE', 'm'),
    pnl.index[pnl['DATE'] == '2019-02-21'][0]: ('2018-19 SEASON ALL-STAR RETURN', 'y'),
    pnl.index[pnl['DATE'] == '2019-10-25'][0]: ('2019-20 SEASON START', 'k'),
    pnl.index[pnl['DATE'] == '2020-02-06'][0]: ('2019-20 SEASON TRADE DEADLINE', 'm'),
    pnl.index[pnl['DATE'] == '2020-02-20'][0]: ('2019-20 SEASON ALL-STAR RETURN', 'y'),
    
}
for xcoord in xcoords:
    ax1.axvline(x=xcoord, label=xcoords[xcoord][0], color=xcoords[xcoord][1], linestyle='dashed')
ax1.legend(bbox_to_anchor=(1, 1.35), loc='upper right', prop={'size': 16})

ax2 = ax1.twinx()
sns.lineplot(x=pnl.index, y='RUNNING_PNL', data=pnl, sort=False, color='tab:blue', ax=ax2)

ax1.set_xlabel('Date', fontsize=22)
ax1.set_ylabel('Daily PNL', fontsize=22)
ax2.set_ylabel('Cumulative PNL', fontsize=22)
ax1.set_xticks([])

ax1.tick_params(axis='both', labelsize=16)
ax2.tick_params(axis='both', labelsize=16)

plt.show()

# %% [markdown]
# Break down ROI by contest type, entry fee, and number of games in the slate to determine where my projections generate the most return on investment.

# %%
fig = plt.figure(1, figsize=(40, 30))
gs = fig.add_gridspec(2, 3)

# ROI vs. Entry Fee
temp = results.copy()
temp['ENTRY_BIN'] = pd.cut(temp['ENTRY_FEE'], bins=[0, 5, 10, 25, 50, 100, 250], duplicates='drop')
pnl = temp.groupby(['DATE', 'ENTRY_BIN']).apply(
    lambda x: pd.Series({
        'ENTRY_FEE': x['ENTRY_FEE'].sum(),
        'PRIZE': x['PRIZE'].sum()
    })
).reset_index()
pnl = pnl.merge(boxscores[['DATE', 'SEASON']], on=['DATE'], how='left')
pnl['ROI'] = (pnl['PRIZE'] - pnl['ENTRY_FEE'])/pnl['ENTRY_FEE']

ax4 = fig.add_subplot(gs[1, 0])
sns.barplot(x="ENTRY_BIN", y="ROI", hue="SEASON", data=pnl, ax=ax4)
ax4.set(xlabel="Entry Fee", ylabel="Return on Investment", title="Cash ROI vs. Entry Fee")
ax4.legend()

# ROI vs. Game Count
temp = results.copy()
temp['GAME_BIN'] = pd.cut(temp['GAME_COUNT'], bins=[0, 3, 6, 9, 15], duplicates='drop')
pnl = temp.groupby(['DATE', 'GAME_BIN']).apply(
    lambda x: pd.Series({
        'ENTRY_FEE': x['ENTRY_FEE'].sum(),
        'PRIZE': x['PRIZE'].sum()
    })
).reset_index()
pnl = pnl.merge(boxscores[['DATE', 'SEASON']], on=['DATE'], how='left')
pnl['ROI'] = (pnl['PRIZE'] - pnl['ENTRY_FEE'])/pnl['ENTRY_FEE']

ax5 = fig.add_subplot(gs[1, 1])
sns.barplot(x="GAME_BIN", y="ROI", hue="SEASON", data=pnl, ax=ax5)
ax5.set(xlabel="Number of Games in Slate", ylabel="Return on Investment", title="Cash ROI vs. Game Count")
ax5.legend()

# ROI vs. Entry Fee & Game Count
temp = results.copy()
temp['ENTRY_BIN'] = pd.cut(temp['ENTRY_FEE'], bins=[0, 5, 10, 25, 50, 100, 250], duplicates='drop')
temp['GAME_BIN'] = pd.cut(temp['GAME_COUNT'], bins=[0, 3, 6, 9, 15], duplicates='drop')
pnl = temp.groupby(['DATE', 'ENTRY_BIN', 'GAME_BIN']).apply(
    lambda x: pd.Series({
        'ENTRY_FEE': x['ENTRY_FEE'].sum(),
        'PRIZE': x['PRIZE'].sum()
    })
).reset_index()
pnl = pnl.merge(boxscores[['DATE', 'SEASON']], on=['DATE'], how='left')
pnl['ROI'] = (pnl['PRIZE'] - pnl['ENTRY_FEE'])/pnl['ENTRY_FEE']

ax6 = fig.add_subplot(gs[1, 2])
pnl['UPPER_ENTRY_FEE'] = pnl['ENTRY_BIN'].apply(lambda x: x.right)
pnl['UPPER_GAME_BIN'] = pnl['GAME_BIN'].apply(lambda x: x.right)
scat = pnl.groupby(['UPPER_GAME_BIN', 'UPPER_ENTRY_FEE']).apply(
    lambda x: pd.Series({
        'ROI': x['ROI'].mean()
    })
).reset_index()
sns.scatterplot(x='UPPER_ENTRY_FEE', y="UPPER_GAME_BIN", data=scat, hue='ROI', s=200, palette='coolwarm', ax=ax6)
ax6.set(xlabel="Entry Fee", ylabel="Number of Games in Slate", title="Cash ROI vs. Entry Fee & Game Count")
ax6.legend()

plt.show()

# %% [markdown]
# It is important not to overfit by cherry picking the contests in which the projections made money. To try to avoid this, I bucketed the entry fees and slate game counts. I will also only isolate a subset of contests if it makes sense why they were more profitable. The results above show that virtually no subset of cash games are profitable. On the other hand, tournaments whose entry fees are at most $1000 and slate game counts are at most 6 look profitable. This makes sense: higher entry contests attract more intelligent players, and high game slates introduce more variance.
#
# Below I will graph the cumulative PNL of a strategy that only enters contests in the subset described above. I will also include cash games whose entry fees are at most $25 and slate game counts are at most 3 to verify the lack of edge.

# %%
fig, plt.figure(1, figsize=(30, 15))

temp = results.loc[(results['GAME_COUNT'] <= 6)]
temp['PNL'] = temp['PRIZE'] - temp['ENTRY_FEE']
pnl = temp.groupby(['DATE']).apply(
    lambda x: pd.Series({
        'ENTRY_FEE': x['ENTRY_FEE'].sum(),
        'PRIZE': x['PRIZE'].sum(),
        'PNL': x['PNL'].sum()
    })
).reset_index()
pnl['RUNNING_PNL'] = pnl['PNL'].cumsum()

pnl['COLOR'] = pnl['PNL'].apply(lambda x: 'green' if x > 0 else 'red')
ax1 = sns.barplot(x=pnl.index, y='PNL', data=pnl, palette=pnl['COLOR'])
ax1.set_title('Tournament PNL', fontsize=28)

xcoords = {
    pnl.index.min(): ('2017-18 SEASON START', 'k'),
    pnl.index[pnl['DATE'] == '2018-02-08'][0]: ('2017-18 SEASON TRADE DEADLINE', 'm'),
    pnl.index[pnl['DATE'] == '2018-02-22'][0]: ('2017-18 SEASON ALL-STAR RETURN', 'y'),
    pnl.index[pnl['DATE'] == '2018-10-19'][0]: ('2018-19 SEASON START', 'k'),
    pnl.index[pnl['DATE'] == '2019-02-07'][0]: ('2018-19 SEASON TRADE DEADLINE', 'm'),
    pnl.index[pnl['DATE'] == '2019-02-21'][0]: ('2018-19 SEASON ALL-STAR RETURN', 'y'),
    pnl.index[pnl['DATE'] == '2019-10-25'][0]: ('2019-20 SEASON START', 'k'),
    pnl.index[pnl['DATE'] == '2020-02-06'][0]: ('2019-20 SEASON TRADE DEADLINE', 'm'),
    pnl.index[pnl['DATE'] == '2020-02-20'][0]: ('2019-20 SEASON ALL-STAR RETURN', 'y'),
    
}
for xcoord in xcoords:
    ax1.axvline(x=xcoord, color=xcoords[xcoord][1], linestyle='dashed')

ax2 = ax1.twinx()
sns.lineplot(x=pnl.index, y='RUNNING_PNL', data=pnl, sort=False, color='tab:blue', ax=ax2)

ax1.set_xlabel('Date', fontsize=22)
ax1.set_ylabel('Daily PNL', fontsize=22)
ax2.set_ylabel('Cumulative PNL', fontsize=22)
ax1.set_xticks([])

ax1.tick_params(axis='both', labelsize=16)
ax2.tick_params(axis='both', labelsize=16)

plt.show()

# %% [markdown]
# I will only focus on tournament contests going forward. The tournament strategy seems like it may actually be profitable. However, there is a lot of variance in PNL, as the cumulative PNL depends entirely on a few days in which it hit big. Most days the strategy loses money, and there are some significant drawdowns.
#
# Below shows the distribution of daily returns of this strategy.

# %%
temp = results.loc[(results['GAME_COUNT'] <= 6)]
temp['PNL'] = temp['PRIZE'] - temp['ENTRY_FEE']
pnl = temp.groupby(['DATE']).apply(
    lambda x: pd.Series({
        'ENTRY_FEE': x['ENTRY_FEE'].sum(),
        'PRIZE': x['PRIZE'].sum(),
        'PNL': x['PNL'].sum()
    })
).reset_index()
pnl['ROI'] = pnl['PNL']/pnl['ENTRY_FEE']
ax = sns.distplot(pnl['ROI'])
ax.set_title('PNL Distribution', fontsize=18)
plt.rcParams["figure.figsize"] = (20, 10)
plt.show()

print('ROI Statistics:')
pnl['ROI'].describe()
# Out:
# ROI Statistics:
# count    454.000000
# mean       0.276356
# std        2.390047
# min       -0.986486
# 25%       -0.653115
# 50%       -0.371430
# 75%        0.296109
# max       31.606050
# Name: ROI, dtype: float64

# %%
print(pnl['PRIZE'].mean())
print(pnl['ENTRY_FEE'].mean())
# Out:
# 5501.786806167401
# 4561.454405286344
