# %%
# for data
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from pyNBA.Data.data import QueryData
from pyNBA.Models.helpers import CleanData
import math
from pyNBA.Data.constants import BAD_CONTEST_SUBSTRINGS, DB_TEAM_TO_NBA_TEAM, OWNERSHIP_NAME_TO_NBA_NAME
from functools import reduce

# for features
from pyNBA.Models.features import FeatureCreation
from pyNBA.Models.cluster import Cluster, Evaluate
from sklearn.feature_selection import SelectFromModel
from sklearn.feature_selection import RFE
from pyNBA.DFS.rules import FPCalculator
from pyNBA.DFS.constants import Site

# for plotting
import matplotlib.pyplot as plt
import seaborn as sns
from research import Helpers
from statsmodels.graphics.api import abline_plot

# for machine learning
from sklearn import model_selection, preprocessing, ensemble, neighbors, linear_model, svm, neural_network, metrics
import xgboost as xgb
from catboost import CatBoostRegressor, Pool
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split

# misc
import warnings
warnings.filterwarnings('ignore')
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
query_data = QueryData()

# historical DFS contest data. I am only interested in predicting ownership in Classic GPP compeititions.
contest_data = query_data.query_contest_data()
contest_data = contest_data.loc[
    (contest_data['CASHLINE'] > 0) & (contest_data['SLATETYPE'] == 'Classic') & (contest_data['CASHLINE'] > 200) &
    (~contest_data['CONTESTNAME'].str.lower().str.contains('|'.join(BAD_CONTEST_SUBSTRINGS)))
].dropna(subset=['CASHLINE'])
contest_data['MAXROI'] = contest_data['TOPPRIZE']/contest_data['ENTRYFEE']
contest_data = contest_data.loc[contest_data['MAXROI'] > 2]

# historical vegas odds data
odds_data = query_data.query_odds_data()
full_game_odds = odds_data.loc[odds_data['PERIOD'] == 'Full Game']
# Out:
# /Users/brandonshimiaie/Projects/pyNBA/sqlite/db/nba.db
# 2.6.0

# %%
contest_data['TEAMSLIST'] = contest_data['TEAMS'].apply(lambda x: x.split('_'))
team_contest_data = contest_data.explode('TEAMSLIST').rename(columns={'TEAMSLIST': 'TEAM'})
team_contest_data['TEAM'] = team_contest_data['TEAM'].apply(lambda x: x if x not in DB_TEAM_TO_NBA_TEAM else DB_TEAM_TO_NBA_TEAM[x])
team_contest_data = team_contest_data.merge(full_game_odds, on=['DATE', 'TEAM'], how='left')
team_contest_data = team_contest_data.dropna(subset=['TOTAL'])

# %%
contest_average_total = team_contest_data.groupby(['DATE', 'CONTESTID']).apply(
    lambda x: pd.Series({
        'AVERAGE_TOTAL': x['TOTAL'].mean()
    })
).reset_index()
contest_data = contest_data.merge(contest_average_total, on=['DATE', 'CONTESTID'], how='left')

# %%
display(contest_data)
# Out:
#              SITE        DATE                   SLATEID SLATETYPE  GAMECOUNT  \
# 0      DRAFTKINGS  2020-03-11  5e6a282ee286d854732c3174   Classic          2
# 1      DRAFTKINGS  2020-03-11  5e696e13f4053b1dcb589c40   Classic          6
# 2      DRAFTKINGS  2020-03-11  5e696e13f4053b1dcb589c40   Classic          6
# 3      DRAFTKINGS  2020-03-11  5e696e13f4053b1dcb589c40   Classic          6
# 4      DRAFTKINGS  2020-03-11  5e696e13f4053b1dcb589c40   Classic          6
# ...           ...         ...                       ...       ...        ...
# 15033  DRAFTKINGS  2017-10-18  5ae4d5805689223dfa12d8ad   Classic         11
# 15034  DRAFTKINGS  2017-10-18  5ae4d5805689223dfa12d8ad   Classic         11
# 15035  DRAFTKINGS  2017-10-18  5ae4d5805689223dfa12d8ad   Classic         11
# 15036  DRAFTKINGS  2017-10-18  5ae4d5805689223dfa12d8ad   Classic         11
# 15037  DRAFTKINGS  2017-10-18  5ae4d5805689223dfa12d8ad   Classic         11
#
#                                                    TEAMS  \
# 0                                        MIA_NYK_ATL_CHA
# 1        DAL_MIA_NOP_DET_NYK_UTA_PHI_ATL_DEN_SAC_OKC_CHA
# 2        DAL_MIA_NOP_DET_NYK_UTA_PHI_ATL_DEN_SAC_OKC_CHA
# 3        DAL_MIA_NOP_DET_NYK_UTA_PHI_ATL_DEN_SAC_OKC_CHA
# 4        DAL_MIA_NOP_DET_NYK_UTA_PHI_ATL_DEN_SAC_OKC_CHA
# ...                                                  ...
# 15033  MIA_SAS_ORL_BKN_BOS_MIL_DEN_CHA_IND_PHI_DAL_NO...
# 15034  MIA_SAS_ORL_BKN_BOS_MIL_DEN_CHA_IND_PHI_DAL_NO...
# 15035  MIA_SAS_ORL_BKN_BOS_MIL_DEN_CHA_IND_PHI_DAL_NO...
# 15036  MIA_SAS_ORL_BKN_BOS_MIL_DEN_CHA_IND_PHI_DAL_NO...
# 15037  MIA_SAS_ORL_BKN_BOS_MIL_DEN_CHA_IND_PHI_DAL_NO...
#
#                       CONTESTID                                  CONTESTNAME  \
# 0      5e6a282ee286d854732c327d  NBA $20K Excellent 8's [$5K to 1st] (Turbo)
# 1      5e6a280d3ce272546761b206         NBA $7.5K Pick and Pop [3 Entry Max]
# 2      5e6a280e3ce272546761b33e          NBA $5K Ankle Breaker [3 Entry Max]
# 3      5e6a288670cbeb5483f3cc83         NBA $10K Buzzer Beater [3 Entry Max]
# 4      5e6a282570cbeb5483f29c7d                   NBA $25K Zone [$5K to 1st]
# ...                         ...                                          ...
# 15033  5ae50c1c085a677335596ae1      NBA $6K Mid-Range Jumper [Single Entry]
# 15034  5ae4d5805689223dfa12da16            NBA $10K Posterizer [2 Entry Max]
# 15035  5ae4d66ff69c5a3e0026d7ea               NBA $5K Hot Shot [3 Entry Max]
# 15036  5ae6006bfd67640e26e3a516          NBA $10K Pick & Roll [Single Entry]
# 15037  5ae627149b41d020924e0486           NBA $6K Pick & Roll [Single Entry]
#
#        PRIZEPOOL  ENTRYFEE  TOPPRIZE  MAXENTRIES  TOTALENTRIES  CASHLINE  \
# 0        20000.0       8.0    5000.0        88.0          2942    301.50
# 1         7500.0      75.0    1500.0         3.0           114    242.50
# 2         5000.0      50.0     600.0         3.0           114    265.00
# 3        10000.0      20.0    1000.0         3.0           589    249.00
# 4        25000.0       5.0    5000.0       150.0          5946    241.25
# ...          ...       ...       ...         ...           ...       ...
# 15033     6000.0      40.0     720.0         1.0           174    279.00
# 15034    10000.0     150.0    2000.0         2.0            74    280.75
# 15035     5000.0       3.0     500.0         3.0          1981    281.25
# 15036    10000.0      12.0    1000.0         1.0           980    278.75
# 15037     6000.0      12.0     600.0         1.0           588    277.50
#
#        TOPSCORE       MAXROI  \
# 0        352.50   625.000000
# 1        316.50    20.000000
# 2        337.75    12.000000
# 3        352.50    50.000000
# 4        371.25  1000.000000
# ...         ...          ...
# 15033    333.00    18.000000
# 15034    320.50    13.333333
# 15035    358.00   166.666667
# 15036    349.75    83.333333
# 15037    323.50    50.000000
#
#                                                TEAMSLIST  AVERAGE_TOTAL
# 0                                   [MIA, NYK, ATL, CHA]     220.750000
# 1      [DAL, MIA, NOP, DET, NYK, UTA, PHI, ATL, DEN, ...     221.666667
# 2      [DAL, MIA, NOP, DET, NYK, UTA, PHI, ATL, DEN, ...     221.666667
# 3      [DAL, MIA, NOP, DET, NYK, UTA, PHI, ATL, DEN, ...     221.666667
# 4      [DAL, MIA, NOP, DET, NYK, UTA, PHI, ATL, DEN, ...     221.666667
# ...                                                  ...            ...
# 15033  [MIA, SAS, ORL, BKN, BOS, MIL, DEN, CHA, IND, ...     209.227273
# 15034  [MIA, SAS, ORL, BKN, BOS, MIL, DEN, CHA, IND, ...     209.227273
# 15035  [MIA, SAS, ORL, BKN, BOS, MIL, DEN, CHA, IND, ...     209.227273
# 15036  [MIA, SAS, ORL, BKN, BOS, MIL, DEN, CHA, IND, ...     209.227273
# 15037  [MIA, SAS, ORL, BKN, BOS, MIL, DEN, CHA, IND, ...     209.227273
#
# [15038 rows x 18 columns]

# %%
regressors = ['GAMECOUNT', 'ENTRYFEE', 'TOPPRIZE', 'MAXENTRIES', 'TOTALENTRIES', 'AVERAGE_TOTAL']
y = 'TOPSCORE'
feature_matrix = contest_data[['DATE', 'CONTESTNAME'] + regressors + [y]]

# %%
helpers = Helpers()
plt.rcParams["figure.figsize"] = (22, 10)
helpers.visualize_dataframe(feature_matrix)
# Out:
#  Categerocial   Numeric   NaN
#
# Percentage of rows containing at least one missing value: 0.0

# %%
linear_models = [
    linear_model.LinearRegression()
#     linear_model.Ridge(),
#     linear_model.ElasticNet()
]

neighbor_models = [
#     neighbors.KNeighborsRegressor()
]

boosted_models = [
    xgb.XGBRegressor(objective='reg:squarederror', eval_metric='mae', learning_rate=0.1, n_estimators=500, tree_method='hist'),
    CatBoostRegressor(eval_metric='MAE', learning_rate=0.1, n_estimators=500, silent=True)
    
]

neural_networks = [
    neural_network.MLPRegressor(max_iter=10000, early_stopping=True, random_state=42)
]

models = linear_models + neighbor_models + boosted_models + neural_networks

transformer = {
        'Function': lambda x: x,
        'Inverse Function': lambda x: x,
        'Name': 'None'
}

numeric_regressors = list(set(regressors))
numeric_columns = numeric_regressors + [y]

min_score = float('inf')
best_model = None
for model in models:
      
    # transform numeric columns
    temp_feature_matrix = feature_matrix.copy()
    temp_feature_matrix[numeric_columns] = temp_feature_matrix[numeric_columns].apply(
        transformer['Function'], axis=1
    )

    # feature selection
    X = temp_feature_matrix[regressors]
    Y = temp_feature_matrix[y]

    if model in (neighbor_models + neural_networks):
        selected_features = regressors.copy()
    else:
        model.fit(X, Y)

        # importance
        importance_selector = SelectFromModel(model, threshold='0.75*median')
        importance_selector = importance_selector.fit(X, Y)
        importance_support = importance_selector.get_support()

        # rank
        rank_selector = RFE(model)
        rank_selector = rank_selector.fit(X, Y)
        rank_support = rank_selector.ranking_
        median_rank = np.median(rank_support)

        selected_features = []
        for feature, importance_flag, rank in zip(list(X.columns), importance_support, rank_support):
            # select the feature if it's important, or has a low rank
            if importance_flag or (rank <= median_rank):
                selected_features.append(feature)

    X = temp_feature_matrix[selected_features].values
    Y = temp_feature_matrix[y].values

    # cross validation
    scores = []
    cv = model_selection.KFold(n_splits=5, shuffle=True)
    for train, test in cv.split(X, Y):
        prediction = model.fit(X[train], Y[train]).predict(X[test])
        true = Y[test]

        prediction = transformer['Inverse Function'](prediction)
        true = transformer['Inverse Function'](true)

        scores.append(metrics.mean_absolute_error(prediction, true))

    mean_score = np.mean(scores)
    print('\nModel:', model)
    print('Transformer:', transformer['Name'])
    print('Selected Features:', selected_features)
    print('Mean MAE:', mean_score)
    if mean_score < min_score:
        min_score = mean_score
        best_model = (model, transformer['Name'], selected_features)

print()
print(best_model, min_score)
# Out:
# Model: LinearRegression()
# Transformer: None
# Selected Features: ['GAMECOUNT', 'MAXENTRIES', 'AVERAGE_TOTAL']
# Mean MAE: 21.387289181379785
#
# Model: XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, eval_metric='mae', gamma=0,
#              gpu_id=-1, importance_type='gain', interaction_constraints='',
#              learning_rate=0.1, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=500, n_jobs=0, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='hist', validate_parameters=1, verbosity=None)
# Transformer: None
# Selected Features: ['GAMECOUNT', 'TOTALENTRIES', 'AVERAGE_TOTAL']
# Mean MAE: 11.996223223963375
#
# Model: <catboost.core.CatBoostRegressor object at 0x12fc794a8>
# Transformer: None
# Selected Features: ['GAMECOUNT', 'TOTALENTRIES', 'AVERAGE_TOTAL']
# Mean MAE: 13.367891325699011
#
# Model: MLPRegressor(early_stopping=True, max_iter=10000, random_state=42)
# Transformer: None
# Selected Features: ['GAMECOUNT', 'ENTRYFEE', 'TOPPRIZE', 'MAXENTRIES', 'TOTALENTRIES', 'AVERAGE_TOTAL']
# Mean MAE: 21.469312762950846
#
# (XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, eval_metric='mae', gamma=0,
#              gpu_id=-1, importance_type='gain', interaction_constraints='',
#              learning_rate=0.1, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=500, n_jobs=0, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='hist', validate_parameters=1, verbosity=None), 'None', ['GAMECOUNT', 'TOTALENTRIES', 'AVERAGE_TOTAL']) 11.996223223963375

# %%
selected_features =  ['GAMECOUNT', 'TOTALENTRIES', 'AVERAGE_TOTAL']
X = feature_matrix[selected_features]
Y = feature_matrix[y]
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.25, random_state=1)

# %%
model = xgb.XGBRegressor()

model_params = {
    'max_depth': [4, 6, 8, 10],
    'eta' : [0.01, 0.02, 0.05, 0.1],
    'n_estimators': [5000],
    'eval_metric': ['mae'],
    'tree_method': ['hist']
}

grid = GridSearchCV(estimator=model, param_grid=model_params, scoring='neg_mean_absolute_error', cv=2, n_jobs=-1)

fit_params = {
    "early_stopping_rounds": 25,
    "eval_set": [(X_test, y_test)]
}

grid.fit(X_train, y_train, **fit_params)    

print("\n========================================================")
print(" Results from Grid Search " )
print("========================================================")    

print("\n The best estimator across ALL searched params:\n", grid.best_estimator_)

print("\n The best score across ALL searched params:\n", grid.best_score_)

print("\n The best parameters across ALL searched params:\n", grid.best_params_)

print("\n ========================================================")
# Out:
# [0]	validation_0-mae:321.28171
# Will train until validation_0-mae hasn't improved in 25 rounds.
# [1]	validation_0-mae:305.24341
# [2]	validation_0-mae:290.00174
# [3]	validation_0-mae:275.52103
# [4]	validation_0-mae:261.76086
# [5]	validation_0-mae:248.69035
# [6]	validation_0-mae:236.27896
# [7]	validation_0-mae:224.48322
# [8]	validation_0-mae:213.27463
# [9]	validation_0-mae:202.63275
# [10]	validation_0-mae:192.51916
# [11]	validation_0-mae:182.91725
# [12]	validation_0-mae:173.78989
# [13]	validation_0-mae:165.10310
# [14]	validation_0-mae:156.86307
# [15]	validation_0-mae:149.05225
# [16]	validation_0-mae:141.60292
# [17]	validation_0-mae:134.54460
# [18]	validation_0-mae:127.82580
# [19]	validation_0-mae:121.46277
# [20]	validation_0-mae:115.40423
# [21]	validation_0-mae:109.64863
# [22]	validation_0-mae:104.18672
# [23]	validation_0-mae:98.99038
# [24]	validation_0-mae:94.05547
# [25]	validation_0-mae:89.36540
# [26]	validation_0-mae:84.92107
# [27]	validation_0-mae:80.69498
# [28]	validation_0-mae:76.68877
# [29]	validation_0-mae:72.87573
# [30]	validation_0-mae:69.26188
# [31]	validation_0-mae:65.83275
# [32]	validation_0-mae:62.57188
# [33]	validation_0-mae:59.48191
# [34]	validation_0-mae:56.54030
# [35]	validation_0-mae:53.75865
# [36]	validation_0-mae:51.13111
# [37]	validation_0-mae:48.64072
# [38]	validation_0-mae:46.28744
# [39]	validation_0-mae:44.08230
# [40]	validation_0-mae:42.00194
# [41]	validation_0-mae:40.05356
# [42]	validation_0-mae:38.23104
# [43]	validation_0-mae:36.52097
# [44]	validation_0-mae:34.92273
# [45]	validation_0-mae:33.44489
# [46]	validation_0-mae:32.06457
# [47]	validation_0-mae:30.77855
# [48]	validation_0-mae:29.59088
# [49]	validation_0-mae:28.50346
# [50]	validation_0-mae:27.48887
# [51]	validation_0-mae:26.54615
# [52]	validation_0-mae:25.68524
# [53]	validation_0-mae:24.89349
# [54]	validation_0-mae:24.15288
# [55]	validation_0-mae:23.47760
# [56]	validation_0-mae:22.86038
# [57]	validation_0-mae:22.29570
# [58]	validation_0-mae:21.78156
# [59]	validation_0-mae:21.30317
# [60]	validation_0-mae:20.87797
# [61]	validation_0-mae:20.48632
# [62]	validation_0-mae:20.13704
# [63]	validation_0-mae:19.80916
# [64]	validation_0-mae:19.51340
# [65]	validation_0-mae:19.23469
# [66]	validation_0-mae:18.98182
# [67]	validation_0-mae:18.75555
# [68]	validation_0-mae:18.54682
# [69]	validation_0-mae:18.34635
# [70]	validation_0-mae:18.18083
# [71]	validation_0-mae:18.02205
# [72]	validation_0-mae:17.87940
# [73]	validation_0-mae:17.75067
# [74]	validation_0-mae:17.63238
# [75]	validation_0-mae:17.52148
# [76]	validation_0-mae:17.42875
# [77]	validation_0-mae:17.34504
# [78]	validation_0-mae:17.25935
# [79]	validation_0-mae:17.16316
# [80]	validation_0-mae:17.07819
# [81]	validation_0-mae:16.99317
# [82]	validation_0-mae:16.92126
# [83]	validation_0-mae:16.86887
# [336]	validation_0-mae:13.34009
# [337]	validation_0-mae:13.33095
# [338]	validation_0-mae:13.32479
# [339]	validation_0-mae:13.31716
# [340]	validation_0-mae:13.31661
# [341]	validation_0-mae:13.30947
# [342]	validation_0-mae:13.30351
# [343]	validation_0-mae:13.29649
# [344]	validation_0-mae:13.29671
# [345]	validation_0-mae:13.27826
# [346]	validation_0-mae:13.27804
# [347]	validation_0-mae:13.26948
# [348]	validation_0-mae:13.26948
# [349]	validation_0-mae:13.26132
# [350]	validation_0-mae:13.26180
# [351]	validation_0-mae:13.25272
# [352]	validation_0-mae:13.25212
# [353]	validation_0-mae:13.24583
# [354]	validation_0-mae:13.24526
# [355]	validation_0-mae:13.24580
# [356]	validation_0-mae:13.24378
# [357]	validation_0-mae:13.23126
# [358]	validation_0-mae:13.23065
# [359]	validation_0-mae:13.21917
# [360]	validation_0-mae:13.21678
# [361]	validation_0-mae:13.21657
# [362]	validation_0-mae:13.20626
# [363]	validation_0-mae:13.20096
# [364]	validation_0-mae:13.19479
# [365]	validation_0-mae:13.19369
# [366]	validation_0-mae:13.19411
# [367]	validation_0-mae:13.18941
# [368]	validation_0-mae:13.17588
# [369]	validation_0-mae:13.17355
# [370]	validation_0-mae:13.17002
# [371]	validation_0-mae:13.17155
# [372]	validation_0-mae:13.16538
# [373]	validation_0-mae:13.15895
# [374]	validation_0-mae:13.16088
# [375]	validation_0-mae:13.15919
# [376]	validation_0-mae:13.15867
# [377]	validation_0-mae:13.15263
# [378]	validation_0-mae:13.14402
# [379]	validation_0-mae:13.13359
# [380]	validation_0-mae:13.12719
# [381]	validation_0-mae:13.12591
# [382]	validation_0-mae:13.11949
# [383]	validation_0-mae:13.11212
# [384]	validation_0-mae:13.10539
# [385]	validation_0-mae:13.10396
# [386]	validation_0-mae:13.10393
# [387]	validation_0-mae:13.10346
# [388]	validation_0-mae:13.10255
# [389]	validation_0-mae:13.09926
# [390]	validation_0-mae:13.09689
# [391]	validation_0-mae:13.09521
# [392]	validation_0-mae:13.07991
# [393]	validation_0-mae:13.06621
# [394]	validation_0-mae:13.06225
# [395]	validation_0-mae:13.06184
# [396]	validation_0-mae:13.06242
# [397]	validation_0-mae:13.06122
# [398]	validation_0-mae:13.05764
# [399]	validation_0-mae:13.05493
# [400]	validation_0-mae:13.05512
# [401]	validation_0-mae:13.04464
# [402]	validation_0-mae:13.04474
# [403]	validation_0-mae:13.03915
# [404]	validation_0-mae:13.03811
# [405]	validation_0-mae:13.03656
# [406]	validation_0-mae:13.03523
# [407]	validation_0-mae:13.03542
# [408]	validation_0-mae:13.02474
# [409]	validation_0-mae:13.02000
# [410]	validation_0-mae:13.01898
# [411]	validation_0-mae:13.01889
# [412]	validation_0-mae:13.01093
# [413]	validation_0-mae:13.00047
# [414]	validation_0-mae:12.99481
# [415]	validation_0-mae:12.98508
# [416]	validation_0-mae:12.98425
# [417]	validation_0-mae:12.98366
# [418]	validation_0-mae:12.98180
# [419]	validation_0-mae:12.97434
# [420]	validation_0-mae:12.97424
# [421]	validation_0-mae:12.96768
# [422]	validation_0-mae:12.96877
# [423]	validation_0-mae:12.96534
# [424]	validation_0-mae:12.95946
# [425]	validation_0-mae:12.94961
# [426]	validation_0-mae:12.94098
# [427]	validation_0-mae:12.93086
# [428]	validation_0-mae:12.92948
# [429]	validation_0-mae:12.91999
# [430]	validation_0-mae:12.92070
# [431]	validation_0-mae:12.92081
# [432]	validation_0-mae:12.92143
# [433]	validation_0-mae:12.92201
# [434]	validation_0-mae:12.92141
# [435]	validation_0-mae:12.91210
# [436]	validation_0-mae:12.91109
# [437]	validation_0-mae:12.89930
# [438]	validation_0-mae:12.89983
# [439]	validation_0-mae:12.89236
# [440]	validation_0-mae:12.88576
# [441]	validation_0-mae:12.87556
# [442]	validation_0-mae:12.87570
# [443]	validation_0-mae:12.87567
# [444]	validation_0-mae:12.87450
# [445]	validation_0-mae:12.87331
# [446]	validation_0-mae:12.87226
# [447]	validation_0-mae:12.86444
# [448]	validation_0-mae:12.85696
# [449]	validation_0-mae:12.84835
# [450]	validation_0-mae:12.83744
# [451]	validation_0-mae:12.83469
# [452]	validation_0-mae:12.83211
# [453]	validation_0-mae:12.82563
# [454]	validation_0-mae:12.80912
# [455]	validation_0-mae:12.80155
# [456]	validation_0-mae:12.79218
# [457]	validation_0-mae:12.78742
# [458]	validation_0-mae:12.78530
# [459]	validation_0-mae:12.78505
# [460]	validation_0-mae:12.78536
# [461]	validation_0-mae:12.78052
# [462]	validation_0-mae:12.77398
# [463]	validation_0-mae:12.77153
# [464]	validation_0-mae:12.76818
# [465]	validation_0-mae:12.76796
# [466]	validation_0-mae:12.76503
# [467]	validation_0-mae:12.76315
# [468]	validation_0-mae:12.74453
# [469]	validation_0-mae:12.74302
# [470]	validation_0-mae:12.74285
# [471]	validation_0-mae:12.74404
# [472]	validation_0-mae:12.74420
# [473]	validation_0-mae:12.74383
# [474]	validation_0-mae:12.74456
# [475]	validation_0-mae:12.74165
# [476]	validation_0-mae:12.74106
# [477]	validation_0-mae:12.74102
# [478]	validation_0-mae:12.73975
# [479]	validation_0-mae:12.73868
# [480]	validation_0-mae:12.73740
# [481]	validation_0-mae:12.72756
# [482]	validation_0-mae:12.72520
# [483]	validation_0-mae:12.71254
# [484]	validation_0-mae:12.71137
# [485]	validation_0-mae:12.70529
# [486]	validation_0-mae:12.69948
# [487]	validation_0-mae:12.69341
# [488]	validation_0-mae:12.69230
# [489]	validation_0-mae:12.69196
# [490]	validation_0-mae:12.67469
# [491]	validation_0-mae:12.67609
# [492]	validation_0-mae:12.67503
# [493]	validation_0-mae:12.67489
# [494]	validation_0-mae:12.67070
# [495]	validation_0-mae:12.66233
# [496]	validation_0-mae:12.66040
# [497]	validation_0-mae:12.66087
# [498]	validation_0-mae:12.65348
# [499]	validation_0-mae:12.65373
# [500]	validation_0-mae:12.65394
# [501]	validation_0-mae:12.64020
# [502]	validation_0-mae:12.63588
# [503]	validation_0-mae:12.63537
# [504]	validation_0-mae:12.63426
# [505]	validation_0-mae:12.63302
# [506]	validation_0-mae:12.62884
# [507]	validation_0-mae:12.62806
# [508]	validation_0-mae:12.62658
# [509]	validation_0-mae:12.61967
# [510]	validation_0-mae:12.61317
# [511]	validation_0-mae:12.60607
# [512]	validation_0-mae:12.60145
# [513]	validation_0-mae:12.60076
# [514]	validation_0-mae:12.59218
# [515]	validation_0-mae:12.58644
# [516]	validation_0-mae:12.58183
# [517]	validation_0-mae:12.57626
# [518]	validation_0-mae:12.57022
# [519]	validation_0-mae:12.56672
# [520]	validation_0-mae:12.56247
# [521]	validation_0-mae:12.55799
# [522]	validation_0-mae:12.55502
# [523]	validation_0-mae:12.54754
# [524]	validation_0-mae:12.54237
# [525]	validation_0-mae:12.54203
# [526]	validation_0-mae:12.54192
# [527]	validation_0-mae:12.54139
# [528]	validation_0-mae:12.52589
# [529]	validation_0-mae:12.52410
# [530]	validation_0-mae:12.51259
# [531]	validation_0-mae:12.51013
# [532]	validation_0-mae:12.51010
# [533]	validation_0-mae:12.49618
# [534]	validation_0-mae:12.48888
# [535]	validation_0-mae:12.47734
# [536]	validation_0-mae:12.47865
# [537]	validation_0-mae:12.47786
# [538]	validation_0-mae:12.47595
# [539]	validation_0-mae:12.46638
# [540]	validation_0-mae:12.46601
# [541]	validation_0-mae:12.46598
# [542]	validation_0-mae:12.46585
# [543]	validation_0-mae:12.46697
# [544]	validation_0-mae:12.46311
# [545]	validation_0-mae:12.46332
# [546]	validation_0-mae:12.46292
# [547]	validation_0-mae:12.45607
# [548]	validation_0-mae:12.45334
# [549]	validation_0-mae:12.44960
# [550]	validation_0-mae:12.44956
# [551]	validation_0-mae:12.44449
# [552]	validation_0-mae:12.44225
# [553]	validation_0-mae:12.44215
# [554]	validation_0-mae:12.43836
# [555]	validation_0-mae:12.43835
# [556]	validation_0-mae:12.43881
# [557]	validation_0-mae:12.43763
# [558]	validation_0-mae:12.43692
# [559]	validation_0-mae:12.43746
# [560]	validation_0-mae:12.43811
# [561]	validation_0-mae:12.43832
# [562]	validation_0-mae:12.43770
# [563]	validation_0-mae:12.43670
# [564]	validation_0-mae:12.43718
# [565]	validation_0-mae:12.43849
# [566]	validation_0-mae:12.43633
# [567]	validation_0-mae:12.42699
# [568]	validation_0-mae:12.41421
# [569]	validation_0-mae:12.41084
# [570]	validation_0-mae:12.40873
# [571]	validation_0-mae:12.39837
# [572]	validation_0-mae:12.39780
# [573]	validation_0-mae:12.39648
# [574]	validation_0-mae:12.39637
# [575]	validation_0-mae:12.39706
# [576]	validation_0-mae:12.39474
# [577]	validation_0-mae:12.39432
# [578]	validation_0-mae:12.38819
# [579]	validation_0-mae:12.38119
# [580]	validation_0-mae:12.38043
# [581]	validation_0-mae:12.37879
# [582]	validation_0-mae:12.37593
# [583]	validation_0-mae:12.37660
# [584]	validation_0-mae:12.36710
# [585]	validation_0-mae:12.36488
# [586]	validation_0-mae:12.36520
# [587]	validation_0-mae:12.36243
# [588]	validation_0-mae:12.36121
# [589]	validation_0-mae:12.35926
# [590]	validation_0-mae:12.35403
# [591]	validation_0-mae:12.35406
# [592]	validation_0-mae:12.35485
# [593]	validation_0-mae:12.35066
# [594]	validation_0-mae:12.34899
# [595]	validation_0-mae:12.34451
# [596]	validation_0-mae:12.34112
# [597]	validation_0-mae:12.34134
# [598]	validation_0-mae:12.34201
# [599]	validation_0-mae:12.34204
# [600]	validation_0-mae:12.33396
# [601]	validation_0-mae:12.32483
# [602]	validation_0-mae:12.32534
# [603]	validation_0-mae:12.32375
# [604]	validation_0-mae:12.31176
# [605]	validation_0-mae:12.30371
# [606]	validation_0-mae:12.29047
# [607]	validation_0-mae:12.28229
# [608]	validation_0-mae:12.27267
# [609]	validation_0-mae:12.27246
# [610]	validation_0-mae:12.27257
# [611]	validation_0-mae:12.26298
# [612]	validation_0-mae:12.26053
# [613]	validation_0-mae:12.26112
# [614]	validation_0-mae:12.25558
# [615]	validation_0-mae:12.25359
# [616]	validation_0-mae:12.24720
# [617]	validation_0-mae:12.24032
# [618]	validation_0-mae:12.23273
# [619]	validation_0-mae:12.23169
# [620]	validation_0-mae:12.22727
# [621]	validation_0-mae:12.22493
# [622]	validation_0-mae:12.21964
# [623]	validation_0-mae:12.21683
# [624]	validation_0-mae:12.21427
# [625]	validation_0-mae:12.20745
# [626]	validation_0-mae:12.20740
# [627]	validation_0-mae:12.20657
# [628]	validation_0-mae:12.20727
# [629]	validation_0-mae:12.20717
# [630]	validation_0-mae:12.20766
# [631]	validation_0-mae:12.20795
# [632]	validation_0-mae:12.20894
# [633]	validation_0-mae:12.20993
# [634]	validation_0-mae:12.20880
# [635]	validation_0-mae:12.20689
# [636]	validation_0-mae:12.20388
# [637]	validation_0-mae:12.19744
# [638]	validation_0-mae:12.19154
# [639]	validation_0-mae:12.18353
# [640]	validation_0-mae:12.18094
# [641]	validation_0-mae:12.17989
# [642]	validation_0-mae:12.18061
# [643]	validation_0-mae:12.17995
# [644]	validation_0-mae:12.17953
# [645]	validation_0-mae:12.17404
# [646]	validation_0-mae:12.17139
# [647]	validation_0-mae:12.17069
# [648]	validation_0-mae:12.16995
# [649]	validation_0-mae:12.16450
# [650]	validation_0-mae:12.16265
# [651]	validation_0-mae:12.16064
# [652]	validation_0-mae:12.15738
# [653]	validation_0-mae:12.15695
# [654]	validation_0-mae:12.15657
# [655]	validation_0-mae:12.15465
# [656]	validation_0-mae:12.15033
# [657]	validation_0-mae:12.14973
# [658]	validation_0-mae:12.14560
# [659]	validation_0-mae:12.14123
# [660]	validation_0-mae:12.13248
# [661]	validation_0-mae:12.13037
# [662]	validation_0-mae:12.12788
# [663]	validation_0-mae:12.12509
# [664]	validation_0-mae:12.12635
# [665]	validation_0-mae:12.12452
# [666]	validation_0-mae:12.12376
# [667]	validation_0-mae:12.12132
# [668]	validation_0-mae:12.11960
# [669]	validation_0-mae:12.11597
# [670]	validation_0-mae:12.11356
# [671]	validation_0-mae:12.11088
# [672]	validation_0-mae:12.11216
# [673]	validation_0-mae:12.11158
# [674]	validation_0-mae:12.11159
# [675]	validation_0-mae:12.11125
# [676]	validation_0-mae:12.10906
# [677]	validation_0-mae:12.10521
# [678]	validation_0-mae:12.10478
# [679]	validation_0-mae:12.10521
# [680]	validation_0-mae:12.09940
# [681]	validation_0-mae:12.09646
# [682]	validation_0-mae:12.09591
# [683]	validation_0-mae:12.09531
# [684]	validation_0-mae:12.09528
# [685]	validation_0-mae:12.09214
# [686]	validation_0-mae:12.09175
# [687]	validation_0-mae:12.09081
# [688]	validation_0-mae:12.08717
# [689]	validation_0-mae:12.08721
# [690]	validation_0-mae:12.08771
# [691]	validation_0-mae:12.08724
# [692]	validation_0-mae:12.08644
# [693]	validation_0-mae:12.08488
# [694]	validation_0-mae:12.08435
# [695]	validation_0-mae:12.08433
# [696]	validation_0-mae:12.08388
# [697]	validation_0-mae:12.08602
# [698]	validation_0-mae:12.08626
# [699]	validation_0-mae:12.08747
# [700]	validation_0-mae:12.08683
# [701]	validation_0-mae:12.08722
# [702]	validation_0-mae:12.08696
# [703]	validation_0-mae:12.08365
# [704]	validation_0-mae:12.08169
# [705]	validation_0-mae:12.07916
# [706]	validation_0-mae:12.07670
# [707]	validation_0-mae:12.07502
# [708]	validation_0-mae:12.07411
# [709]	validation_0-mae:12.07363
# [710]	validation_0-mae:12.07124
# [711]	validation_0-mae:12.07017
# [712]	validation_0-mae:12.07009
# [713]	validation_0-mae:12.06453
# [714]	validation_0-mae:12.06394
# [715]	validation_0-mae:12.06399
# [716]	validation_0-mae:12.06390
# [717]	validation_0-mae:12.06221
# [718]	validation_0-mae:12.05912
# [719]	validation_0-mae:12.05607
# [720]	validation_0-mae:12.05603
# [721]	validation_0-mae:12.05641
# [722]	validation_0-mae:12.05618
# [723]	validation_0-mae:12.05546
# [724]	validation_0-mae:12.05534
# [725]	validation_0-mae:12.05544
# [726]	validation_0-mae:12.05576
# [727]	validation_0-mae:12.05595
# [728]	validation_0-mae:12.05623
# [729]	validation_0-mae:12.05607
# [730]	validation_0-mae:12.05562
# [731]	validation_0-mae:12.05577
# [732]	validation_0-mae:12.05557
# [733]	validation_0-mae:12.05349
# [734]	validation_0-mae:12.05325
# [735]	validation_0-mae:12.05327
# [736]	validation_0-mae:12.05334
# [737]	validation_0-mae:12.05355
# [738]	validation_0-mae:12.05380
# [739]	validation_0-mae:12.05461
# [740]	validation_0-mae:12.05453
# [741]	validation_0-mae:12.05255
# [742]	validation_0-mae:12.05048
# [743]	validation_0-mae:12.04944
# [744]	validation_0-mae:12.04724
# [745]	validation_0-mae:12.04743
# [746]	validation_0-mae:12.04739
# [747]	validation_0-mae:12.04505
# [748]	validation_0-mae:12.04541
# [749]	validation_0-mae:12.04529
# [750]	validation_0-mae:12.04554
# [751]	validation_0-mae:12.04581
# [752]	validation_0-mae:12.04574
# [753]	validation_0-mae:12.04582
# [754]	validation_0-mae:12.04380
# [755]	validation_0-mae:12.04190
# [756]	validation_0-mae:12.04174
# [757]	validation_0-mae:12.04183
# [758]	validation_0-mae:12.04126
# [759]	validation_0-mae:12.04112
# [760]	validation_0-mae:12.04149
# [761]	validation_0-mae:12.04016
# [762]	validation_0-mae:12.04047
# [763]	validation_0-mae:12.03678
# [764]	validation_0-mae:12.03573
# [765]	validation_0-mae:12.03175
# [766]	validation_0-mae:12.03162
# [767]	validation_0-mae:12.03004
# [768]	validation_0-mae:12.02992
# [769]	validation_0-mae:12.03079
# [770]	validation_0-mae:12.03100
# [771]	validation_0-mae:12.03061
# [772]	validation_0-mae:12.02342
# [773]	validation_0-mae:12.02410
# [774]	validation_0-mae:12.02564
# [775]	validation_0-mae:12.02535
# [776]	validation_0-mae:12.02356
# [777]	validation_0-mae:12.02426
# [778]	validation_0-mae:12.02507
# [779]	validation_0-mae:12.01939
# [780]	validation_0-mae:12.01937
# [781]	validation_0-mae:12.01944
# [782]	validation_0-mae:12.01922
# [783]	validation_0-mae:12.01907
# [784]	validation_0-mae:12.01985
# [785]	validation_0-mae:12.01970
# [786]	validation_0-mae:12.01562
# [787]	validation_0-mae:12.01608
# [788]	validation_0-mae:12.00980
# [789]	validation_0-mae:12.00960
# [790]	validation_0-mae:12.00716
# [791]	validation_0-mae:12.00660
# [792]	validation_0-mae:12.00106
# [793]	validation_0-mae:12.00175
# [794]	validation_0-mae:11.99890
# [795]	validation_0-mae:11.99564
# [796]	validation_0-mae:11.99478
# [797]	validation_0-mae:11.99486
# [798]	validation_0-mae:11.99437
# [799]	validation_0-mae:11.99292
# [800]	validation_0-mae:11.99289
# [801]	validation_0-mae:11.98827
# [802]	validation_0-mae:11.98829
# [803]	validation_0-mae:11.98818
# [804]	validation_0-mae:11.98761
# [805]	validation_0-mae:11.98557
# [806]	validation_0-mae:11.98655
# [807]	validation_0-mae:11.98603
# [808]	validation_0-mae:11.98490
# [809]	validation_0-mae:11.98240
# [810]	validation_0-mae:11.98238
# [811]	validation_0-mae:11.98189
# [812]	validation_0-mae:11.97924
# [813]	validation_0-mae:11.97912
# [814]	validation_0-mae:11.97890
# [815]	validation_0-mae:11.97906
# [816]	validation_0-mae:11.97466
# [817]	validation_0-mae:11.97519
# [818]	validation_0-mae:11.97506
# [819]	validation_0-mae:11.97398
# [820]	validation_0-mae:11.97474
# [821]	validation_0-mae:11.97401
# [822]	validation_0-mae:11.97360
# [823]	validation_0-mae:11.97176
# [824]	validation_0-mae:11.97153
# [825]	validation_0-mae:11.97180
# [826]	validation_0-mae:11.96969
# [827]	validation_0-mae:11.97006
# [828]	validation_0-mae:11.96962
# [829]	validation_0-mae:11.96954
# [830]	validation_0-mae:11.96963
# [831]	validation_0-mae:11.96937
# [832]	validation_0-mae:11.96514
# [833]	validation_0-mae:11.96513
# [834]	validation_0-mae:11.96519
# [835]	validation_0-mae:11.96361
# [836]	validation_0-mae:11.96139
# [837]	validation_0-mae:11.95794
# [838]	validation_0-mae:11.95884
# [839]	validation_0-mae:11.95331
# [840]	validation_0-mae:11.95341
# [841]	validation_0-mae:11.95341
# [842]	validation_0-mae:11.95369
# [843]	validation_0-mae:11.94922
# [844]	validation_0-mae:11.94797
# [845]	validation_0-mae:11.94846
# [846]	validation_0-mae:11.94704
# [847]	validation_0-mae:11.94805
# [848]	validation_0-mae:11.94795
# [849]	validation_0-mae:11.94914
# [850]	validation_0-mae:11.94949
# [851]	validation_0-mae:11.94634
# [852]	validation_0-mae:11.94646
# [853]	validation_0-mae:11.94767
# [854]	validation_0-mae:11.94741
# [855]	validation_0-mae:11.94749
# [856]	validation_0-mae:11.94690
# [857]	validation_0-mae:11.94705
# [858]	validation_0-mae:11.94733
# [859]	validation_0-mae:11.94715
# [860]	validation_0-mae:11.94500
# [861]	validation_0-mae:11.94373
# [862]	validation_0-mae:11.94267
# [863]	validation_0-mae:11.94152
# [864]	validation_0-mae:11.94229
# [865]	validation_0-mae:11.93983
# [866]	validation_0-mae:11.93810
# [867]	validation_0-mae:11.93829
# [868]	validation_0-mae:11.93572
# [869]	validation_0-mae:11.93499
# [870]	validation_0-mae:11.93624
# [871]	validation_0-mae:11.93381
# [872]	validation_0-mae:11.93253
# [873]	validation_0-mae:11.93304
# [874]	validation_0-mae:11.93261
# [875]	validation_0-mae:11.93290
# [876]	validation_0-mae:11.93309
# [877]	validation_0-mae:11.93113
# [878]	validation_0-mae:11.93045
# [879]	validation_0-mae:11.92920
# [880]	validation_0-mae:11.92866
# [881]	validation_0-mae:11.92705
# [882]	validation_0-mae:11.92608
# [883]	validation_0-mae:11.92679
# [884]	validation_0-mae:11.92676
# [885]	validation_0-mae:11.92694
# [886]	validation_0-mae:11.92582
# [887]	validation_0-mae:11.92606
# [888]	validation_0-mae:11.92458
# [889]	validation_0-mae:11.92446
# [890]	validation_0-mae:11.92355
# [891]	validation_0-mae:11.92045
# [892]	validation_0-mae:11.91531
# [893]	validation_0-mae:11.91750
# [894]	validation_0-mae:11.91378
# [895]	validation_0-mae:11.91147
# [896]	validation_0-mae:11.91073
# [897]	validation_0-mae:11.90840
# [898]	validation_0-mae:11.90822
# [899]	validation_0-mae:11.90779
# [900]	validation_0-mae:11.90761
# [901]	validation_0-mae:11.90785
# [902]	validation_0-mae:11.90621
# [903]	validation_0-mae:11.90512
# [904]	validation_0-mae:11.90458
# [905]	validation_0-mae:11.90532
# [906]	validation_0-mae:11.90210
# [907]	validation_0-mae:11.89960
# [908]	validation_0-mae:11.90002
# [909]	validation_0-mae:11.90001
# [910]	validation_0-mae:11.90046
# [911]	validation_0-mae:11.89941
# [912]	validation_0-mae:11.89976
# [913]	validation_0-mae:11.90002
# [914]	validation_0-mae:11.90086
# [915]	validation_0-mae:11.90217
# [916]	validation_0-mae:11.89982
# [917]	validation_0-mae:11.89695
# [918]	validation_0-mae:11.89657
# [919]	validation_0-mae:11.89843
# [920]	validation_0-mae:11.89855
# [921]	validation_0-mae:11.89880
# [922]	validation_0-mae:11.89862
# [923]	validation_0-mae:11.89424
# [924]	validation_0-mae:11.89346
# [925]	validation_0-mae:11.89347
# [926]	validation_0-mae:11.89341
# [927]	validation_0-mae:11.89226
# [928]	validation_0-mae:11.89199
# [929]	validation_0-mae:11.88996
# [930]	validation_0-mae:11.88908
# [931]	validation_0-mae:11.88888
# [932]	validation_0-mae:11.88920
# [933]	validation_0-mae:11.88891
# [934]	validation_0-mae:11.88824
# [935]	validation_0-mae:11.88797
# [936]	validation_0-mae:11.88672
# [937]	validation_0-mae:11.88680
# [938]	validation_0-mae:11.88734
# [939]	validation_0-mae:11.88747
# [940]	validation_0-mae:11.88800
# [941]	validation_0-mae:11.88685
# [942]	validation_0-mae:11.88746
# [943]	validation_0-mae:11.88772
# [944]	validation_0-mae:11.88578
# [945]	validation_0-mae:11.88575
# [946]	validation_0-mae:11.88686
# [947]	validation_0-mae:11.88591
# [948]	validation_0-mae:11.88731
# [949]	validation_0-mae:11.88729
# [950]	validation_0-mae:11.88535
# [951]	validation_0-mae:11.88558
# [952]	validation_0-mae:11.88726
# [953]	validation_0-mae:11.88644
# [954]	validation_0-mae:11.88565
# [955]	validation_0-mae:11.87886
# [956]	validation_0-mae:11.87938
# [957]	validation_0-mae:11.87920
# [958]	validation_0-mae:11.87637
# [959]	validation_0-mae:11.87521
# [960]	validation_0-mae:11.87432
# [961]	validation_0-mae:11.87174
# [962]	validation_0-mae:11.87047
# [963]	validation_0-mae:11.86470
# [964]	validation_0-mae:11.86249
# [965]	validation_0-mae:11.86142
# [966]	validation_0-mae:11.86012
# [967]	validation_0-mae:11.85936
# [968]	validation_0-mae:11.85967
# [969]	validation_0-mae:11.85925
# [970]	validation_0-mae:11.86041
# [971]	validation_0-mae:11.86108
# [972]	validation_0-mae:11.86008
# [973]	validation_0-mae:11.85880
# [974]	validation_0-mae:11.85843
# [975]	validation_0-mae:11.85637
# [976]	validation_0-mae:11.85478
# [977]	validation_0-mae:11.85123
# [978]	validation_0-mae:11.85025
# [979]	validation_0-mae:11.85018
# [980]	validation_0-mae:11.85129
# [981]	validation_0-mae:11.85110
# [982]	validation_0-mae:11.85095
# [983]	validation_0-mae:11.85098
# [984]	validation_0-mae:11.85119
# [985]	validation_0-mae:11.85130
# [986]	validation_0-mae:11.85106
# [987]	validation_0-mae:11.84982
# [988]	validation_0-mae:11.84976
# [989]	validation_0-mae:11.84816
# [990]	validation_0-mae:11.84770
# [991]	validation_0-mae:11.84729
# [992]	validation_0-mae:11.84739
# [993]	validation_0-mae:11.84834
# [994]	validation_0-mae:11.84771
# [995]	validation_0-mae:11.84793
# [996]	validation_0-mae:11.84829
# [997]	validation_0-mae:11.84843
# [998]	validation_0-mae:11.84896
# [999]	validation_0-mae:11.84896
# [1000]	validation_0-mae:11.84948
# [1001]	validation_0-mae:11.84898
# [1002]	validation_0-mae:11.84939
# [1003]	validation_0-mae:11.84900
# [1004]	validation_0-mae:11.84904
# [1005]	validation_0-mae:11.84894
# [1006]	validation_0-mae:11.84871
# [1007]	validation_0-mae:11.84895
# [1008]	validation_0-mae:11.85002
# [1009]	validation_0-mae:11.84998
# [1010]	validation_0-mae:11.84988
# [1011]	validation_0-mae:11.85014
# [1012]	validation_0-mae:11.84900
# [1013]	validation_0-mae:11.84822
# [1014]	validation_0-mae:11.84871
# [1015]	validation_0-mae:11.84863
# [1016]	validation_0-mae:11.84962
# Stopping. Best iteration:
# [991]	validation_0-mae:11.84729
#
#
# ========================================================
#  Results from Grid Search
# ========================================================
#
#  The best estimator across ALL searched params:
#  XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, eta=0.05,
#              eval_metric='mae', gamma=0, gpu_id=-1, importance_type='gain',
#              interaction_constraints='', learning_rate=0.0500000007,
#              max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=5000, n_jobs=0,
#              num_parallel_tree=1, random_state=0, reg_alpha=0, reg_lambda=1,
#              scale_pos_weight=1, subsample=1, tree_method='hist',
#              validate_parameters=1, verbosity=None)
#
#  The best score across ALL searched params:
#  -12.885168854533664
#
#  The best parameters across ALL searched params:
#  {'eta': 0.05, 'eval_metric': 'mae', 'max_depth': 6, 'n_estimators': 5000, 'tree_method': 'hist'}
#
#  ========================================================

# %%
best_params = grid.best_params_
model = xgb.XGBRegressor(**best_params)

model.fit(X_train, y_train, **fit_params)

y_hat = model.predict(X_test)
# Out:
# [0]	validation_0-mae:321.28171
# Will train until validation_0-mae hasn't improved in 25 rounds.
# [1]	validation_0-mae:305.24344
# [2]	validation_0-mae:290.00177
# [3]	validation_0-mae:275.52103
# [4]	validation_0-mae:261.76086
# [5]	validation_0-mae:248.69035
# [6]	validation_0-mae:236.27896
# [7]	validation_0-mae:224.48323
# [8]	validation_0-mae:213.27463
# [9]	validation_0-mae:202.63275
# [10]	validation_0-mae:192.51916
# [11]	validation_0-mae:182.91724
# [12]	validation_0-mae:173.78989
# [13]	validation_0-mae:165.10312
# [14]	validation_0-mae:156.86307
# [15]	validation_0-mae:149.05225
# [16]	validation_0-mae:141.60292
# [17]	validation_0-mae:134.54460
# [18]	validation_0-mae:127.82580
# [19]	validation_0-mae:121.46277
# [20]	validation_0-mae:115.40423
# [21]	validation_0-mae:109.64862
# [22]	validation_0-mae:104.18672
# [23]	validation_0-mae:98.99040
# [24]	validation_0-mae:94.05547
# [25]	validation_0-mae:89.36540
# [26]	validation_0-mae:84.92107
# [27]	validation_0-mae:80.69498
# [28]	validation_0-mae:76.68875
# [29]	validation_0-mae:72.87573
# [30]	validation_0-mae:69.26188
# [31]	validation_0-mae:65.83274
# [32]	validation_0-mae:62.57188
# [33]	validation_0-mae:59.48191
# [34]	validation_0-mae:56.54030
# [35]	validation_0-mae:53.75865
# [36]	validation_0-mae:51.13111
# [37]	validation_0-mae:48.64072
# [38]	validation_0-mae:46.28744
# [39]	validation_0-mae:44.08230
# [40]	validation_0-mae:42.00194
# [41]	validation_0-mae:40.05356
# [42]	validation_0-mae:38.23104
# [43]	validation_0-mae:36.52097
# [44]	validation_0-mae:34.92273
# [45]	validation_0-mae:33.44489
# [46]	validation_0-mae:32.06457
# [47]	validation_0-mae:30.77855
# [48]	validation_0-mae:29.59088
# [49]	validation_0-mae:28.50346
# [50]	validation_0-mae:27.48887
# [51]	validation_0-mae:26.54615
# [52]	validation_0-mae:25.68524
# [53]	validation_0-mae:24.89349
# [54]	validation_0-mae:24.15288
# [55]	validation_0-mae:23.47760
# [56]	validation_0-mae:22.86038
# [57]	validation_0-mae:22.29570
# [58]	validation_0-mae:21.78156
# [59]	validation_0-mae:21.30317
# [60]	validation_0-mae:20.87797
# [61]	validation_0-mae:20.48632
# [62]	validation_0-mae:20.13704
# [63]	validation_0-mae:19.80916
# [64]	validation_0-mae:19.51340
# [65]	validation_0-mae:19.23469
# [66]	validation_0-mae:18.98182
# [67]	validation_0-mae:18.75555
# [68]	validation_0-mae:18.54682
# [69]	validation_0-mae:18.34635
# [70]	validation_0-mae:18.18083
# [71]	validation_0-mae:18.02205
# [72]	validation_0-mae:17.87940
# [73]	validation_0-mae:17.75067
# [74]	validation_0-mae:17.63238
# [75]	validation_0-mae:17.52148
# [76]	validation_0-mae:17.42875
# [77]	validation_0-mae:17.34504
# [78]	validation_0-mae:17.25935
# [79]	validation_0-mae:17.16316
# [80]	validation_0-mae:17.07819
# [81]	validation_0-mae:16.99317
# [82]	validation_0-mae:16.92126
# [83]	validation_0-mae:16.86887
# [84]	validation_0-mae:16.81832
# [85]	validation_0-mae:16.76225
# [86]	validation_0-mae:16.69709
# [87]	validation_0-mae:16.63720
# [88]	validation_0-mae:16.60348
# [89]	validation_0-mae:16.55572
# [90]	validation_0-mae:16.51544
# [91]	validation_0-mae:16.48149
# [92]	validation_0-mae:16.45613
# [93]	validation_0-mae:16.42397
# [94]	validation_0-mae:16.38252
# [95]	validation_0-mae:16.34970
# [96]	validation_0-mae:16.30227
# [97]	validation_0-mae:16.28270
# [98]	validation_0-mae:16.23944
# [99]	validation_0-mae:16.22480
# [100]	validation_0-mae:16.19780
# [101]	validation_0-mae:16.16692
# [102]	validation_0-mae:16.13283
# [103]	validation_0-mae:16.10560
# [104]	validation_0-mae:16.09526
# [105]	validation_0-mae:16.06290
# [106]	validation_0-mae:16.05040
# [107]	validation_0-mae:16.01517
# [108]	validation_0-mae:15.98914
# [109]	validation_0-mae:15.95575
# [110]	validation_0-mae:15.89360
# [111]	validation_0-mae:15.85454
# [112]	validation_0-mae:15.82939
# [113]	validation_0-mae:15.82102
# [114]	validation_0-mae:15.78315
# [115]	validation_0-mae:15.76737
# [116]	validation_0-mae:15.75818
# [117]	validation_0-mae:15.75275
# [118]	validation_0-mae:15.74243
# [119]	validation_0-mae:15.71374
# [120]	validation_0-mae:15.68716
# [121]	validation_0-mae:15.65886
# [122]	validation_0-mae:15.63952
# [123]	validation_0-mae:15.61889
# [124]	validation_0-mae:15.59396
# [125]	validation_0-mae:15.55042
# [126]	validation_0-mae:15.53585
# [127]	validation_0-mae:15.48719
# [128]	validation_0-mae:15.46661
# [129]	validation_0-mae:15.44045
# [130]	validation_0-mae:15.43689
# [131]	validation_0-mae:15.43256
# [132]	validation_0-mae:15.40905
# [133]	validation_0-mae:15.39633
# [134]	validation_0-mae:15.38005
# [135]	validation_0-mae:15.35647
# [136]	validation_0-mae:15.34161
# [137]	validation_0-mae:15.33293
# [138]	validation_0-mae:15.32679
# [392]	validation_0-mae:13.07991
# [393]	validation_0-mae:13.06621
# [394]	validation_0-mae:13.06225
# [395]	validation_0-mae:13.06184
# [396]	validation_0-mae:13.06242
# [397]	validation_0-mae:13.06122
# [398]	validation_0-mae:13.05764
# [399]	validation_0-mae:13.05493
# [400]	validation_0-mae:13.05512
# [401]	validation_0-mae:13.04464
# [402]	validation_0-mae:13.04474
# [403]	validation_0-mae:13.03915
# [404]	validation_0-mae:13.03811
# [405]	validation_0-mae:13.03656
# [406]	validation_0-mae:13.03523
# [407]	validation_0-mae:13.03542
# [408]	validation_0-mae:13.02474
# [409]	validation_0-mae:13.02000
# [410]	validation_0-mae:13.01898
# [411]	validation_0-mae:13.01889
# [412]	validation_0-mae:13.01093
# [413]	validation_0-mae:13.00047
# [414]	validation_0-mae:12.99481
# [415]	validation_0-mae:12.98508
# [416]	validation_0-mae:12.98425
# [417]	validation_0-mae:12.98366
# [418]	validation_0-mae:12.98180
# [419]	validation_0-mae:12.97434
# [420]	validation_0-mae:12.97424
# [421]	validation_0-mae:12.96768
# [422]	validation_0-mae:12.96877
# [423]	validation_0-mae:12.96533
# [424]	validation_0-mae:12.95947
# [425]	validation_0-mae:12.94961
# [426]	validation_0-mae:12.94098
# [427]	validation_0-mae:12.93086
# [428]	validation_0-mae:12.92948
# [429]	validation_0-mae:12.91999
# [430]	validation_0-mae:12.92070
# [431]	validation_0-mae:12.92081
# [432]	validation_0-mae:12.92143
# [433]	validation_0-mae:12.92201
# [434]	validation_0-mae:12.92141
# [435]	validation_0-mae:12.91210
# [436]	validation_0-mae:12.91109
# [437]	validation_0-mae:12.89930
# [438]	validation_0-mae:12.89983
# [439]	validation_0-mae:12.89237
# [440]	validation_0-mae:12.88576
# [441]	validation_0-mae:12.87556
# [442]	validation_0-mae:12.87569
# [443]	validation_0-mae:12.87567
# [444]	validation_0-mae:12.87450
# [445]	validation_0-mae:12.87331
# [446]	validation_0-mae:12.87226
# [447]	validation_0-mae:12.86444
# [448]	validation_0-mae:12.85696
# [449]	validation_0-mae:12.84835
# [450]	validation_0-mae:12.83744
# [451]	validation_0-mae:12.83469
# [452]	validation_0-mae:12.83211
# [453]	validation_0-mae:12.82563
# [454]	validation_0-mae:12.80912
# [455]	validation_0-mae:12.80155
# [456]	validation_0-mae:12.79218
# [457]	validation_0-mae:12.78742
# [458]	validation_0-mae:12.78530
# [459]	validation_0-mae:12.78505
# [460]	validation_0-mae:12.78536
# [461]	validation_0-mae:12.78052
# [462]	validation_0-mae:12.77398
# [463]	validation_0-mae:12.77153
# [464]	validation_0-mae:12.76818
# [465]	validation_0-mae:12.76796
# [466]	validation_0-mae:12.76503
# [467]	validation_0-mae:12.76315
# [468]	validation_0-mae:12.74453
# [469]	validation_0-mae:12.74302
# [470]	validation_0-mae:12.74285
# [471]	validation_0-mae:12.74404
# [472]	validation_0-mae:12.74420
# [473]	validation_0-mae:12.74383
# [474]	validation_0-mae:12.74456
# [475]	validation_0-mae:12.74165
# [476]	validation_0-mae:12.74106
# [477]	validation_0-mae:12.74102
# [478]	validation_0-mae:12.73975
# [479]	validation_0-mae:12.73868
# [480]	validation_0-mae:12.73740
# [481]	validation_0-mae:12.72756
# [482]	validation_0-mae:12.72520
# [483]	validation_0-mae:12.71254
# [484]	validation_0-mae:12.71137
# [485]	validation_0-mae:12.70529
# [486]	validation_0-mae:12.69948
# [487]	validation_0-mae:12.69341
# [488]	validation_0-mae:12.69230
# [489]	validation_0-mae:12.69196
# [490]	validation_0-mae:12.67469
# [491]	validation_0-mae:12.67609
# [492]	validation_0-mae:12.67503
# [493]	validation_0-mae:12.67489
# [494]	validation_0-mae:12.67070
# [495]	validation_0-mae:12.66233
# [496]	validation_0-mae:12.66040
# [497]	validation_0-mae:12.66087
# [498]	validation_0-mae:12.65348
# [499]	validation_0-mae:12.65373
# [500]	validation_0-mae:12.65394
# [501]	validation_0-mae:12.64020
# [502]	validation_0-mae:12.63588
# [503]	validation_0-mae:12.63536
# [504]	validation_0-mae:12.63426
# [505]	validation_0-mae:12.63302
# [506]	validation_0-mae:12.62884
# [507]	validation_0-mae:12.62806
# [508]	validation_0-mae:12.62658
# [509]	validation_0-mae:12.61967
# [510]	validation_0-mae:12.61317
# [511]	validation_0-mae:12.60607
# [512]	validation_0-mae:12.60145
# [513]	validation_0-mae:12.60076
# [514]	validation_0-mae:12.59218
# [515]	validation_0-mae:12.58644
# [516]	validation_0-mae:12.58183
# [517]	validation_0-mae:12.57626
# [518]	validation_0-mae:12.57022
# [519]	validation_0-mae:12.56672
# [520]	validation_0-mae:12.56247
# [521]	validation_0-mae:12.55799
# [522]	validation_0-mae:12.55502
# [523]	validation_0-mae:12.54754
# [524]	validation_0-mae:12.54237
# [525]	validation_0-mae:12.54203
# [526]	validation_0-mae:12.54192
# [527]	validation_0-mae:12.54139
# [528]	validation_0-mae:12.52589
# [529]	validation_0-mae:12.52410
# [530]	validation_0-mae:12.51259
# [531]	validation_0-mae:12.51013
# [532]	validation_0-mae:12.51010
# [533]	validation_0-mae:12.49618
# [534]	validation_0-mae:12.48888
# [535]	validation_0-mae:12.47734
# [536]	validation_0-mae:12.47864
# [537]	validation_0-mae:12.47786
# [538]	validation_0-mae:12.47595
# [539]	validation_0-mae:12.46638
# [540]	validation_0-mae:12.46601
# [541]	validation_0-mae:12.46598
# [542]	validation_0-mae:12.46585
# [543]	validation_0-mae:12.46697
# [544]	validation_0-mae:12.46311
# [545]	validation_0-mae:12.46332
# [546]	validation_0-mae:12.46292
# [547]	validation_0-mae:12.45607
# [548]	validation_0-mae:12.45334
# [549]	validation_0-mae:12.44960
# [550]	validation_0-mae:12.44956
# [551]	validation_0-mae:12.44449
# [552]	validation_0-mae:12.44225
# [553]	validation_0-mae:12.44215
# [554]	validation_0-mae:12.43836
# [555]	validation_0-mae:12.43835
# [556]	validation_0-mae:12.43881
# [557]	validation_0-mae:12.43763
# [558]	validation_0-mae:12.43692
# [559]	validation_0-mae:12.43746
# [560]	validation_0-mae:12.43811
# [561]	validation_0-mae:12.43832
# [562]	validation_0-mae:12.43770
# [563]	validation_0-mae:12.43670
# [564]	validation_0-mae:12.43718
# [565]	validation_0-mae:12.43849
# [566]	validation_0-mae:12.43633
# [567]	validation_0-mae:12.42699
# [568]	validation_0-mae:12.41421
# [569]	validation_0-mae:12.41084
# [570]	validation_0-mae:12.40873
# [571]	validation_0-mae:12.39837
# [572]	validation_0-mae:12.39780
# [573]	validation_0-mae:12.39648
# [574]	validation_0-mae:12.39637
# [575]	validation_0-mae:12.39706
# [576]	validation_0-mae:12.39474
# [577]	validation_0-mae:12.39432
# [578]	validation_0-mae:12.38819
# [579]	validation_0-mae:12.38119
# [580]	validation_0-mae:12.38043
# [581]	validation_0-mae:12.37879
# [582]	validation_0-mae:12.37593
# [583]	validation_0-mae:12.37660
# [584]	validation_0-mae:12.36710
# [585]	validation_0-mae:12.36488
# [586]	validation_0-mae:12.36520
# [587]	validation_0-mae:12.36243
# [588]	validation_0-mae:12.36121
# [589]	validation_0-mae:12.35926
# [590]	validation_0-mae:12.35403
# [591]	validation_0-mae:12.35406
# [592]	validation_0-mae:12.35485
# [593]	validation_0-mae:12.35066
# [594]	validation_0-mae:12.34899
# [595]	validation_0-mae:12.34451
# [596]	validation_0-mae:12.34112
# [597]	validation_0-mae:12.34134
# [598]	validation_0-mae:12.34201
# [599]	validation_0-mae:12.34204
# [600]	validation_0-mae:12.33396
# [601]	validation_0-mae:12.32483
# [602]	validation_0-mae:12.32534
# [603]	validation_0-mae:12.32375
# [604]	validation_0-mae:12.31176
# [605]	validation_0-mae:12.30371
# [606]	validation_0-mae:12.29047
# [607]	validation_0-mae:12.28229
# [608]	validation_0-mae:12.27267
# [609]	validation_0-mae:12.27246
# [610]	validation_0-mae:12.27257
# [611]	validation_0-mae:12.26298
# [612]	validation_0-mae:12.26053
# [613]	validation_0-mae:12.26112
# [614]	validation_0-mae:12.25558
# [615]	validation_0-mae:12.25359
# [616]	validation_0-mae:12.24720
# [617]	validation_0-mae:12.24032
# [618]	validation_0-mae:12.23273
# [619]	validation_0-mae:12.23169
# [620]	validation_0-mae:12.22727
# [621]	validation_0-mae:12.22493
# [622]	validation_0-mae:12.21964
# [623]	validation_0-mae:12.21683
# [624]	validation_0-mae:12.21427
# [625]	validation_0-mae:12.20745
# [626]	validation_0-mae:12.20740
# [627]	validation_0-mae:12.20657
# [628]	validation_0-mae:12.20727
# [629]	validation_0-mae:12.20717
# [630]	validation_0-mae:12.20766
# [631]	validation_0-mae:12.20795
# [632]	validation_0-mae:12.20894
# [633]	validation_0-mae:12.20993
# [634]	validation_0-mae:12.20880
# [635]	validation_0-mae:12.20689
# [636]	validation_0-mae:12.20388
# [637]	validation_0-mae:12.19744
# [638]	validation_0-mae:12.19154
# [639]	validation_0-mae:12.18353
# [640]	validation_0-mae:12.18094
# [641]	validation_0-mae:12.17989
# [642]	validation_0-mae:12.18061
# [643]	validation_0-mae:12.17995
# [644]	validation_0-mae:12.17953
# [645]	validation_0-mae:12.17404
# [646]	validation_0-mae:12.17139
# [647]	validation_0-mae:12.17069
# [648]	validation_0-mae:12.16995
# [649]	validation_0-mae:12.16450
# [650]	validation_0-mae:12.16265
# [651]	validation_0-mae:12.16064
# [652]	validation_0-mae:12.15738
# [653]	validation_0-mae:12.15695
# [654]	validation_0-mae:12.15657
# [655]	validation_0-mae:12.15465
# [656]	validation_0-mae:12.15033
# [657]	validation_0-mae:12.14973
# [658]	validation_0-mae:12.14560
# [659]	validation_0-mae:12.14123
# [660]	validation_0-mae:12.13248
# [661]	validation_0-mae:12.13037
# [662]	validation_0-mae:12.12788
# [663]	validation_0-mae:12.12509
# [664]	validation_0-mae:12.12635
# [665]	validation_0-mae:12.12452
# [666]	validation_0-mae:12.12376
# [667]	validation_0-mae:12.12132
# [668]	validation_0-mae:12.11960
# [669]	validation_0-mae:12.11597
# [670]	validation_0-mae:12.11356
# [671]	validation_0-mae:12.11088
# [672]	validation_0-mae:12.11216
# [673]	validation_0-mae:12.11158
# [674]	validation_0-mae:12.11159
# [675]	validation_0-mae:12.11125
# [676]	validation_0-mae:12.10906
# [677]	validation_0-mae:12.10521
# [678]	validation_0-mae:12.10478
# [679]	validation_0-mae:12.10521
# [680]	validation_0-mae:12.09940
# [681]	validation_0-mae:12.09646
# [682]	validation_0-mae:12.09591
# [683]	validation_0-mae:12.09531
# [684]	validation_0-mae:12.09528
# [685]	validation_0-mae:12.09214
# [686]	validation_0-mae:12.09175
# [687]	validation_0-mae:12.09081
# [688]	validation_0-mae:12.08717
# [689]	validation_0-mae:12.08721
# [690]	validation_0-mae:12.08771
# [691]	validation_0-mae:12.08724
# [692]	validation_0-mae:12.08644
# [693]	validation_0-mae:12.08488
# [694]	validation_0-mae:12.08435
# [695]	validation_0-mae:12.08433
# [696]	validation_0-mae:12.08388
# [697]	validation_0-mae:12.08602
# [698]	validation_0-mae:12.08626
# [699]	validation_0-mae:12.08747
# [700]	validation_0-mae:12.08683
# [701]	validation_0-mae:12.08722
# [702]	validation_0-mae:12.08696
# [703]	validation_0-mae:12.08364
# [704]	validation_0-mae:12.08169
# [705]	validation_0-mae:12.07917
# [706]	validation_0-mae:12.07670
# [707]	validation_0-mae:12.07502
# [708]	validation_0-mae:12.07411
# [709]	validation_0-mae:12.07363
# [710]	validation_0-mae:12.07124
# [711]	validation_0-mae:12.07017
# [712]	validation_0-mae:12.07009
# [713]	validation_0-mae:12.06454
# [714]	validation_0-mae:12.06394
# [715]	validation_0-mae:12.06399
# [716]	validation_0-mae:12.06390
# [717]	validation_0-mae:12.06221
# [718]	validation_0-mae:12.05912
# [719]	validation_0-mae:12.05607
# [720]	validation_0-mae:12.05603
# [721]	validation_0-mae:12.05641
# [722]	validation_0-mae:12.05618
# [723]	validation_0-mae:12.05546
# [724]	validation_0-mae:12.05533
# [725]	validation_0-mae:12.05544
# [726]	validation_0-mae:12.05576
# [727]	validation_0-mae:12.05595
# [728]	validation_0-mae:12.05623
# [729]	validation_0-mae:12.05607
# [730]	validation_0-mae:12.05562
# [731]	validation_0-mae:12.05577
# [732]	validation_0-mae:12.05557
# [733]	validation_0-mae:12.05349
# [734]	validation_0-mae:12.05325
# [735]	validation_0-mae:12.05327
# [736]	validation_0-mae:12.05334
# [737]	validation_0-mae:12.05355
# [738]	validation_0-mae:12.05380
# [739]	validation_0-mae:12.05461
# [740]	validation_0-mae:12.05453
# [741]	validation_0-mae:12.05255
# [742]	validation_0-mae:12.05048
# [743]	validation_0-mae:12.04944
# [744]	validation_0-mae:12.04724
# [745]	validation_0-mae:12.04743
# [746]	validation_0-mae:12.04739
# [747]	validation_0-mae:12.04505
# [748]	validation_0-mae:12.04541
# [749]	validation_0-mae:12.04529
# [750]	validation_0-mae:12.04554
# [751]	validation_0-mae:12.04581
# [752]	validation_0-mae:12.04574
# [753]	validation_0-mae:12.04582
# [754]	validation_0-mae:12.04380
# [755]	validation_0-mae:12.04190
# [756]	validation_0-mae:12.04174
# [757]	validation_0-mae:12.04183
# [758]	validation_0-mae:12.04126
# [759]	validation_0-mae:12.04112
# [760]	validation_0-mae:12.04149
# [761]	validation_0-mae:12.04016
# [762]	validation_0-mae:12.04047
# [763]	validation_0-mae:12.03678
# [764]	validation_0-mae:12.03573
# [765]	validation_0-mae:12.03175
# [766]	validation_0-mae:12.03162
# [767]	validation_0-mae:12.03004
# [768]	validation_0-mae:12.02992
# [769]	validation_0-mae:12.03079
# [770]	validation_0-mae:12.03100
# [771]	validation_0-mae:12.03061
# [772]	validation_0-mae:12.02342
# [773]	validation_0-mae:12.02410
# [774]	validation_0-mae:12.02564
# [775]	validation_0-mae:12.02535
# [776]	validation_0-mae:12.02356
# [777]	validation_0-mae:12.02426
# [778]	validation_0-mae:12.02507
# [779]	validation_0-mae:12.01939
# [780]	validation_0-mae:12.01937
# [781]	validation_0-mae:12.01944
# [782]	validation_0-mae:12.01922
# [783]	validation_0-mae:12.01907
# [784]	validation_0-mae:12.01985
# [785]	validation_0-mae:12.01970
# [786]	validation_0-mae:12.01562
# [787]	validation_0-mae:12.01608
# [788]	validation_0-mae:12.00980
# [789]	validation_0-mae:12.00960
# [790]	validation_0-mae:12.00716
# [791]	validation_0-mae:12.00660
# [792]	validation_0-mae:12.00106
# [793]	validation_0-mae:12.00175
# [794]	validation_0-mae:11.99890
# [795]	validation_0-mae:11.99564
# [796]	validation_0-mae:11.99478
# [797]	validation_0-mae:11.99486
# [798]	validation_0-mae:11.99437
# [799]	validation_0-mae:11.99292
# [800]	validation_0-mae:11.99289
# [801]	validation_0-mae:11.98827
# [802]	validation_0-mae:11.98829
# [803]	validation_0-mae:11.98818
# [804]	validation_0-mae:11.98761
# [805]	validation_0-mae:11.98557
# [806]	validation_0-mae:11.98655
# [807]	validation_0-mae:11.98603
# [808]	validation_0-mae:11.98490
# [809]	validation_0-mae:11.98240
# [810]	validation_0-mae:11.98238
# [811]	validation_0-mae:11.98189
# [812]	validation_0-mae:11.97924
# [813]	validation_0-mae:11.97912
# [814]	validation_0-mae:11.97890
# [815]	validation_0-mae:11.97906
# [816]	validation_0-mae:11.97466
# [817]	validation_0-mae:11.97519
# [818]	validation_0-mae:11.97506
# [819]	validation_0-mae:11.97398
# [820]	validation_0-mae:11.97474
# [821]	validation_0-mae:11.97401
# [822]	validation_0-mae:11.97360
# [823]	validation_0-mae:11.97176
# [824]	validation_0-mae:11.97153
# [825]	validation_0-mae:11.97180
# [826]	validation_0-mae:11.96969
# [827]	validation_0-mae:11.97006
# [828]	validation_0-mae:11.96962
# [829]	validation_0-mae:11.96954
# [830]	validation_0-mae:11.96963
# [831]	validation_0-mae:11.96937
# [832]	validation_0-mae:11.96514
# [833]	validation_0-mae:11.96513
# [834]	validation_0-mae:11.96518
# [835]	validation_0-mae:11.96361
# [836]	validation_0-mae:11.96139
# [837]	validation_0-mae:11.95794
# [838]	validation_0-mae:11.95884
# [839]	validation_0-mae:11.95331
# [840]	validation_0-mae:11.95341
# [841]	validation_0-mae:11.95341
# [842]	validation_0-mae:11.95369
# [843]	validation_0-mae:11.94922
# [844]	validation_0-mae:11.94797
# [845]	validation_0-mae:11.94846
# [846]	validation_0-mae:11.94704
# [847]	validation_0-mae:11.94805
# [848]	validation_0-mae:11.94795
# [849]	validation_0-mae:11.94914
# [850]	validation_0-mae:11.94949
# [851]	validation_0-mae:11.94634
# [852]	validation_0-mae:11.94646
# [853]	validation_0-mae:11.94767
# [854]	validation_0-mae:11.94741
# [855]	validation_0-mae:11.94748
# [856]	validation_0-mae:11.94690
# [857]	validation_0-mae:11.94705
# [858]	validation_0-mae:11.94733
# [859]	validation_0-mae:11.94715
# [860]	validation_0-mae:11.94500
# [861]	validation_0-mae:11.94373
# [862]	validation_0-mae:11.94267
# [863]	validation_0-mae:11.94152
# [864]	validation_0-mae:11.94230
# [865]	validation_0-mae:11.93983
# [866]	validation_0-mae:11.93810
# [867]	validation_0-mae:11.93829
# [868]	validation_0-mae:11.93572
# [869]	validation_0-mae:11.93499
# [870]	validation_0-mae:11.93624
# [871]	validation_0-mae:11.93381
# [872]	validation_0-mae:11.93253
# [873]	validation_0-mae:11.93304
# [874]	validation_0-mae:11.93261
# [875]	validation_0-mae:11.93290
# [876]	validation_0-mae:11.93309
# [877]	validation_0-mae:11.93113
# [878]	validation_0-mae:11.93045
# [879]	validation_0-mae:11.92920
# [880]	validation_0-mae:11.92866
# [881]	validation_0-mae:11.92705
# [882]	validation_0-mae:11.92608
# [883]	validation_0-mae:11.92679
# [884]	validation_0-mae:11.92676
# [885]	validation_0-mae:11.92694
# [886]	validation_0-mae:11.92582
# [887]	validation_0-mae:11.92606
# [888]	validation_0-mae:11.92458
# [889]	validation_0-mae:11.92446
# [890]	validation_0-mae:11.92355
# [891]	validation_0-mae:11.92045
# [892]	validation_0-mae:11.91531
# [893]	validation_0-mae:11.91750
# [894]	validation_0-mae:11.91378
# [895]	validation_0-mae:11.91147
# [896]	validation_0-mae:11.91072
# [897]	validation_0-mae:11.90840
# [898]	validation_0-mae:11.90822
# [899]	validation_0-mae:11.90779
# [900]	validation_0-mae:11.90762
# [901]	validation_0-mae:11.90785
# [902]	validation_0-mae:11.90621
# [903]	validation_0-mae:11.90512
# [904]	validation_0-mae:11.90458
# [905]	validation_0-mae:11.90532
# [906]	validation_0-mae:11.90210
# [907]	validation_0-mae:11.89960
# [908]	validation_0-mae:11.90002
# [909]	validation_0-mae:11.90001
# [910]	validation_0-mae:11.90046
# [911]	validation_0-mae:11.89941
# [912]	validation_0-mae:11.89976
# [913]	validation_0-mae:11.90002
# [914]	validation_0-mae:11.90086
# [915]	validation_0-mae:11.90216
# [916]	validation_0-mae:11.89982
# [917]	validation_0-mae:11.89695
# [918]	validation_0-mae:11.89657
# [919]	validation_0-mae:11.89843
# [920]	validation_0-mae:11.89855
# [921]	validation_0-mae:11.89880
# [922]	validation_0-mae:11.89862
# [923]	validation_0-mae:11.89424
# [924]	validation_0-mae:11.89347
# [925]	validation_0-mae:11.89347
# [926]	validation_0-mae:11.89341
# [927]	validation_0-mae:11.89226
# [928]	validation_0-mae:11.89199
# [929]	validation_0-mae:11.88996
# [930]	validation_0-mae:11.88908
# [931]	validation_0-mae:11.88888
# [932]	validation_0-mae:11.88920
# [933]	validation_0-mae:11.88891
# [934]	validation_0-mae:11.88824
# [935]	validation_0-mae:11.88796
# [936]	validation_0-mae:11.88672
# [937]	validation_0-mae:11.88680
# [938]	validation_0-mae:11.88734
# [939]	validation_0-mae:11.88747
# [940]	validation_0-mae:11.88800
# [941]	validation_0-mae:11.88685
# [942]	validation_0-mae:11.88746
# [943]	validation_0-mae:11.88772
# [944]	validation_0-mae:11.88578
# [945]	validation_0-mae:11.88575
# [946]	validation_0-mae:11.88686
# [947]	validation_0-mae:11.88591
# [948]	validation_0-mae:11.88731
# [949]	validation_0-mae:11.88729
# [950]	validation_0-mae:11.88535
# [951]	validation_0-mae:11.88558
# [952]	validation_0-mae:11.88726
# [953]	validation_0-mae:11.88644
# [954]	validation_0-mae:11.88565
# [955]	validation_0-mae:11.87886
# [956]	validation_0-mae:11.87938
# [957]	validation_0-mae:11.87920
# [958]	validation_0-mae:11.87637
# [959]	validation_0-mae:11.87521
# [960]	validation_0-mae:11.87432
# [961]	validation_0-mae:11.87174
# [962]	validation_0-mae:11.87047
# [963]	validation_0-mae:11.86470
# [964]	validation_0-mae:11.86249
# [965]	validation_0-mae:11.86142
# [966]	validation_0-mae:11.86012
# [967]	validation_0-mae:11.85936
# [968]	validation_0-mae:11.85967
# [969]	validation_0-mae:11.85925
# [970]	validation_0-mae:11.86041
# [971]	validation_0-mae:11.86108
# [972]	validation_0-mae:11.86008
# [973]	validation_0-mae:11.85880
# [974]	validation_0-mae:11.85843
# [975]	validation_0-mae:11.85637
# [976]	validation_0-mae:11.85478
# [977]	validation_0-mae:11.85123
# [978]	validation_0-mae:11.85025
# [979]	validation_0-mae:11.85018
# [980]	validation_0-mae:11.85129
# [981]	validation_0-mae:11.85110
# [982]	validation_0-mae:11.85095
# [983]	validation_0-mae:11.85098
# [984]	validation_0-mae:11.85119
# [985]	validation_0-mae:11.85130
# [986]	validation_0-mae:11.85106
# [987]	validation_0-mae:11.84982
# [988]	validation_0-mae:11.84976
# [989]	validation_0-mae:11.84816
# [990]	validation_0-mae:11.84770
# [991]	validation_0-mae:11.84729
# [992]	validation_0-mae:11.84739
# [993]	validation_0-mae:11.84834
# [994]	validation_0-mae:11.84771
# [995]	validation_0-mae:11.84793
# [996]	validation_0-mae:11.84829
# [997]	validation_0-mae:11.84843
# [998]	validation_0-mae:11.84896
# [999]	validation_0-mae:11.84896
# [1000]	validation_0-mae:11.84948
# [1001]	validation_0-mae:11.84898
# [1002]	validation_0-mae:11.84939
# [1003]	validation_0-mae:11.84900
# [1004]	validation_0-mae:11.84904
# [1005]	validation_0-mae:11.84894
# [1006]	validation_0-mae:11.84871
# [1007]	validation_0-mae:11.84895
# [1008]	validation_0-mae:11.85002
# [1009]	validation_0-mae:11.84998
# [1010]	validation_0-mae:11.84988
# [1011]	validation_0-mae:11.85014
# [1012]	validation_0-mae:11.84900
# [1013]	validation_0-mae:11.84822
# [1014]	validation_0-mae:11.84871
# [1015]	validation_0-mae:11.84863
# [1016]	validation_0-mae:11.84962
# Stopping. Best iteration:
# [991]	validation_0-mae:11.84729

# %%
feature_importances = model.feature_importances_
feature_importance_df = pd.DataFrame({'Importance': feature_importances, 'Feature': selected_features})
feature_importance_df = feature_importance_df.sort_values(by='Importance')
ax = sns.barplot(x="Feature", y="Importance", data=feature_importance_df)
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
plt.show()

# %%
# Kpi
print("R2 (explained variance):")
print("Model:", round(metrics.r2_score(y_test, y_hat), 3))

print("\nMean Absolute Error (Σ|y-pred|/n):")
print("Model:", round(metrics.mean_absolute_error(y_test, y_hat), 6))

print("\nRoot Mean Squared Error (sqrt(Σ(y-pred)^2/n)):")
print("Model:", round(np.sqrt(metrics.mean_squared_error(y_test, y_hat)), 6))
# Out:
# R2 (explained variance):
# Model: 0.722
#
# Mean Absolute Error (Σ|y-pred|/n):
# Model: 11.847289
#
# Root Mean Squared Error (sqrt(Σ(y-pred)^2/n)):
# Model: 16.465596

# %%
residuals = y_test - y_hat

# plot predicted vs true
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(18, 10))
sns.scatterplot(y_hat, y_test, ax=ax[0])
abline_plot(intercept=0, slope=1, color="red", ax=ax[0])
ax[0].grid(True)
ax[0].set(xlabel="Predicted", ylabel="True", title="Predicted vs True")
ax[0].legend()
    
# plot predicted vs residuals
sns.scatterplot(y_hat, residuals, ax=ax[1])
ax[1].grid(True)
ax[1].set(xlabel="Predicted", ylabel="Residuals", title="Predicted vs Residuals")
ax[1].hlines(y=0, xmin=np.min(y_hat), xmax=np.max(y_hat))
ax[1].legend()
plt.show()

fig, ax = plt.subplots(figsize=(18, 5))
sns.distplot(residuals, color="red", hist=True, kde=True, kde_kws={"shade":True}, ax=ax)
ax.grid(True)
ax.set(title="Residuals distribution")
plt.show()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
